# %%
# !pip install pylibjpeg pylibjpeg-libjpeg pydicom
# Out:
# WARNING: Ignoring invalid distribution -illow (/home/ryan.zurrin001/miniconda3/envs/P3_2/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/home/ryan.zurrin001/miniconda3/envs/P3_2/lib/python3.9/site-packages)
# ...
# WARNING: Ignoring invalid distribution -illow (/home/ryan.zurrin001/miniconda3/envs/P3_2/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/home/ryan.zurrin001/miniconda3/envs/P3_2/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/home/ryan.zurrin001/miniconda3/envs/P3_2/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/home/ryan.zurrin001/miniconda3/envs/P3_2/lib/python3.9/site-packages)

# %%
data = Data(r'../../raid/data01/deephealth/dh_dcm_ast')

# %%
data.getSeriesCount()
# Out:
# 186764

# %%
print(data.getFileNamesInSeries(0))
# Out:
# ['DXm.2.25.327701373051007081828181561095836790377', 'DXm.2.25.214600937758118091934649285423608587441', 'DXm.2.25.119403010146292111130118207990186551199', 'DXm.2.25.97161058065485149118059870586506470816']

# %%
print(data.getFileNamesInSeries(10), True)
# Out:
# ['DXm.2.25.132505748830747409740198430912303576844', 'DXm.2.25.54340766639065471216209220321566650531', 'DXm.2.25.167180963455726584960672303706274696026', 'DXm.2.25.44352051871134028490313801179633239805'] True

# %%
print(data.getFileNamesInSeries(10)[2])
# Out:
# DXm.2.25.167180963455726584960672303706274696026

# %%
data.get(1000, True)
# Out:
# ...took  4.5299530029296875e-06 seconds
# '2.25.101573901059944246975171029673224356891'

# %%
print(data.getFileNamesInSeries(1000))
# Out:
# ['DXm.2.25.259623010879749137951167467366033296161', 'DXm.2.25.296046052601058320315562812327324013930', 'DXm.2.25.192048973871924935059143385674867363202', 'DXm.2.25.270571869210536492093036832694840470469']

# %%
print(data.getFileNamesInSeries(100))
# Out:
# ['DXm.2.25.271941598564795692344173788616588000312', 'DXm.2.25.107882933273802421580640187968914551649', 'DXm.2.25.142015897399972656283821072037712159619', 'DXm.2.25.251433960589794812220668926966719252912']

# %%
data.getDicomsInSeries(1000, True)
# Out:
# ...took  0.0003829002380371094 seconds
# 4

# %%
data.getTotalDicoms()
# Out:
# 821345

# %%
data.viewSeries2DImages(1000, 5, True)
# Out:
# only  4  images in series

# %%
data.getTotal2DDicoms()
# Out:
# 819329

# %%
data.viewSeries2DImages(1000, 2, True)
# Out:
# ...took  0.38352346420288086 seconds

# %%
data.viewSeries2DImages(1000, 1, True)
# Out:
# ...took  0.3504645824432373 seconds

# %%
data.getDicomsInSeries(500, True)
# Out:
# ...took  0.0002887248992919922 seconds
# 4

# %%
data.viewSeries2DImages(500, 2, True)
# Out:
# ...took  0.40240955352783203 seconds

# %%
data.viewSeries2DImages(500, 0, True)
# Out:
# ...took  0.3948092460632324 seconds

# %%
data.getDicomsInSeries(2000, True)
# Out:
# ...took  0.0001647472381591797 seconds
# 4

# %%
data.viewSeries2DImages(2000,1, True)
# Out:
# ...took  0.23864221572875977 seconds

# %%
data.viewSeries2DImages(1045,1, True)
# Out:
# ...took  0.24235868453979492 seconds

# %%
data.viewSeries2DImages(1045,2, True)
# Out:
# ...took  0.23781919479370117 seconds

# %%
data.getDicomsInSeries(1045)
# Out:
# 4

# %%
data.viewSeries2DImages(1045,6, True)
# Out:
# only  4  images in series

# %%
data.viewSeries2DImages(1045,0, True)
# Out:
# ...took  0.2375948429107666 seconds

# %%
fpath = get_testdata_file(r'../../raid/data01/deephealth/dh_dcm_ast')
fpath
# Out:
# '/home/ryan.zurrin001/miniconda3/envs/P3_2/lib/python3.9/site-packages/pydicom/data/test_files/CT_small.dcm'

# %%
fpath = get_testdata_file("CT_small.dcm")
ds = dcmread(fpath)

# %%
print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 192
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.5962.1.1.1.1.1.20040119072730.12322
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.5962.2
# (0002, 0013) Implementation Version Name         SH: 'DCTOOL100'
# (0002, 0016) Source Application Entity Title     AE: 'CLUNIE1'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20040119'
# (0008, 0013) Instance Creation Time              TM: '072731'
# ...
