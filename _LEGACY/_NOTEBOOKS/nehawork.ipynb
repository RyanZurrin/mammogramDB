# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import omama.label as O
import os
import pandas as pd
import pickle

# %%
path = '/raid/data01/deephealth/'
folder = 'dh_dh2'

# %%
data = O.Data(path, folder)

# %%
data._cal_2DLabel(executionTime=True)
# Out:
# ...took  47.35879969596863 seconds
# Total 2D dicoms 12781
# Total labels 12781
# Counter({'NonCancer': 11976, 'No Label information': 768, 'IndexCancer': 37})
# ['NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'No Label information',
#  'No Label information',
#  'No Label information',
#  'No Label information',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
# ...

# %%
data._cal_3DLabel(executionTime = True)
# Out:
# ...took  1366.4223713874817 seconds
# Total 3D dicoms 9363
# Total labels 9363
# Counter({'NonCancer': 8751, 'No Label information': 612})
# ['NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'No Label information',
#  'No Label information',
#  'No Label information',
#  'No Label information',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
#  'NonCancer',
# ...

# %%
l_df = pd.DataFrame(columns=['folder', '2D/3D', 'label', 'image laterality'])

# %%
result = data.createRecord(l_df, executionTime=True)

# %%
picklefile = open('dataObject', 'wb')
#pickle the dataframe
pickle.dump(data, picklefile)
#close file
picklefile.close()

# %%
#read the pickle file
picklefile = open('dataObject', 'rb')
#unpickle the dataframe
df_result = pickle.load(picklefile)
#close file
picklefile.close()

# %%
df_result

# %%
df_result.files_2D
# Out:
# ['/raid/data01/deephealth//dh_dh2/2.25.100200417657065059753016354291204569362/DXm.2.25.128135024517585088804036346256122061228',
#  '/raid/data01/deephealth//dh_dh2/2.25.100200417657065059753016354291204569362/DXm.2.25.138958233010157353053172884464671585590',
#  '/raid/data01/deephealth//dh_dh2/2.25.100200417657065059753016354291204569362/DXm.2.25.181259504719757329453756090216489870110',
#  '/raid/data01/deephealth//dh_dh2/2.25.100200417657065059753016354291204569362/DXm.2.25.227295396277787313759840476328917156198',
#  '/raid/data01/deephealth//dh_dh2/2.25.100200417657065059753016354291204569362/DXm.2.25.297202884850645966957310269858011965581',
#  '/raid/data01/deephealth//dh_dh2/2.25.100200417657065059753016354291204569362/DXm.2.25.60300474986300168282209063928918931739',
#  '/raid/data01/deephealth//dh_dh2/2.25.100583625697035504173473332435565025652/DXm.2.25.155109783994098590262782724252618661291',
# ...
