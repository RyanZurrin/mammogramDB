# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('../')

import omama as O
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_238202/2281576821.py in <module>
#       2 sys.path.append('../')
#       3
# ----> 4 import omama as O
#
# ~/Projects/omama/_EXPERIMENTS/../omama/__init__.py in <module>
# ----> 1 from .data import Data
#
# ~/Projects/omama/_EXPERIMENTS/../omama/data.py in <module>
#       3 import os
#       4 # reading in dicom files
# ----> 5 import pydicom as dicom
#       6 from os import listdir
#       7 from os.path import isfile, join
#
# ModuleNotFoundError: No module named 'pydicom'

# %%
twoD_data = O.Data('/raid/data01/deephealth/dh_dcm_ast/', timing=True)
# Out:
# ...took  7.8931567668914795 seconds

# %%
example_2d = twoD_data.getPixels(1000, 3, timing=True)
print(example_2d.ndim, example_2d.shape)
imshow( example_2d )
# Out:
# ...took 0.3674588203430176 seconds
# 2 (3328, 2560)

# %%
threeD_data = O.Data('/raid/data01/deephealth/dh_dh2/', timing=True)
# Out:
# ...took  0.14335322380065918 seconds

# %%
example_3d = threeD_data.getPixels(10,10, timing=True)
print(example_3d.ndim, example_3d.shape)
center_slice = example_3d[example_3d.shape[0] // 2] 
imshow( center_slice )
# Out:
# ...took 10.411185264587402 seconds
# 3 (63, 2457, 1996)
