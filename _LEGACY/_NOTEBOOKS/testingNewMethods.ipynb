# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = O.Data(r'../../../raid/data01/deephealth/dh_dh2/')
data.setDf(r'/home2/deephealth/labels/dh_dh2_labels.csv')
print(data.df)
# Out:
#                                   StudyInstanceUID CancerLaterality      Label
# 0     2.25.118657020821082351510538697641908046675             None  NonCancer
# 1      2.25.24974237302217889236471674842254400421             None  NonCancer
# 2     2.25.330047135490263461987008844163541144387             None  NonCancer
# 3     2.25.293923190844227131155437522879504958950             None  NonCancer
# 4     2.25.234810466767402426258529783173561476083             None  NonCancer
# ...                                            ...              ...        ...
# 2281  2.25.141472786006756535415434533011381261941             None  NonCancer
# 2282  2.25.208252564113591469786934896652240083625             None  NonCancer
# 2283  2.25.201583189397305656623412321188279816701             None  NonCancer
# 2284  2.25.255348679175338774948756636618422664906             None  NonCancer
# 2285   2.25.51225140535093166693209614555836119980             None  NonCancer
#
# [2286 rows x 3 columns]

# %%
data.getSeriesCount()
# Out:
# 2438

# %%
data.getDicomInfo(1000, 5)
# Out:
# ('2.25.232021486411718494156207742354173044439', 'R', (2457, 1890))

# %%
data.is2D(1000, 5)
# Out:
# True

# %%
data.is3D(1000, 5)
# Out:
# False

# %%
data.getData(1000, 5)
# Out:
# ('2.25.232021486411718494156207742354173044439', 'R', (2457, 1890))

# %%
data.is3D(1961, 1)
# Out:
# True

# %%
data.getData(1961, 1)
# Out:
# ('2.25.44634227847410345535527040388083494623', 'None', (79, 2457, 1996))
