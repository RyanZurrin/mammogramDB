# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
imgs = O.DataHelper.get2D(N=10, config_num=2)

# %%
pixel_list = []
for img in imgs:
    print(img.pixels.shape)
    pixel_list.append(img.pixels)
# Out:
# (3062, 2394)
# (2294, 1914)
# (3062, 2394)
# (3062, 2394)
# (2294, 1914)
# (3062, 2394)
# (3062, 2394)
# (2294, 1914)
# (2294, 1914)
# (2294, 1914)

# %%
from skimage.transform import resize

# %%
resized_pixels = []
for arr in pixel_list:
    resized_pixels.append(resize(arr, (64, 64)))

# %%
for img in resized_pixels:
    print(img.shape)
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)

# %%
O.DataHelper.view_grid(resized_pixels)
