# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
O.OutlierDetector.get_best_algorithm_runs("ECOD")
# Out:
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# ECOD & Histogram & 0.6250 \\
# 'ECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\nECOD & Histogram & 0.6250 \\\\\n'

# %%
table = O.OutlierDetector.get_best_algorithm_runs('CBLOF', dataset='8%', N=30)
# Out:
# CBLOF & Downsample & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Histogram & 0.6250 \\
# CBLOF & Downsample & 0.5000 \\
# CBLOF & Downsample & 0.5000 \\
# CBLOF & Downsample & 0.5000 \\
# CBLOF & SIFT & 0.5000 \\
# CBLOF & SIFT & 0.5000 \\
# CBLOF & SIFT & 0.5000 \\
# CBLOF & Downsample & 0.3750 \\
# CBLOF & Downsample & 0.3750 \\
# CBLOF & Downsample & 0.3750 \\
# CBLOF & Downsample & 0.3750 \\
# CBLOF & Downsample & 0.3750 \\
# CBLOF & Downsample & 0.3750 \\
# CBLOF & Downsample & 0.3750 \\
# CBLOF & Downsample & 0.3750 \\
# CBLOF & Downsample & 0.3750 \\

# %%
O.OutlierDetector.get_from_cache('hist_24%_97499e56cabdfb5044b9740aa82992ee')
# Out:
# {'CBLOF': 0.8333333333333334,
#  'AvgKNN': 0.8333333333333334,
#  'MedKNN': 0.8333333333333334,
#  'HBOS': 0.7916666666666666,
#  'KNN': 0.7916666666666666,
#  'OCSVM': 0.75,
#  'KDE': 0.75,
#  'Sampling': 0.75,
#  'SUOD': 0.7083333333333334,
#  'ECOD': 0.625,
#  'LOF': 0.625,
#  'COPOD': 0.625,
#  'GMM': 0.625,
#  'FB': 0.625,
#  'IForest': 0.5833333333333334,
#  'MCD': 0.5416666666666666,
#  'PCA': 0.4583333333333333,
#  'LODA': 0.4166666666666667,
#  'COF': 0.375,
#  'INNE': 0.375,
#  'DeepSVDD': 0.3333333333333333,
#  'SOS': 0.25,
#  'SOGAAL': 0.25,
#  'SOD': 0.08333333333333333,
#  'LMDD': 0.0,
#  'AnoGAN': 0.0,
#  'AE': -1,
#  'VAE': -1}

# %%
O.OutlierDetector.generate_analysis_report(output_file='testingLatex', include_hash=True)
# Out:
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{booktabs}
# \begin{document}
# \begin{table}[]
# \centering
# \begin{tabular}{c|c|c|c}
# \toprule
# Algorithm & Feature & Accuracy & hash \\
# \midrule
# DeepSVDD & Histogram & 0.7500 & hist_8%_291695b60cc6fd600d037a72fed16684 \\
# OCSVM & Histogram & 0.6250 & hist_8%_de38ada3ffca4f429a28828ed2378b4b \\
# CBLOF & Downsample & 0.6250 & downsample_8%_6f2b47df02fbfb2882d1fcec58f72bd7 \\
# SOS & SIFT & 0.6250 & sift_8%_6dea08df81d7224f7bef281cf8513f45 \\
# KDE & Histogram & 0.6250 & hist_8%_de38ada3ffca4f429a28828ed2378b4b \\
# Sampling & Downsample & 0.6250 & downsample_8%_490bd62a21c0cbf7fa03f2566a19ac18 \\
# MCD & Histogram & 0.6250 & hist_8%_69ed6a34c3e8ee502c6518e2e1bb86b7 \\
# COF & Histogram & 0.6250 & hist_8%_265e66024fc6a8dbb6ca511fd3df39ec \\
# HBOS & Histogram & 0.6250 & hist_8%_265e66024fc6a8dbb6ca511fd3df39ec \\
# KNN & Histogram & 0.6250 & hist_8%_265e66024fc6a8dbb6ca511fd3df39ec \\
# ...

# %%
O.OutlierDetector.generate_analysis_report(output_file='testingLatex', include_hash=True, num_best=2)
# Out:
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \usepackage{booktabs}
# \begin{document}
# \begin{table}[]
# \centering
# \begin{tabular}{c|c|c|c}
# \toprule
# Algorithm & Feature & Accuracy & hash \\
# \midrule
# DeepSVDD & Histogram & 0.7500 & hist_8%_291695b60cc6fd600d037a72fed16684 \\
# DeepSVDD & Histogram & 0.7500 & hist_8%_482adaafa532844b0af7b9e0f6de0992 \\
# CBLOF & Downsample & 0.6250 & downsample_8%_6f2b47df02fbfb2882d1fcec58f72bd7 \\
# CBLOF & Histogram & 0.6250 & hist_8%_265e66024fc6a8dbb6ca511fd3df39ec \\
# SOS & SIFT & 0.6250 & sift_8%_6dea08df81d7224f7bef281cf8513f45 \\
# SOS & SIFT & 0.6250 & sift_8%_fe700cd500e09abd1e4ec68342e09bbe \\
# Sampling & Downsample & 0.6250 & downsample_8%_9c342e61b39b4ade57cb554ea5597876 \\
# Sampling & Histogram & 0.6250 & hist_8%_291695b60cc6fd600d037a72fed16684 \\
# MCD & Histogram & 0.6250 & hist_8%_69ed6a34c3e8ee502c6518e2e1bb86b7 \\
# MCD & Histogram & 0.6250 & hist_8%_bd59e68f194f0dcda6870505050509d0 \\
# ...

# %%
O.OutlierDetector.get_configuration('sift_13%_baa39e488717834d980b534022172577')
# Out:
# {'kwargs': {'contamination': 0.13,
#   'metric': 'gaussian',
#   'metric_params': None,
#   'verbose': False,
#   'n_jobs': 2,
#   'norm_type': 'minmax',
#   'tol': 0.3,
#   'n_bins': 2,
#   'alpha': 0.8,
#   'beta': 6,
#   'n_neighbors': 10,
#   'n_clusters': 2,
#   'base_estimators': ['LOF',
#    'INNE',
#    'CBLOF',
#    'HBOS',
#    'FB',
#    'AvgKNN',
#    'Sampling'],
#   'cluster_estimator': 'KMeans',
#   'n_estimators': 100,
#   'subset_size': 0.5,
#   'combination': 'maximum',
#   'leaf_size': 30,
#   'p': 2,
#   'novelty': True,
#   'kernel': 'rbf',
#   'degree': 3,
#   'gamma': 0.1,
#   'coef0': 1,
#   'nu': 0.5,
#   'shrinking': True,
#   'cache_size': 200,
#   'max_iter': -1,
#   'max_samples': 0.5,
#   'bootstrap': False,
#   'behaviour': 'new',
#   'random_state': None,
#   'store_precision': False,
#   'assume_centered': False,
#   'support_fraction': None,
#   'bandwidth': 2.0,
#   'radius': 1.0}}
