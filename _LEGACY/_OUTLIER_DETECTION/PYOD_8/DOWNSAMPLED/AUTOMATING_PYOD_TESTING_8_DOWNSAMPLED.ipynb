# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../../../..')
import omama as O

# %%
imgs = O.DataHelper.get2D(N = 100, config_num=5, randomize=True, timing=True)
features = O.Features.get_features(imgs, feature_type="downsample", norm_type="minmax")
# Out:
# get2D                    ...took    42.413398 seconds

# %%
agruments = {"contamination": .08, "verbose": True, "n_jobs":1}

# %%
OLD = O.OutlierDetector(run_id='DownSampled', imgs=imgs, features=features, number_bad=8, verbose=True, exclude=['MCD', 'GMM'], timing=True, kwargs=agruments)
# Out:
# Running 2 ECOD...
# In ECOD algorithm
# ECOD accuracy: 0.25
# Running 2 LOF...
# In LOF algorithm
# LOF accuracy: 0.25
# Running 2 OCSVM...
# In OCSVM algorithm
# [LibSVM]*
# optimization finished, #iter = 50
# obj = 12.500000, rho = 0.500000
# nSV = 100, nBSV = 0
# OCSVM accuracy: 0.0
# Running 2 IForest...
# In IForest algorithm
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.4s finished
# IForest accuracy: 0.25
# Running 2 CBLOF...
# In CBLOF algorithm
# CBLOF accuracy: 0.375
# Running 2 COPOD...
# In COPOD algorithm
# COPOD accuracy: 0.25
# Running 2 SOS...
# In SOS algorithm
# contamination:  0.1
# SOS accuracy: 0.25
# Running 2 KDE...
# In KDE algorithm
# KDE accuracy: 0.0
# Running 2 Sampling...
# In Sampling algorithm
# Sampling accuracy: 0.5
# GMM accuracy: None
# Running 2 PCA...
# In PCA algorithm
# PCA accuracy: 0.0
# MCD accuracy: None
# Running 2 LMDD...
# In LMDD algorithm
# ...

# %%
OLD.results

# %%
O.OutlierDetector.show_records()
# Out:
# {
#     "downsample_13%_0c4336260c734ae105e55c657faa2f17": {
#         "CBLOF": 0.6153846153846154,
#         "KNN": 0.6153846153846154,
#         "LOF": 0.5384615384615384,
#         "INNE": 0.5384615384615384,
#         "FB": 0.5384615384615384,
#         "COF": 0.46153846153846156,
#         "AvgKNN": 0.46153846153846156,
#         "MedKNN": 0.46153846153846156,
#         "SOD": 0.46153846153846156,
#         "Sampling": 0.38461538461538464,
#         "LODA": 0.3076923076923077,
#         "ECOD": 0.15384615384615385,
#         "IForest": 0.15384615384615385,
#         "COPOD": 0.15384615384615385,
#         "LMDD": 0.15384615384615385,
#         "SUOD": 0.15384615384615385,
#         "DeepSVDD": 0.15384615384615385,
#         "OCSVM": 0.07692307692307693,
#         "SOS": 0.07692307692307693,
#         "SOGAAL": 0.07692307692307693,
#         "AnoGAN": 0.07692307692307693,
#         "KDE": 0.0,
#         "PCA": 0.0,
#         "HBOS": 0.0,
#         "AE": 0.0,
#         "VAE": -1
# ...
