# %% [markdown]
# # MO-GAAL - Multi-Objective Generative Adversarial Active Learning
# ### MO_GAAL directly generates informative potential outliers to assist the classifier in describing a boundary that can separate outliers from normal data effectively. Moreover, to prevent the generator from falling into the mode collapsing problem, the network structure of SO-GAAL is expanded from a single generator (SO-GAAL) to multiple generators with different objectives (MO-GAAL) to generate a reasonable reference distribution for the whole dataset.
# Source: https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.mo_gaal

# %% [markdown]
# ### Arguments that work with MO-GAAL algorithm:
# 1. stop_epochs
# 2. lr_d
# 3. lr_g
# 4. decay
# 5. momentum
# 6. contamination

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../../../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imgs = O.DataHelper.get2D(N = 100, config_num=5, randomize=True, timing=True)
downsampled_imgs = O.Normalize.downsample(imgs, output_shape=(64, 64), flatten=True, timing=True)
# Out:
# get2D                    ...took    40.946741 seconds
# image downsampling       ...took     1.053275 seconds
# image downsampling       ...took     2.098766 seconds
# image downsampling       ...took     3.499460 seconds
# image downsampling       ...took     3.958499 seconds
# image downsampling       ...took     5.001947 seconds
# image downsampling       ...took     6.045725 seconds
# image downsampling       ...took     6.503809 seconds
# image downsampling       ...took     6.961562 seconds
# image downsampling       ...took     7.418972 seconds
# image downsampling       ...took     8.464030 seconds
# image downsampling       ...took     8.922045 seconds
# image downsampling       ...took     9.379877 seconds
# image downsampling       ...took    12.125907 seconds
# image downsampling       ...took    13.169330 seconds
# image downsampling       ...took    15.912988 seconds
# image downsampling       ...took    17.184040 seconds
# image downsampling       ...took    18.230573 seconds
# image downsampling       ...took    18.687443 seconds
# image downsampling       ...took    19.144420 seconds
# image downsampling       ...took    21.887931 seconds
# image downsampling       ...took    22.345904 seconds
# image downsampling       ...took    23.388310 seconds
# image downsampling       ...took    23.845785 seconds
# image downsampling       ...took    24.303634 seconds
# image downsampling       ...took    24.760887 seconds
# image downsampling       ...took    25.218543 seconds
# image downsampling       ...took    26.256563 seconds
# image downsampling       ...took    26.715914 seconds
# image downsampling       ...took    27.174165 seconds
# image downsampling       ...took    27.631024 seconds
# image downsampling       ...took    29.031259 seconds
# image downsampling       ...took    30.072906 seconds
# image downsampling       ...took    31.112465 seconds
# image downsampling       ...took    31.569834 seconds
# image downsampling       ...took    32.608677 seconds
# image downsampling       ...took    33.647466 seconds
# image downsampling       ...took    34.105359 seconds
# image downsampling       ...took    35.147973 seconds
# image downsampling       ...took    37.899093 seconds
# image downsampling       ...took    38.357039 seconds
# image downsampling       ...took    39.400783 seconds
# image downsampling       ...took    39.857639 seconds
# image downsampling       ...took    40.313758 seconds
# image downsampling       ...took    41.353397 seconds
# image downsampling       ...took    41.810589 seconds
# image downsampling       ...took    42.851128 seconds
# image downsampling       ...took    43.307961 seconds
# image downsampling       ...took    43.765213 seconds
# image downsampling       ...took    44.803030 seconds
# image downsampling       ...took    45.260780 seconds
# image downsampling       ...took    46.300691 seconds
# image downsampling       ...took    47.339800 seconds
# image downsampling       ...took    48.382057 seconds
# image downsampling       ...took    49.430738 seconds
# image downsampling       ...took    49.887142 seconds
# image downsampling       ...took    50.927663 seconds
# image downsampling       ...took    52.327709 seconds
# image downsampling       ...took    52.783913 seconds
# image downsampling       ...took    53.825074 seconds
# image downsampling       ...took    54.865444 seconds
# image downsampling       ...took    57.716046 seconds
# image downsampling       ...took    58.881740 seconds
# image downsampling       ...took    59.339384 seconds
# image downsampling       ...took    59.796834 seconds
# image downsampling       ...took    60.837507 seconds
# image downsampling       ...took    61.875899 seconds
# image downsampling       ...took    62.916089 seconds
# image downsampling       ...took    63.955006 seconds
# image downsampling       ...took    64.412310 seconds
# image downsampling       ...took    64.869886 seconds
# image downsampling       ...took    65.326856 seconds
# image downsampling       ...took    65.784982 seconds
# image downsampling       ...took    66.823059 seconds
# image downsampling       ...took    67.865090 seconds
# image downsampling       ...took    68.905900 seconds
# image downsampling       ...took    69.363442 seconds
# image downsampling       ...took    70.402359 seconds
# image downsampling       ...took    70.859210 seconds
# image downsampling       ...took    73.602609 seconds
# image downsampling       ...took    74.058964 seconds
# image downsampling       ...took    74.515978 seconds
# image downsampling       ...took    74.979163 seconds
# image downsampling       ...took    77.728825 seconds
# image downsampling       ...took    78.190099 seconds
# image downsampling       ...took    78.647427 seconds
# image downsampling       ...took    79.695632 seconds
# image downsampling       ...took    80.733937 seconds
# image downsampling       ...took    81.191575 seconds
# image downsampling       ...took    82.228548 seconds
# image downsampling       ...took    83.268162 seconds
# image downsampling       ...took    84.307795 seconds
# image downsampling       ...took    85.347305 seconds
# image downsampling       ...took    86.384731 seconds
# image downsampling       ...took    87.422351 seconds
# image downsampling       ...took    87.886723 seconds
# image downsampling       ...took    88.343019 seconds
# image downsampling       ...took    89.382401 seconds
# image downsampling       ...took    89.840092 seconds
# image downsampling       ...took    91.242219 seconds
# image downsampling       ...took    92.284307 seconds
# downsample               ...took    92.285562 seconds

# %%
train_scoresX, train_labelsX = O.OutlierDetector.detect_outliers(downsampled_imgs, pyod_algorithm='MOGAAL')
O.Features.view_image_and_features(imgs, ['downsample'], train_scores=[train_scoresX])
# Out:
# /home/ryan.zurrin001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 2022-08-25 19:24:45.094989: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 64.00MiB (rounded to 67108864)requested by op MatrixDiagV3
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-08-25 19:24:45.095303: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2022-08-25 19:24:45.095370: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 46, Chunks in use: 46. 11.5KiB allocated for chunks. 11.5KiB in use in bin. 480B client-requested in use in bin.
# 2022-08-25 19:24:45.095549: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.095735: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-08-25 19:24:45.095921: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.095969: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096154: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096205: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16384): 	Total Chunks: 22, Chunks in use: 22. 377.5KiB allocated for chunks. 377.5KiB in use in bin. 352.0KiB client-requested in use in bin.
# 2022-08-25 19:24:45.096256: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096332: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (65536): 	Total Chunks: 1, Chunks in use: 0. 125.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096441: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (131072): 	Total Chunks: 5, Chunks in use: 4. 800.0KiB allocated for chunks. 640.0KiB in use in bin. 640.0KiB client-requested in use in bin.
# 2022-08-25 19:24:45.096492: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (262144): 	Total Chunks: 1, Chunks in use: 0. 302.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096598: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096722: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096784: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096832: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096897: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096946: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.096996: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (33554432): 	Total Chunks: 1, Chunks in use: 0. 62.89MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.097045: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (67108864): 	Total Chunks: 5, Chunks in use: 5. 354.72MiB allocated for chunks. 354.72MiB in use in bin. 320.00MiB client-requested in use in bin.
# 2022-08-25 19:24:45.097093: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.097140: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-25 19:24:45.097190: I tensorflow/core/common_runtime/bfc_allocator.cc:1014] Bin for 64.00MiB was 64.00MiB, Chunk State:
# 2022-08-25 19:24:45.097239: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 439549952
# 2022-08-25 19:24:45.097291: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000000 of size 1280 by op ScratchBuffer action_count 292700990556996111 step 0 next 1
# 2022-08-25 19:24:45.097339: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000500 of size 256 by op AssignVariableOp action_count 292700990556996112 step 0 next 2
# 2022-08-25 19:24:45.097386: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000600 of size 256 by op Fill action_count 292700990556996120 step 0 next 8
# 2022-08-25 19:24:45.097434: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000700 of size 256 by op Fill action_count 292700990556996121 step 0 next 9
# 2022-08-25 19:24:45.097480: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000800 of size 256 by op Fill action_count 292700990556996128 step 0 next 10
# 2022-08-25 19:24:45.097526: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000900 of size 256 by op Mul action_count 292700990556996123 step 0 next 11
# 2022-08-25 19:24:45.097573: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000a00 of size 256 by op Fill action_count 292700990556996129 step 0 next 12
# 2022-08-25 19:24:45.097620: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000b00 of size 256 by op Add action_count 292700990556996125 step 0 next 13
# 2022-08-25 19:24:45.097668: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000c00 of size 256 by op Fill action_count 292700990556996130 step 0 next 14
# 2022-08-25 19:24:45.097714: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000d00 of size 256 by op AssignVariableOp action_count 292700990556996131 step 0 next 15
# 2022-08-25 19:24:45.097759: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000e00 of size 256 by op Fill action_count 292700990556996132 step 0 next 16
# 2022-08-25 19:24:45.097806: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c000f00 of size 256 by op Mul action_count 292700990556996136 step 0 next 17
# 2022-08-25 19:24:45.097851: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c001000 of size 16384 by op Fill action_count 292700990556996139 step 0 next 20
# 2022-08-25 19:24:45.097897: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c005000 of size 16384 by op Fill action_count 292700990556996145 step 0 next 22
# 2022-08-25 19:24:45.097942: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1
I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c0f9300 of size 256 by op Fill action_count 292700990556996291 step 0 next 80
# 2022-08-25 19:24:45.101562: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c0f9400 of size 16384 by op Fill action_count 292700990556996292 step 0 next 81
# 2022-08-25 19:24:45.101610: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f7b1c0fd400 of size 128512 by op UNUSED action_count 0 step 0 next 66
# 2022-08-25 19:24:45.101655: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c11ca00 of size 163840 by op Add action_count 292700990556996265 step 0 next 67
# 2022-08-25 19:24:45.101700: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f7b1c144a00 of size 163840 by op UNUSED action_count 292700990556996282 step 0 next 74
# 2022-08-25 19:24:45.101745: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b1c16ca00 of size 163840 by op Add action_count 292700990556996280 step 0 next 75
# 2022-08-25 19:24:45.101790: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f7b1c194a00 of size 65945088 by op UNUSED action_count 0 step 0 next 18
# 2022-08-25 19:24:45.101836: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b20078800 of size 67108864 by op Mul action_count 292700990556996137 step 0 next 19
# 2022-08-25 19:24:45.101881: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b24078800 of size 67108864 by op Mul action_count 292700990556996143 step 0 next 21
# 2022-08-25 19:24:45.101926: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b28078800 of size 67108864 by op Mul action_count 292700990556996151 step 0 next 25
# 2022-08-25 19:24:45.101971: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b2c078800 of size 67108864 by op Mul action_count 292700990556996157 step 0 next 27
# 2022-08-25 19:24:45.102016: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b30078800 of size 103512064 by op Mul action_count 292700990556996165 step 0 next 18446744073709551615
# 2022-08-25 19:24:45.102060: I tensorflow/core/common_runtime/bfc_allocator.cc:1051]      Summary of in-use Chunks by size:
# 2022-08-25 19:24:45.102108: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 46 Chunks of size 256 totalling 11.5KiB
# 2022-08-25 19:24:45.102160: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-08-25 19:24:45.102207: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 20 Chunks of size 16384 totalling 320.0KiB
# 2022-08-25 19:24:45.102254: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 28160 totalling 27.5KiB
# 2022-08-25 19:24:45.102303: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 30720 totalling 30.0KiB
# 2022-08-25 19:24:45.102350: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 4 Chunks of size 163840 totalling 640.0KiB
# 2022-08-25 19:24:45.102396: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 4 Chunks of size 67108864 totalling 256.00MiB
# 2022-08-25 19:24:45.102443: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 103512064 totalling 98.72MiB
# 2022-08-25 19:24:45.102490: I tensorflow/core/common_runtime/bfc_allocator.cc:1058] Sum Total of in-use chunks: 355.72MiB
# 2022-08-25 19:24:45.102535: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] total_region_allocated_bytes_: 439549952 memory_limit_: 439549952 available bytes: 0 curr_region_allocation_bytes_: 879099904
# 2022-08-25 19:24:45.102584: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Stats:
# Limit:                       439549952
# InUse:                       373002496
# MaxInUse:                    439549952
# NumAllocs:                         130
# MaxAllocSize:                103512064
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-08-25 19:24:45.102638: W tensorflow/core/common_runtime/bfc_allocator.cc:467] *______________*****************************************************************************xxxxxxxx
# 2022-08-25 19:24:45.102713: W tensorflow/core/framework/op_kernel.cc:1767] OP_REQUIRES failed at matrix_diag_op.cc:266 : Resource exhausted: OOM when allocating tensor with shape[4096,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_1168905/2618173964.py in <module>
# ----> 1 train_scoresX, train_labelsX = O.OutlierDetector.detect_outliers(downsampled_imgs, pyod_algorithm='MOGAAL')
#       2 O.Features.view_image_and_features(imgs, ['downsample'], train_scores=[train_scoresX])
#
# ~/Projects/omama/_EXPERIMENTS/OUTLIER_DETECTION/PYOD_5/DOWNSAMPLED/../../../../omama/outlier_detection/outlier_detector.py in detect_outliers(data_x, data_y, pyod_algorithm, activation_hidden, algorithm, alpha, approx_clf, approx_clf_list, approx_flag_global, approx_ng_clf_list, assume_centered, bandwidth, base_estimator, base_estimators, batch_size, behaviour, beta, bootstrap, bootstrap_features, bps_flag, c, cache_size, capacity, check_detector, check_estimator, clustering_estimator, coef0, combination, contamination, copy, cost_forecast_loc_fit, cost_forecast_loc_pred, covariance_type, D_layers, decay, decoder_neurons, degree, dis_measure, dropout_rate, encoder_neurons, epochs, epochs_query, eps, estimator_params, G_layers, gamma, hidden_activation, hidden_neurons, index_D_layer_for_recon_error, init_params, iterated_power, jl_method, kernel, l2_regularizer, latent_dim, latent_dim_G, leaf_size, learning_rate, learning_rate_query, loss, lr_d, lr_g, max_features, max_iter, max_samples, means_init, method, metric, metric_params, momentum, n_bins, n_clusters, n_components, n_estimators, n_init, n_iter, n_jobs, n_neighbors, n_random_cuts, n_selected_components, novelty, nu, optimizer, output_activation, p, parallel_execution, perplexity, precisions_init, preprocessing, radius, random_state, ref_set, reg_covar, rp_clf_list, rp_ng_clf_list, rp_flag_global, rule_of_thumb, shrinking, standardization, stop_epochs, store_precision, subset_size, support_fraction, svd_solver, target_dim_frac, tol, use_ae, use_weights, validation_size, verbose, warm_start, weighted, weights_init, whiten, whitening)
#     931
#     932         if data_y is None:
# --> 933             clf.fit(data_x)
#     934         else:
#     935             clf.fit(data_x, data_y)
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/pyod/models/mo_gaal.py in fit(self, X, y)
#     132         # Create k combine models
#     133         for i in range(self.k):
# --> 134             names['sub_generator' + str(i)] = create_generator(latent_size)
#     135             latent = Input(shape=(latent_size,))
#     136             names['fake' + str(i)] = names['sub_generator' + str(i)](latent)
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/pyod/models/gaal_base.py in create_generator(latent_size)
#      73
#      74     gen = Sequential()
# ---> 75     gen.add(Dense(latent_size, input_dim=latent_size, activation='relu',
#      76                   kernel_initializer=keras.initializers.Identity(
#      77                       gain=1.0)))
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     520     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521     try:
# --> 522       result = method(self, *args, **kwargs)
#     523     finally:
#     524       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/sequential.py in add(self, layer)
#     211           # and create the node connecting the current layer
#     212           # to the input layer we just created.
# --> 213           layer(x)
#     214           set_inputs = True
#     215
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     967     # >> model = tf.keras.Model(inputs, outputs)
#     968     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 969       return self._functional_construction_call(inputs, args, kwargs,
#     970                                                 input_list)
#     971
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1105         layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1106       # Check input assumptions set after layer building, e.g. input shape.
# -> 1107       outputs = self._keras_tensor_symbolic_call(
#    1108           inputs, input_masks, args, kwargs)
#    1109
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     838       return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     839     else:
# --> 840       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     841
#     842   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     876           # overridden).
#     877           # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 878           self._maybe_build(inputs)
#     879           inputs = self._maybe_cast_inputs(inputs)
#     880           outputs = call_fn(inputs, *args, **kwargs)
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2623         # operations.
#    2624         with tf_utils.maybe_init_scope(self):
# -> 2625           self.build(input_shapes)  # pylint:disable=not-callable
#    2626       # We must set also ensure that the layer is marked as built, and the build
#    2627       # shape is stored since user defined build functions may not be calling
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/layers/core.py in build(self, input_shape)
#    1189                        'should be defined. Found `None`.')
#    1190     self.input_spec = InputSpec(min_ndim=2, axes={-1: last_dim})
# -> 1191     self.kernel = self.add_weight(
#    1192         'kernel',
#    1193         shape=[last_dim, self.units],
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     637         caching_device = None
#     638
# --> 639     variable = self._add_variable_with_custom_getter(
#     640         name=name,
#     641         shape=shape,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     808         # "best effort" to set the initializer with the highest restore UID.
#     809         initializer = checkpoint_initializer
# --> 810     new_variable = getter(
#     811         name=name,
#     812         shape=shape,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     125   # can remove the V1.
#     126   variable_shape = tensor_shape.TensorShape(shape)
# --> 127   return tf_variables.VariableV1(
#     128       initial_value=init_val,
#     129       name=name,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     258   def __call__(cls, *args, **kwargs):
#     259     if cls is VariableV1:
# --> 260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
#     262       return cls._variable_v2_call(*args, **kwargs)
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     204     if aggregation is None:
#     205       aggregation = VariableAggregation.NONE
# --> 206     return previous_getter(
#     207         initial_value=initial_value,
#     208         trainable=trainable,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/variables.py in <lambda>(**kwargs)
#     197                         shape=None):
#     198     """Call on Variable class. Useful to force the signature."""
# --> 199     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     200     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     201       previous_getter = _make_getter(getter, previous_getter)
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2610   if use_resource:
#    2611     distribute_strategy = kwargs.get("distribute_strategy", None)
# -> 2612     return resource_variable_ops.ResourceVariable(
#    2613         initial_value=initial_value,
#    2614         trainable=trainable,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1582       self._init_from_proto(variable_def, import_scope=import_scope)
#    1583     else:
# -> 1584       self._init_from_args(
#    1585           initial_value=initial_value,
#    1586           trainable=trainable,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1720           with ops.name_scope("Initializer"), device_context_manager(None):
#    1721             if init_from_fn:
# -> 1722               initial_value = initial_value()
#    1723             if isinstance(initial_value, trackable.CheckpointInitialValue):
#    1724               self._maybe_initialize_trackable()
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/initializers/initializers_v2.py in __call__(self, shape, dtype, **kwargs)
#     659       raise ValueError(
#     660           'Identity matrix initializer can only be used for 2D matrices.')
# --> 661     initializer = linalg_ops.eye(*shape, dtype=dtype)
#     662     return self.gain * initializer
#     663
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/linalg_ops.py in eye(num_rows, num_columns, batch_shape, dtype, name)
#     235     A `Tensor` of shape `batch_shape + [num_rows, num_columns]`
#     236   """
# --> 237   return linalg_ops_impl.eye(num_rows,
#     238                              num_columns=num_columns,
#     239                              batch_shape=batch_shape,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/linalg_ops_impl.py in eye(num_rows, num_columns, batch_shape, dtype, name)
#      75     diag_ones = array_ops.ones(diag_shape, dtype=dtype)
#      76     if is_square:
# ---> 77       return array_ops.matrix_diag(diag_ones)
#      78     else:
#      79       zero_matrix = array_ops.zeros(shape, dtype=dtype)
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py in matrix_diag(diagonal, name, k, num_rows, num_cols, padding_value, align)
#    2557     padding_value = bool(padding_value)
#    2558
# -> 2559   return gen_array_ops.matrix_diag_v3(
#    2560       diagonal=diagonal,
#    2561       k=k,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py in matrix_diag_v3(diagonal, k, num_rows, num_cols, padding_value, align, name)
#    5524       return _result
#    5525     except _core._NotOkStatusException as e:
# -> 5526       _ops.raise_from_not_ok_status(e, name)
#    5527     except _core._FallbackException:
#    5528       pass
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6895   message = e.message + (" name: " + name if name is not None else "")
#    6896   # pylint: disable=protected-access
# -> 6897   six.raise_from(core._status_to_exception(e.code, message), None)
#    6898   # pylint: enable=protected-access
#    6899
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[4096,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:MatrixDiagV3] name: diag
