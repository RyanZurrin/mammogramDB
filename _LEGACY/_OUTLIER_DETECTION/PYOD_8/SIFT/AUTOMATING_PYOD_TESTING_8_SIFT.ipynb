# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../../../..')
import omama as O

# %%
imgs = O.DataHelper.get2D(N = 10, config_num=5, randomize=True, timing=True)
features = O.Features.get_features(imgs, feature_type="sift", norm_type="minmax")
# Out:
# get2D                    ...took     4.566716 seconds
# minmax: not list
# minmax: not list
# kp:  25 28
# kp:  63 8
# kp:  76 34
# kp:  92 70
# kp:  95 95
# kp:  100 8
# kp:  116 102
# kp:  118 84
# kp:  118 158
# kp:  121 222
# kp:  121 222
# kp:  130 8
# kp:  130 160
# kp:  138 153
# kp:  141 101
# kp:  167 7
# kp:  215 8
# kp:  234 8
# kp:  257 323
# kp:  267 7
# kp:  283 8
# kp:  342 459
# kp:  368 407
# kp:  378 7
# kp:  416 7
# kp:  436 370
# kp:  487 7
# kp:  497 505
# kp:  530 674
# kp:  531 34
# kp:  542 7
# kp:  559 82
# kp:  575 278
# kp:  583 584
# kp:  599 694
# kp:  605 554
# kp:  606 696
# kp:  657 949
# kp:  705 22
# kp:  729 51
# kp:  730 1037
# kp:  741 6
# kp:  762 121
# kp:  762 412
# kp:  769 849
# kp:  778 549
# kp:  786 271
# kp:  828 674
# kp:  838 1534
# kp:  844 747
# kp:  846 439
# kp:  849 299
# kp:  850 1584
# kp:  854 1571
# kp:  872 828
# kp:  872 1122
# kp:  875 1504
# kp:  889 753
# kp:  890 1137
# kp:  903 1523
# kp:  908 1638
# kp:  910 585
# ...

# %%
agruments = {"contamination": .08, "verbose": False}

# %%
OLD = O.OutlierDetector(run_id='sift', imgs=imgs, features=features, number_bad=8, verbose=False, timing=True, kwargs=agruments)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# run_all_algorithms       ...took    27.681532 seconds
# OD __init__              ...took    27.682050 seconds

# %%
OLD.results
# Out:
# ({'ECOD': 0.0,
#   'LOF': 0.0,
#   'OCSVM': 0.0,
#   'IForest': 0.0,
#   'CBLOF': 0.0,
#   'COPOD': 0.0,
#   'SOS': 0.0,
#   'KDE': 0.0,
#   'GMM': 0.0,
#   'PCA': 0.0,
#   'MCD': 0.0,
#   'LMDD': 0.0,
#   'COF': 0.0,
#   'HBOS': 0.0,
#   'KNN': 0.0,
#   'AvgKNN': 0.0,
#   'MedKNN': 0.0,
#   'INNE': 0.0,
#   'FB': 0.0,
#   'LODA': 0.0,
#   'SUOD': 0.0,
#   'AE': 0.0,
#   'VAE': 0.0,
#   'SOGAAL': 0.0,
#   'DeepSVDD': 0.0,
#   'AnoGAN': 0.0,
#   'Sampling': -1,
#   'SOD': -1,
#   'MOGAAL': -1},
#  {'Sampling': ValueError('subset_size=20 must be between 0 and n_samples=10.'),
#   'SOD': ValueError('Expected n_neighbors <= n_samples,  but n_samples = 10, n_neighbors = 21'),
#   'MOGAAL': AttributeError("'int' object has no attribute 'assign'")})

# %%
O.OutlierDetector.show_records()
