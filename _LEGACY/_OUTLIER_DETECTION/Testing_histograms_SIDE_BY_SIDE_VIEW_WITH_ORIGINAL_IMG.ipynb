# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O
import numpy as np
import mahotas as mh
import matplotlib.pyplot as plt

# %%
imgs = O.DataHelper.get2D(N=50, config_num=2)

# %%
for img in imgs:
    O.DataHelper.show_image_and_histogram(img)
