# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imgs = O.DataHelper.get2D(N=100, config_num=2, timing=True)
# Out:
# get2D                    ...took    44.737345 seconds

# %%
O.DataHelper.view_grid(imgs)

# %%
out_file = open("outfile.txt", "w")
for img in imgs:
    out_file.write(img.filePath + "\n")
out_file.close()

# %%
index = 54
O.DataHelper.view(imgs[index])

# %%
imgs[index].label
# Out:
# 'IndexCancer'

# %%
imgs[index].filePath
# Out:
# '/raid/data01/deephealth/dh_dcm_ast/2.25.100106310335705418077395932274653810425/DXm.2.25.41840648022000818954245230828971871497'

# %%
# taking 20 random samples of 100, and counting the number of images with wire frames to get average % within dataset
# 6, 4, 3, 3, 5, 3, 4, 3, 4, 2, 0, 4, 5, 5, 4, 5, 3, 4, 5, 4

# %%
vals = [6, 4, 3, 3, 5, 3, 4, 3, 4, 2, 0, 4, 5, 5, 4, 5, 3, 4, 5, 4]

# %%
sum(vals) / 20
# Out:
# 3.8

# %%
# About 4% of our 2D data set has images with wire frames in them

# %%
# Building the sample data set caches that contain 5% images with frames
ol = O.OmamaLoader(config_num=5)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.000588 seconds
# load_images              ...took     0.000169 seconds
# csv_to_map               ...took     0.254750 seconds
# load_labels              ...took     0.105205 seconds
# save_pickle              ...took     0.000283 seconds
# generate_counts          ...took     0.000133 seconds
# generate_stats           ...took     0.000133 seconds
# total _init              ...took     0.371007 seconds
# total __init__           ...took     0.371073 seconds

# %%
# Building the sample data set caches that contain 10% images with frames
ol = O.OmamaLoader(config_num=6)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.000596 seconds
# load_images              ...took     0.000129 seconds
# csv_to_map               ...took     0.234251 seconds
# load_labels              ...took     0.104090 seconds
# save_pickle              ...took     0.000278 seconds
# generate_counts          ...took     0.000130 seconds
# generate_stats           ...took     0.000131 seconds
# total _init              ...took     0.349927 seconds
# total __init__           ...took     0.350000 seconds

# %%
# Building the sample data set caches that contain 10% images with frames
ol = O.OmamaLoader(config_num=7)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.000402 seconds
# load_images              ...took     0.000065 seconds
# csv_to_map               ...took     0.219895 seconds
# load_labels              ...took     0.105214 seconds
# save_pickle              ...took     0.000283 seconds
# generate_counts          ...took     0.000135 seconds
# generate_stats           ...took     0.000131 seconds
# total _init              ...took     0.336493 seconds
# total __init__           ...took     0.336560 seconds

# %%
print(data)
# Out:
# namespace(dh_dh2=namespace(total=0, 3D=0, 2D=0),
#           dh_dh0new=namespace(total=0, 3D=0, 2D=0),
#           dh_dcm_ast=namespace(total=100, 3D=0, 2D=100),
#           total_all_dicoms=100,
#           total_2d_all=100,
#           total_3d_all=0,
#           total_2d_cancer=5,
#           total_2d_preindex=0,
#           total_2d_noncancer=95,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=5,
#           total_preindex=0,
#           total_noncancer=95,
#           total_no_label=0)
# None

# %%
imgs = O.DataHelper.get2D(N=100, config_num=7, randomize=True, timing=True)
# Out:
# get2D                    ...took    39.563918 seconds

# %%
O.DataHelper.view_grid(imgs)
