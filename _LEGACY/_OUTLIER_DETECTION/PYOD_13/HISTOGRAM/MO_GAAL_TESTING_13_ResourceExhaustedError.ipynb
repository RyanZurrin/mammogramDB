# %% [markdown]
# # MO-GAAL - Multi-Objective Generative Adversarial Active Learning
# ### MO_GAAL directly generates informative potential outliers to assist the classifier in describing a boundary that can separate outliers from normal data effectively. Moreover, to prevent the generator from falling into the mode collapsing problem, the network structure of SO-GAAL is expanded from a single generator (SO-GAAL) to multiple generators with different objectives (MO-GAAL) to generate a reasonable reference distribution for the whole dataset.
# Source: https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.mo_gaal

# %% [markdown]
# ### Arguments that work with MO-GAAL algorithm:
# 1. stop_epochs
# 2. lr_d
# 3. lr_g
# 4. decay
# 5. momentum
# 6. contamination

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../../../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imgs = O.DataHelper.get2D(N = 100, config_num=6, randomize=True, timing=True)
downsampled_imgs = O.Normalize.downsample(imgs, output_shape=(64, 64), flatten=True, timing=True)
# Out:
# get2D                    ...took   250.115902 seconds
# image downsampling       ...took     7.952829 seconds
# image downsampling       ...took    10.802903 seconds
# image downsampling       ...took    13.639123 seconds
# image downsampling       ...took    16.498880 seconds
# image downsampling       ...took    24.952059 seconds
# image downsampling       ...took    27.806757 seconds
# image downsampling       ...took    30.661370 seconds
# image downsampling       ...took    47.367457 seconds
# image downsampling       ...took    50.169176 seconds
# image downsampling       ...took    56.537164 seconds
# image downsampling       ...took    63.108120 seconds
# image downsampling       ...took    65.924510 seconds
# image downsampling       ...took    68.799059 seconds
# image downsampling       ...took    75.148633 seconds
# image downsampling       ...took    91.881924 seconds
# image downsampling       ...took    98.285358 seconds
# ...

# %%
train_scoresX, train_labelsX = O.OutlierDetector.detect_outliers(downsampled_imgs, pyod_algorithm='MOGAAL')
O.Features.view_image_and_features(imgs, ['downsample'], train_scores=[train_scoresX])
# Out:
# 2022-08-31 20:30:31.825789: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-08-31 20:30:38.310936: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-08-31 20:30:38.428922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2022-08-31 20:30:38.428997: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-08-31 20:30:38.450538: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# ...
