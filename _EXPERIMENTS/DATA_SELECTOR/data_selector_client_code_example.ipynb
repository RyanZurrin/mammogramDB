# %%
import sys
sys.path.insert(0,'../..')
import omama as O
import pandas as pd
import numpy as np
from omama.analysis.data_selection_algo.src.data_selector import DataSelector
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
subsetter=DataSelector()

# %%
df_omama=subsetter.load_dataset(filepath="/home/p.bendiksen001/deephealth/df_omama_complete.pkl")

# %%
df_omama.info()

# %%
df_omama.head(5)

# %%
df_omama=subsetter.fill_na_dataset(df_omama)

# %%
df_omama.to_pickle("/home/p.bendiksen001/deephealth/df_omama_complete_fill_na.pkl")

# %%
df_omama=subsetter.load_dataset(filepath="/home/p.bendiksen001/deephealth/df_omama_complete_fill_na.pkl")

# %%
subsetter.check_percent_missing_values_by_field(df_omama)
# Out:
#                                           percent_missing
# AccessionNumber                                  0.000000
# AcquisitionDeviceProcessingCode                 26.075449
# AcquisitionNumber                               99.566835
# AnatomicRegionSequence                           7.454305
# AnnotationDisplayFormatID                       99.916735
# AnodeTargetMaterial                              9.511452
# BitsAllocated                                    0.000000
# BitsStored                                       0.000000
# BodyPartExamined                                 0.000000
# BodyPartThickness                                7.468355
# BorderDensity                                   99.916735
# BreastImplantPresent                             2.267376
# BurnedInAnnotation                               0.000000
# CalibrationImage                                92.006950
# CodeMeaning                                    100.000000
# ...

# %%
df_omama_reduced=subsetter.subset_by_fields(df_omama)

# %%
df_omama_reduced.info()

# %%
df = subsetter.store_dataset(df_omama_reduced, path_to_store= '/home/p.bendiksen001/deephealth/')

# %%
df_omama=subsetter.load_dataset(filepath="/home/p.bendiksen001/deephealth/df_omama_reduced.pkl")

# %%
df_omama_pipelined=subsetter.subset_pipeline_post_manufacturer_step(filepath='/home/p.bendiksen001/deephealth/df_omama_reduced.pkl')
# Out:
# /home/p.bendiksen001/deephealth/omama/_EXPERIMENTS/DATA_SELECTOR/../../omama/analysis/data_selection_algo/src/data_selector.py:250: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_omama['Shape'] = df_omama['Shape'].str.replace('(2457, 1890,.*)', '2457, 1890, x)')
# /home/p.bendiksen001/deephealth/omama/_EXPERIMENTS/DATA_SELECTOR/../../omama/analysis/data_selection_algo/src/data_selector.py:251: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_omama['Shape'] = df_omama['Shape'].str.replace('(2457, 1996,.*)', '2457, 1996, x)')
# /home/p.bendiksen001/deephealth/omama/_EXPERIMENTS/DATA_SELECTOR/../../omama/analysis/data_selection_algo/src/data_selector.py:252: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_omama['Shape'] = df_omama['Shape'].str.replace('(2059, 652,.*)', '2059, 652, x)')
# ...

# %%
np.savetxt(r'/raid/mpsych/deepsight_run/whitelists/whitelist.txt', df_omama_pipelined.FilePath, fmt='%s')

# %%
df_omama_pipelined_2D_Only = df_omama_pipelined[df_omama_pipelined.FilePath.str.contains("DXm")]

df_omama_pipelined_2D_Only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191547 entries, 799023 to 466768
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   FilePath           191547 non-null  object
#  1   StudyInstanceUID   191547 non-null  object
#  2   image              191547 non-null  object
#  3   Imagelaterality    191547 non-null  object
#  4   label              191547 non-null  object
#  5   PatientAge         191097 non-null  float64
#  6   PatientName        0 non-null       float64
#  7   PatientBirthDate   0 non-null       float64
#  8   PatientSex         0 non-null       float64
#  9   PatientID          191547 non-null  object
#  10  Shape              191547 non-null  object
#  11  Manufacturer       191547 non-null  object
#  12  Modality           191546 non-null  object
#  13  SeriesInstanceUID  191547 non-null  object
#  14  SOPInstanceUID     191547 non-null  object
# ...

# %%
np.savetxt(r'/raid/mpsych/deepsight_run/whitelists/whitelist_2d.txt', df_omama_pipelined_2D_Only.FilePath, fmt='%s')

# %%
df_omama_pipelined_3D_Only = df_omama_pipelined[df_omama_pipelined.FilePath.str.contains("BT")]

df_omama_pipelined_3D_Only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67534 entries, 895690 to 913140
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FilePath           67534 non-null  object
#  1   StudyInstanceUID   67534 non-null  object
#  2   image              67534 non-null  object
#  3   Imagelaterality    67534 non-null  object
#  4   label              67534 non-null  object
#  5   PatientAge         54 non-null     float64
#  6   PatientName        0 non-null      float64
#  7   PatientBirthDate   0 non-null      float64
#  8   PatientSex         0 non-null      float64
#  9   PatientID          67534 non-null  object
#  10  Shape              67534 non-null  object
#  11  Manufacturer       67534 non-null  object
#  12  Modality           67534 non-null  object
#  13  SeriesInstanceUID  67534 non-null  object
#  14  SOPInstanceUID     67534 non-null  object
# dtypes: float64(4), object(11)
# ...

# %%
np.savetxt(r'/raid/mpsych/deepsight_run/whitelists/whitelist_3d.txt', df_omama_pipelined_3D_Only.FilePath, fmt='%s')
