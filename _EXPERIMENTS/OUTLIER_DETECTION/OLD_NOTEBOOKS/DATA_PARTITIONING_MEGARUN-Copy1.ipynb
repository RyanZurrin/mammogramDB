# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
omama_loader = O.OmamaLoader(config_num=2)
data = O.Data(omama_loader, load_cache=True)

# %%
len(data)
# Out:
# 176492

# %%
save_dir = '/home/ryan.zurrin001/Projects/omama/omama/outlier_detection/'
test_partition_list = data.partition_data(num_partitions=4, save_directory=save_dir, timing=True)
# Out:
# Saving partitioned paths to files in: /home/ryan.zurrin001/Projects/omama/omama/outlier_detection/
# partition_data           ...took     0.214014 seconds

# %%
len(test_partition_list[3])
# Out:
# 44123

# %%
path = '/raid/mpsych/cache_files/outlier_detection_logs/top200_run4.txt'
O.DataHelper.view_grid(path, ncols=10, figsize=(40, 40))

# %%
path = '/raid/mpsych/cache_files/outlier_detection_logs/bottom200_run4.txt'
O.DataHelper.view_grid(path, ncols=10)

# %%
path = '/raid/mpsych/cache_files/outlier_detection_logs/threshold_run4.txt' # images 2300 - 2500
O.DataHelper.view_grid(path, ncols=10)
