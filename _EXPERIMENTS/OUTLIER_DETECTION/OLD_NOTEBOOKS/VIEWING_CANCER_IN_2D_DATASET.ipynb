# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ol = O.OmamaLoader(config_num=14)
data2d = O.Data(ol, load_cache=True)

# %%
print(data2d)
# Out:
# Data(namespace(dh_dh2=namespace(total=17, 3D=0, 2D=17),
#           dh_dh0new=namespace(total=288, 3D=0, 2D=288),
#           dh_dcm_ast=namespace(total=164799, 3D=0, 2D=164799),
#           total_all_dicoms=165104,
#           total_2d_all=165104,
#           total_3d_all=0,
#           total_2d_cancer=5588,
#           total_2d_preindex=1544,
#           total_2d_noncancer=157972,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=5588,
#           total_preindex=1544,
#           total_noncancer=157972,
#           total_no_label=0))

# %%
data2d.filter_data(labels=["IndexCancer"])

# %%
len(data2d)
# Out:
# 5588

# %%
O.DataHelper.view_grid(data2d[:200], ncols=10)

# %%
O.DataHelper.view_grid(data2d[200:400], ncols=10)

# %%
O.DataHelper.view_grid(data2d[400:600], ncols=10)
