# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ol = O.OmamaLoader(config_num=13)
phase3_data = O.Data(ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.022125 seconds
# load_images              ...took     0.005817 seconds
# csv_to_map               ...took     0.494214 seconds
# 1000                     ...took     2.375824 seconds
# 2000                     ...took     4.846442 seconds
# 3000                     ...took     7.361988 seconds
# 4000                     ...took     9.855835 seconds
# 5000                     ...took    12.319294 seconds
# 6000                     ...took    14.813256 seconds
# 7000                     ...took    17.619165 seconds
# 8000                     ...took    20.168865 seconds
# 9000                     ...took    22.636768 seconds
# 10000                    ...took    25.095588 seconds
# 11000                    ...took    27.434684 seconds
# load_labels              ...took    29.088534 seconds
# save_pickle              ...took     0.029529 seconds
# generate_counts          ...took     0.013454 seconds
# ...

# %%
len(phase3_data)
# Out:
# 11648

# %%
# top 300 using the HBOS algorithm
path = '/raid/mpsych/cache_files/outlier_detection_logs/samples/top300_hbos_phase3.txt'
O.DataHelper.view_grid(path, ncols=10)
