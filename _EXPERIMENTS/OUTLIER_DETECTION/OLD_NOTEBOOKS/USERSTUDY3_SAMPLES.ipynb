# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imgs  = O.DataHelper.get2D(N=100, config_num=14, randomize=True)
O.DataHelper.view_grid(imgs)

# %%
imgs  = O.DataHelper.get2D(N=100, config_num=14, randomize=True)
O.DataHelper.view_grid(imgs)

# %%
imgs  = O.DataHelper.get2D(N=100, config_num=14, randomize=True)
O.DataHelper.view_grid(imgs)

# %%
imgs  = O.DataHelper.get2D(N=100, config_num=14, randomize=True)
O.DataHelper.view_grid(imgs)

# %%
imgs  = O.DataHelper.get2D(N=100, config_num=14, randomize=True)
O.DataHelper.view_grid(imgs)
