# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %%
import sys
sys.path.insert(0,'../..')
import omama as O
import pickle

# %%
# ol = O.OmamaLoader(config_num=27)
# data = O.Data(ol, load_cache=True)
dataset_B = O.DataHelper.get2D(N=1000, config_num=27)
# Out:
# DataLoader type is:  <class 'omama.omama_loader.OmamaLoader'>

# %%
for img in dataset_B:
    print(img.filePath)
# Out:
# /raid/data01/deephealth/dh_dcm_ast/2.25.101061596273797118379578161597667520568/DXm.2.25.196019876218144338833912653988519089450
# /raid/data01/deephealth/dh_dcm_ast/2.25.101305069476490315601276636535835442733/DXm.2.25.187959266909957004435527232080131655286
# /raid/data01/deephealth/dh_dcm_ast/2.25.101342675621179815626949670445106436415/DXm.2.25.156799870628027491452997435739216973699
# /raid/data01/deephealth/dh_dcm_ast/2.25.101438132421818920818932745259868778815/DXm.2.25.110353053144484196646236383886655653667
# /raid/data01/deephealth/dh_dcm_ast/2.25.101510617389074050971204475716091746407/DXm.2.25.135165624907069169803736429415703757935
# /raid/data01/deephealth/dh_dcm_ast/2.25.101512619415929936467237556871105847065/DXm.2.25.228757218061276551299441733976634454315
# /raid/data01/deephealth/dh_dcm_ast/2.25.102038761507494102693728350705541482458/DXm.2.25.13032401631218353207605391966361356572
# ...

# %%
 gtB = [
37, 55, 62, 92, 113, 137, 138, 142, 147, 190, 221, 249, 272, 279, 305, 342, 365, 393, 408, 
412, 416, 452, 462, 497, 521, 537, 547, 552, 578, 589, 590, 607, 611, 661, 663, 672, 706, 
720, 748, 810, 828, 860, 878, 892, 904, 922, 959, 960, 963, 990
 ]

# %%
O.DataHelper.view_grid(dataset_B[:100], ncols=10, show_indices=True)
# Out:
# /home/ryan.zurrin001/Projects/omama/_EXPERIMENTS/OUTLIER_DETECTION/../../omama/data_helper.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(pixels)

# %%
O.DataHelper.view_grid(dataset_B[100:200], ncols=10, show_indices=True, index=100)

# %%
O.DataHelper.view_grid(dataset_B[200:300], ncols=10, show_indices=True, index=200)

# %%
O.DataHelper.view_grid(dataset_B[300:400], ncols=10, show_indices=True, index=300)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2217529/825635201.py in <module>
# ----> 1 O.DataHelper.view_grid(dataset_B[300:400], ncols=10, show_indices=True, index=300)
#
# ~/Projects/omama/_EXPERIMENTS/OUTLIER_DETECTION/../../omama/data_helper.py in view_grid(images, slice_num, ncols, figsize, cmap, show_indices, index)
#     615                     index += 1
#     616         plt.tight_layout()
# --> 617         plt.show()
#     618
#     619         # if index < len(imgs):
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
# ...

# %%
O.DataHelper.view_grid(dataset_B[400:500], ncols=10, show_indices=True, index=400)

# %%
O.DataHelper.view_grid(dataset_B[500:600], ncols=10, show_indices=True, index=500)

# %%
O.DataHelper.view_grid(dataset_B[600:700], ncols=10, show_indices=True, index=600)

# %%
O.DataHelper.view_grid(dataset_B[700:800], ncols=10, show_indices=True, index=700)

# %%
O.DataHelper.view_grid(dataset_B[800:900], ncols=10, show_indices=True, index=800)

# %%
O.DataHelper.view_grid(dataset_B[900:1000], ncols=10, show_indices=True, index=900)
