# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
NO_RUNS = 1
DATASET = 'C'

# %%
runs = {}

for algo in odl.ALGORITHMS:
    
    print('Running', algo)

    runs[algo] = []
    
    for run in range(NO_RUNS):
    
        results = odl.run(DATASET, algo)
        
        print(algo, results['evaluation']['jaccard_score'])
        
        runs[algo].append(results)

    print('='*80)
# Out:
# Running AE
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running AE...
# In AE algorithm
# 2023-01-15 18:23:28.633826: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-15 18:23:30.112805: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-01-15 18:23:30.251560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-01-15 18:23:30.251607: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-15 18:23:30.254912: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-01-15 18:23:30.254952: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-01-15 18:23:30.255887: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-01-15 18:23:30.256368: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-01-15 18:23:30.256933: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-01-15 18:23:30.257702: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-01-15 18:23:30.257962: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-01-15 18:23:30.265733: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 76)                5852
# _________________________________________________________________
# dropout (Dropout)            (None, 76)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 76)                5852
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 76)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                1848
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                300
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 12)                156
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 76)                1900
# =================================================================
# Total params: 16,220
# Trainable params: 16,220
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2023-01-15 18:23:30.266633: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-15 18:23:30.270610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-01-15 18:23:30.278409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-15 18:23:30.278447: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-15 18:23:30.850181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-15 18:23:30.850229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-15 18:23:30.850236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-15 18:23:30.861797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# 2023-01-15 18:23:31.464739: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-01-15 18:23:31.482996: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245755000 Hz
# Epoch 1/100
# 2023-01-15 18:23:32.083106: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 3/3 [==============================] - 2s 98ms/step - loss: 9.9895 - val_loss: 7.9297
# 2023-01-15 18:23:32.884337: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-01-15 18:23:32.884695: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 2/100
# 3/3 [==============================] - 0s 12ms/step - loss: 8.0119 - val_loss: 6.7998
# Epoch 3/100
# 3/3 [==============================] - 0s 13ms/step - loss: 6.7794 - val_loss: 6.0505
# Epoch 4/100
# 3/3 [==============================] - 0s 13ms/step - loss: 5.9206 - val_loss: 5.5420
# Epoch 5/100
# 3/3 [==============================] - 0s 13ms/step - loss: 5.4602 - val_loss: 5.1655
# Epoch 6/100
# 3/3 [==============================] - 0s 11ms/step - loss: 5.0772 - val_loss: 4.8899
# Epoch 7/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.8170 - val_loss: 4.6848
# Epoch 8/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.5676 - val_loss: 4.5458
# Epoch 9/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.4253 - val_loss: 4.4419
# Epoch 10/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.3175 - val_loss: 4.3689
# Epoch 11/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.2015 - val_loss: 4.3144
# Epoch 12/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.1269 - val_loss: 4.2709
100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.0589 - val_loss: 2.5539
# Epoch 53/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.0224 - val_loss: 2.5264
# Epoch 54/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.0090 - val_loss: 2.5108
# Epoch 55/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9892 - val_loss: 2.4974
# Epoch 56/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9626 - val_loss: 2.4804
# Epoch 57/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9295 - val_loss: 2.4691
# Epoch 58/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9515 - val_loss: 2.4528
# Epoch 59/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.9058 - val_loss: 2.4405
# Epoch 60/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9062 - val_loss: 2.4281
# Epoch 61/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8887 - val_loss: 2.4147
# Epoch 62/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8553 - val_loss: 2.4007
# Epoch 63/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8233 - val_loss: 2.3881
# Epoch 64/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8156 - val_loss: 2.3766
# Epoch 65/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8287 - val_loss: 2.3667
# Epoch 66/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7833 - val_loss: 2.3598
# Epoch 67/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7635 - val_loss: 2.3528
# Epoch 68/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.7586 - val_loss: 2.3434
# Epoch 69/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7708 - val_loss: 2.3315
# Epoch 70/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7526 - val_loss: 2.3215
# Epoch 71/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7401 - val_loss: 2.3094
# Epoch 72/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7183 - val_loss: 2.3019
# Epoch 73/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7042 - val_loss: 2.2958
# Epoch 74/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6916 - val_loss: 2.2903
# Epoch 75/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6716 - val_loss: 2.2814
# Epoch 76/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6619 - val_loss: 2.2739
# Epoch 77/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6715 - val_loss: 2.2643
# Epoch 78/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6611 - val_loss: 2.2538
# Epoch 79/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6528 - val_loss: 2.2460
# Epoch 80/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6447 - val_loss: 2.2391
# Epoch 81/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6394 - val_loss: 2.2320
# Epoch 82/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6320 - val_loss: 2.2255
# Epoch 83/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6128 - val_loss: 2.2219
# Epoch 84/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6025 - val_loss: 2.2175
# Epoch 85/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6109 - val_loss: 2.2119
# Epoch 86/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5884 - val_loss: 2.2076
# Epoch 87/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5632 - val_loss: 2.2035
# Epoch 88/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5727 - val_loss: 2.1972
# Epoch 89/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5521 - val_loss: 2.1902
# Epoch 90/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5460 - val_loss: 2.1830
# Epoch 91/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5572 - val_loss: 2.1718
# Epoch 92/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5258 - val_loss: 2.1621
# Epoch 93/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5338 - val_loss: 2.1577
# Epoch 94/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5376 - val_loss: 2.1548
# Epoch 95/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5056 - val_loss: 2.1565
# Epoch 96/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5209 - val_loss: 2.1554
# Epoch 97/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.5070 - val_loss: 2.1525
# Epoch 98/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5130 - val_loss: 2.1485
# Epoch 99/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4964 - val_loss: 2.1464
# Epoch 100/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4782 - val_loss: 2.1403
# len of imgs and t_scores are equal for AE
# Trained!
# AE 0.3333333333333333
# ================================================================================
# Running AvgKNN
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running AvgKNN...
# In AvgKNN algorithm
# len of imgs and t_scores are equal for AvgKNN
# Trained!
# AvgKNN 0.06666666666666667
# ================================================================================
# Running VAE
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running VAE...
# In VAE algorithm
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 86)]         0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 86)           7482        input_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          11136       dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           8256        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           2080        dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            66          dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2)            66          dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 2)            0           dense_11[0][0]
#                                                                  dense_12[0][0]
# ==================================================================================================
# Total params: 29,086
# Trainable params: 29,086
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                96
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 86)                11094
# =================================================================
# Total params: 21,628
# Trainable params: 21,628
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 86)]         0
# __________________________________________________________________________________________________
# model (Functional)              [(None, 2), (None, 2 29086       input_1[0][0]
# __________________________________________________________________________________________________
# model_1 (Functional)            (None, 86)           21628       model[0][2]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 86)           7482        input_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          11136       dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           8256        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           2080        dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2)            66          dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            66          dropout_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 2)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# tf.math.square (TFOpLambda)     (None, 2)            0           dense_11[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 2)            0           tf.__operators__.add[0][0]
#                                                                  tf.math.square[0][0]
# __________________________________________________________________________________________________
# tf.math.exp (TFOpLambda)        (None, 2)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 2)            0           tf.math.subtract[0][0]
#                                                                  tf.math.exp[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None,)              0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 86)           0           model_1[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, 86)           0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None,)              0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference (TFO (None, 86)           0           tf.convert_to_tensor[0][0]
#                                                                  tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None,)              0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None,)              0           tf.math.squared_difference[0][0]
# __________________________________________________________________________________________________
# tf.math.abs (TFOpLambda)        (None,)              0           tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None,)              0           tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None,)              0           tf.math.abs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None,)              0           tf.math.multiply[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb ()                   0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.math.reduce_mean_1[0][0]
# ==================================================================================================
# Total params: 50,714
# Trainable params: 50,714
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 1s 163ms/step - loss: 118.3886 - val_loss: 38.8494
# Epoch 2/100
# 3/3 [==============================] - 0s 17ms/step - loss: 118.9324 - val_loss: 37.8842
# Epoch 3/100
# 3/3 [==============================] - 0s 16ms/step - loss: 117.9206 - val_loss: 37.7788
# Epoch 4/100
# 3/3 [==============================] - 0s 14ms/step - loss: 117.8930 - val_loss: 37.8295
# Epoch 5/100
# 3/3 [==============================] - 0s 14ms/step - loss: 111.5163 - val_loss: 37.8780
# Epoch 6/100
# 3/3 [==============================] - 0s 14ms/step - loss: 112.3380 - val_loss: 35.9649
# Epoch 7/100
# 3/3 [==============================] - 0s 15ms/step - loss: 109.8503 - val_loss: 39.4507
# Epoch 8/100
# 3/3 [==============================] - 0s 13ms/step - loss: 79.1692 - val_loss: 26.5311
# Epoch 98/100
# 3/3 [==============================] - 0s 13ms/step - loss: 79.8431 - val_loss: 29.7309
# Epoch 99/100
# 3/3 [==============================] - 0s 14ms/step - loss: 80.5851 - val_loss: 26.1347
# Epoch 100/100
# 3/3 [==============================] - 0s 12ms/step - loss: 80.4581 - val_loss: 27.7605
# len of imgs and t_scores are equal for VAE
# Trained!
# VAE 0.45454545454545453
# ================================================================================
# Running SOGAAL
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running SOGAAL...
# In SOGAAL algorithm
# Epoch 1 of 60
#
# Testing for epoch 1 index 1:
# /home/daniel.haehn/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 2 of 60
#
# Testing for epoch 2 index 1:
# Epoch 3 of 60
#
# Testing for epoch 3 index 1:
# Epoch 4 of 60
#
# Testing for epoch 4 index 1:
# Epoch 5 of 60
#
# Testing for epoch 5 index 1:
# Epoch 6 of 60
#
# Testing for epoch 6 index 1:
# 2023-01-15 18:25:37.755934: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.760130: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.793052: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.797211: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.847873: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.851994: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.884492: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.888620: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.925622: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.929761: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 7 of 60
#
# Testing for epoch 7 index 1:
# Epoch 8 of 60
#
# Testing for epoch 8 index 1:
# Epoch 9 of 60
#
# Testing for epoch 9 index 1:
# Epoch 10 of 60
#
# Testing for epoch 10 index 1:
# Epoch 11 of 60
#
# Testing for epoch 11 index 1:
# 2023-01-15 18:25:37.964054: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:37.968298: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.000913: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.005005: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.037514: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.041630: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.091384: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.095503: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.146115: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.150215: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 12 of 60
#
# Testing for epoch 12 index 1:
# Epoch 13 of 60
#
# Testing for epoch 13 index 1:
# Epoch 14 of 60
#
# Testing for epoch 14 index 1:
# Epoch 15 of 60
#
# Testing for epoch 15 index 1:
# Epoch 16 of 60
#
# Testing for epoch 16 index 1:
# 2023-01-15 18:25:38.202646: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.206792: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.242544: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.246698: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.297538: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.301707: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.334211: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.338333: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.372253: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.376348: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 17 of 60
#
# Testing for epoch 17 index 1:
# Epoch 18 of 60
#
# Testing for epoch 18 index 1:
# Epoch 19 of 60
#
# Testing for epoch 19 index 1:
# Epoch 20 of 60
#
# Testing for epoch 20 index 1:
# Epoch 21 of 60
#
# Testing for epoch 21 index 1:
# 2023-01-15 18:25:38.410448: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.414594: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.446986: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.451211: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.483868: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.487996: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.524040: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.528209: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.578987: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.583093: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 22 of 60
#
# Testing for epoch 22 index 1:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9901
# Epoch 23 of 60
#
# Testing for epoch 23 index 1:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9999
# 2023-01-15 18:25:38.634589: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.779509: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 24 of 60
#
# Testing for epoch 24 index 1:
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0080
# Epoch 25 of 60
#
# Testing for epoch 25 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0144
# Epoch 26 of 60
#
# Testing for epoch 26 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0193
# 2023-01-15 18:25:38.852011: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.920748: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:38.992011: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 27 of 60
#
# Testing for epoch 27 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0228
# Epoch 28 of 60
#
# Testing for epoch 28 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0251
# Epoch 29 of 60
#
# Testing for epoch 29 index 1:
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0263
# 2023-01-15 18:25:39.062549: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:39.135684: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:39.222861: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 30 of 60
#
# Testing for epoch 30 index 1:
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0264
# Epoch 31 of 60
#
# Testing for epoch 31 index 1:
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0256
# Epoch 32 of 60
#
# Testing for epoch 32 index 1:
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0240
# 2023-01-15 18:25:39.292875: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:39.380151: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:25:39.451551: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 33 of 60
#
# ...
# Epoch 41/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4723 - val_loss: 3.4590
# Epoch 42/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4623 - val_loss: 3.4743
# Epoch 43/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4612 - val_loss: 3.4966
# Epoch 44/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4490 - val_loss: 3.5300
# Epoch 45/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4443 - val_loss: 3.5521
# Epoch 46/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4320 - val_loss: 3.5892
# Epoch 47/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4259 - val_loss: 3.6248
# Epoch 48/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4179 - val_loss: 3.6708
# Epoch 49/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4106 - val_loss: 3.7135
# Epoch 50/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4025 - val_loss: 3.7489
# Epoch 51/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4029 - val_loss: 3.7853
# Epoch 52/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3931 - val_loss: 3.8260
# Epoch 53/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3811 - val_loss: 3.8650
# Epoch 54/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3833 - val_loss: 3.8909
# Epoch 55/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3735 - val_loss: 3.9254
# Epoch 56/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3729 - val_loss: 3.9537
# Epoch 57/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3632 - val_loss: 3.9890
# Epoch 58/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3594 - val_loss: 4.0171
# Epoch 59/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3550 - val_loss: 4.0519
# Epoch 60/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3507 - val_loss: 4.0931
# Epoch 61/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3487 - val_loss: 4.1327
# Epoch 62/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3404 - val_loss: 4.1682
# Epoch 63/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3353 - val_loss: 4.2089
# Epoch 64/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3309 - val_loss: 4.2461
# Epoch 65/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3237 - val_loss: 4.2855
# Epoch 66/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3267 - val_loss: 4.3169
# Epoch 67/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3145 - val_loss: 4.3650
# Epoch 68/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3108 - val_loss: 4.4132
# Epoch 69/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3056 - val_loss: 4.4763
# Epoch 70/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3065 - val_loss: 4.5242
# Epoch 71/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3069 - val_loss: 4.5712
# Epoch 72/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2973 - val_loss: 4.6173
# Epoch 73/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2917 - val_loss: 4.6565
# Epoch 74/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2866 - val_loss: 4.6898
# Epoch 75/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2860 - val_loss: 4.7322
# Epoch 76/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2751 - val_loss: 4.7694
# Epoch 77/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2834 - val_loss: 4.8022
# Epoch 78/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2715 - val_loss: 4.8406
# Epoch 79/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2625 - val_loss: 4.8696
# Epoch 80/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2661 - val_loss: 4.9071
# Epoch 81/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2643 - val_loss: 4.9674
# Epoch 82/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2542 - val_loss: 5.0345
# Epoch 83/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2581 - val_loss: 5.0924
# Epoch 84/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2426 - val_loss: 5.1402
# Epoch 85/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2459 - val_loss: 5.1834
# Epoch 86/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2462 - val_loss: 5.2474
# Epoch 87/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2439 - val_loss: 5.3246
# Epoch 88/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2408 - val_loss: 5.4183
# Epoch 89/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2331 - val_loss: 5.4782
# Epoch 90/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2390 - val_loss: 5.5449
# Epoch 91/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.
# query sample 64 / 100
# iter: 0
# query sample 65 / 100
# iter: 0
# query sample 66 / 100
# iter: 0
# query sample 67 / 100
# iter: 0
# query sample 68 / 100
# iter: 0
# query sample 69 / 100
# iter: 0
# query sample 70 / 100
# iter: 0
# query sample 71 / 100
# iter: 0
# query sample 72 / 100
# iter: 0
# query sample 73 / 100
# iter: 0
# query sample 74 / 100
# iter: 0
# query sample 75 / 100
# iter: 0
# query sample 76 / 100
# iter: 0
# query sample 77 / 100
# iter: 0
# query sample 78 / 100
# iter: 0
# query sample 79 / 100
# iter: 0
# query sample 80 / 100
# iter: 0
# query sample 81 / 100
# iter: 0
# query sample 82 / 100
# iter: 0
# query sample 83 / 100
# iter: 0
# query sample 84 / 100
# iter: 0
# query sample 85 / 100
# iter: 0
# query sample 86 / 100
# iter: 0
# query sample 87 / 100
# iter: 0
# query sample 88 / 100
# iter: 0
# query sample 89 / 100
# iter: 0
# query sample 90 / 100
# iter: 0
# query sample 91 / 100
# iter: 0
# query sample 92 / 100
# iter: 0
# query sample 93 / 100
# iter: 0
# query sample 94 / 100
# iter: 0
# query sample 95 / 100
# iter: 0
# query sample 96 / 100
# iter: 0
# query sample 97 / 100
# iter: 0
# query sample 98 / 100
# iter: 0
# query sample 99 / 100
# iter: 0
# query sample 100 / 100
# iter: 0
# len of imgs and t_scores are equal for AnoGAN
# Trained!
# AnoGAN 0.11627906976744186
# ================================================================================
# Running HBOS
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running HBOS...
# In HBOS algorithm
# len of imgs and t_scores are equal for HBOS
# Trained!
# HBOS 0.23076923076923078
# ================================================================================
# Running LOF
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running LOF...
# In LOF algorithm
# len of imgs and t_scores are equal for LOF
# Trained!
# LOF 0.7142857142857143
# ================================================================================
# Running OCSVM
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running OCSVM...
# In OCSVM algorithm
# [LibSVM]*
# optimization finished, #iter = 50
# obj = 12.500000, rho = 0.500000
# nSV = 100, nBSV = 0
# len of imgs and t_scores are equal for OCSVM
# Trained!
# OCSVM 0.0
# ================================================================================
# Running IForest
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running IForest...
# In IForest algorithm
# len of imgs and t_scores are equal for IForest
# Trained!
# IForest 0.09090909090909091
# ================================================================================
# Running CBLOF
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running CBLOF...
# In CBLOF algorithm
# len of imgs and t_scores are equal for CBLOF
# Trained!
# CBLOF 0.043478260869565216
# ================================================================================
# Running COPOD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running COPOD...
# In COPOD algorithm
# len of imgs and t_scores are equal for COPOD
# Trained!
# COPOD 0.0
# ================================================================================
# Running SOS
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running SOS...
# In SOS algorithm
# contamination:  0.24
# len of imgs and t_scores are equal for SOS
# Trained!
# SOS 0.6
# ================================================================================
# Running KDE
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running KDE...
# In KDE algorithm
# len of imgs and t_scores are equal for KDE
# Trained!
# KDE 0.0
# ================================================================================
# Running Sampling
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running Sampling...
# In Sampling algorithm
# contamination:  0.24
# random_state: None
# len of imgs and t_scores are equal for Sampling
# Trained!
# Sampling 0.11627906976744186
# ================================================================================
# Running PCA
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running PCA...
# In PCA algorithm
# len of imgs and t_scores are equal for PCA
# Trained!
# PCA 0.06666666666666667
# ================================================================================
# Running LMDD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running LMDD...
# In LMDD algorithm
# len of imgs and t_scores are equal for LMDD
# Trained!
# LMDD 0.02127659574468085
# ================================================================================
# Running COF
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running COF...
# In COF algorithm
# len of imgs and t_scores are equal for COF
# Trained!
# COF 0.7142857142857143
# ================================================================================
# Running ECOD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running ECOD...
# In ECOD algorithm
# len of imgs and t_scores are equal for ECOD
# Trained!
# ECOD 0.02127659574468085
# ================================================================================
# Running KNN
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running KNN...
# In KNN algorithm
# KNN(algorithm='auto', contamination=0.24, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#   radius=1.0)
# len of imgs and t_scores are equal for KNN
# Trained!
# KNN 0.043478260869565216
# ================================================================================
# Running MedKNN
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running MedKNN...
# In MedKNN algorithm
# len of imgs and t_scores are equal for MedKNN
# Trained!
# MedKNN 0.06666666666666667
# ================================================================================
# Running SOD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running SOD...
# In SOD algorithm
# len of imgs and t_scores are equal for SOD
# Trained!
# SOD 0.45454545454545453
# ================================================================================
# Running INNE
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running INNE...
# In INNE algorithm
# len of imgs and t_scores are equal for INNE
# Trained!
# INNE 0.5483870967741935
# ================================================================================
# Running FB
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running FB...
# In FB algorithm
# len of imgs and t_scores are equal for FB
# Trained!
# FB 0.043478260869565216
# ================================================================================
# Running LODA
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running LODA...
# In LODA algorithm
# len of imgs and t_scores are equal for LODA
# Trained!
# LODA 0.06818181818181818
# ================================================================================
# Running SUOD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running SUOD...
# In SUOD algorithm
# Worker 1 sum of ranks: 12.5
#
# Split among workers BPS: [0, 8, 8] [8, 0]
# Parallel Training...
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Balanced Scheduling Total Train Time: 0.6483180522918701
# Split among workers default: [8] []
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# len of imgs and t_scores are equal for SUOD
# Trained!
# SUOD 0.0
# ================================================================================

# %%
run = 0

for algo in odl.ALGORITHMS:
    
    jaccard = runs[algo][run]['evaluation']['jaccard_score']
    f1 = runs[algo][run]['evaluation']['f1']
    tp = runs[algo][run]['evaluation']['tp']
    
    print(algo, jaccard, f1, tp)
# Out:
# AE 0.3333333333333333 0.5 12
# AvgKNN 0.06666666666666667 0.125 3
# VAE 0.45454545454545453 0.625 15
# SOGAAL 0.0 0.0 0
# DeepSVDD 0.11627906976744186 0.20833333333333334 5
# AnoGAN 0.11627906976744186 0.20833333333333334 5
# HBOS 0.23076923076923078 0.375 9
# LOF 0.7142857142857143 0.8333333333333334 20
# OCSVM 0.0 0.0 0
# IForest 0.09090909090909091 0.16666666666666666 4
# CBLOF 0.043478260869565216 0.08333333333333333 2
# COPOD 0.0 0.0 0
# SOS 0.6 0.75 18
# KDE 0.0 0.0 0
# Sampling 0.11627906976744186 0.20833333333333334 5
# PCA 0.06666666666666667 0.125 3
# LMDD 0.02127659574468085 0.041666666666666664 1
# COF 0.7142857142857143 0.8333333333333334 20
# ECOD 0.02127659574468085 0.041666666666666664 1
# KNN 0.043478260869565216 0.08333333333333333 2
# MedKNN 0.06666666666666667 0.125 3
# SOD 0.45454545454545453 0.625 15
# INNE 0.5483870967741935 0.7083333333333334 17
# FB 0.043478260869565216 0.08333333333333333 2
# LODA 0.06818181818181818 0.1276595744680851 3
# SUOD 0.0 0.0 0
