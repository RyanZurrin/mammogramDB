# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
odl.print_results('/raid/mpsych/ODL/BSTAR_default_10_152237.pkl')
# Out:
# AE
#     roc_auc 0.536842105263158 +/- 0.0
#     f1_score 0.12000000000000002 +/- 2.7755575615628914e-17
#     acc_score 0.9120000000000001 +/- 1.1102230246251565e-16
#     jaccard_score 0.06382978723404255 +/- 0.0
#     precision_score 0.12000000000000002 +/- 2.7755575615628914e-17
#     average_precision 0.05840000000000001 +/- 0.0
#     recall_score 0.12000000000000002 +/- 2.7755575615628914e-17
#     hamming_loss 0.088 +/- 0.0
#     log_loss 3.0394475050390697 +/- 4.440892098500626e-16
#     tn 906.0 +/- 0.0
#     fp 44.0 +/- 0.0
#     fn 44.0 +/- 0.0
#     tp 6.0 +/- 0.0
# AvgKNN
#     roc_auc 0.8210526315789475 +/- 1.1102230246251565e-16
#     f1_score 0.66 +/- 0.0
#     acc_score 0.9659999999999999 +/- 1.1102230246251565e-16
#     jaccard_score 0.4925373134328358 +/- 0.0
#     precision_score 0.66 +/- 0.0
#     average_precision 0.45260000000000006 +/- 0.0
#     recall_score 0.66 +/- 0.0
#     hamming_loss 0.03400000000000001 +/- 6.938893903907228e-18
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/ASTAR_default_10_152236.pkl', '/raid/mpsych/ODL/BSTAR_default_10_152237.pkl'], variable='jaccard_score')
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl|ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset ASTAR}} & \multicolumn{3}{c}{\textbf{Dataset BSTAR}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Jaccard Score} &\textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Jaccard Score} \\
#         \midrule
#         HBOS & Gaussian + Histogram & 0.6508 &HBOS & Gaussian + Histogram & 0.6400 \\
# CBLOF & Gaussian + Histogram & $0.5990\pm0.0082$ &AvgKNN & Gaussian + Histogram & 0.4925 \\
# AvgKNN & Gaussian + Histogram & 0.5949 &ECOD & Gaussian + Histogram & 0.4925 \\
# KNN & Gaussian + Histogram & 0.5949 &KNN & Gaussian + Histogram & 0.4925 \\
# MedKNN & Gaussian + Histogram & 0.5949 &MedKNN & Gaussian + Histogram & 0.4925 \\
# ECOD & Gaussian + Histogram & 0.5500 &IForest & Gaussian + Histogram & $0.4786\pm0.0111$ \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/BSTAR_default_10_152237.pkl','/raid/mpsych/ODL/ASTAR_default_10_152236.pkl'], variable='precision_score')
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl|ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset BSTAR}} & \multicolumn{3}{c}{\textbf{Dataset ASTAR}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Precision Score} &\textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Precision Score} \\
#         \midrule
#         HBOS & Gaussian + Histogram & 1.0000 &HBOS & Gaussian + Histogram & 1.0000 \\
# LODA & Gaussian + Histogram & $0.7083\pm0.4460$ &CBLOF & Gaussian + Histogram & $0.7492\pm0.0063$ \\
# AvgKNN & Gaussian + Histogram & 0.6600 &AvgKNN & Gaussian + Histogram & 0.7460 \\
# ECOD & Gaussian + Histogram & 0.6600 &KNN & Gaussian + Histogram & 0.7460 \\
# KNN & Gaussian + Histogram & 0.6600 &MedKNN & Gaussian + Histogram & 0.7460 \\
# MedKNN & Gaussian + Histogram & 0.6600 &ECOD & Gaussian + Histogram & 0.7213 \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/ASTAR_default_10_152236.pkl','/raid/mpsych/ODL/BSTAR_default_10_152237.pkl'], variable='f1_score')
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl|ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset ASTAR}} & \multicolumn{3}{c}{\textbf{Dataset BSTAR}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{F1 Score} &\textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{F1 Score} \\
#         \midrule
#         HBOS & Gaussian + Histogram & 0.7885 &HBOS & Gaussian + Histogram & 0.7805 \\
# CBLOF & Gaussian + Histogram & $0.7492\pm0.0063$ &AvgKNN & Gaussian + Histogram & 0.6600 \\
# AvgKNN & Gaussian + Histogram & 0.7460 &ECOD & Gaussian + Histogram & 0.6600 \\
# KNN & Gaussian + Histogram & 0.7460 &KNN & Gaussian + Histogram & 0.6600 \\
# MedKNN & Gaussian + Histogram & 0.7460 &MedKNN & Gaussian + Histogram & 0.6600 \\
# ECOD & Gaussian + Histogram & 0.7097 &IForest & Gaussian + Histogram & $0.6473\pm0.0101$ \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/ASTAR_default_10_152236.pkl', '/raid/mpsych/ODL/BSTAR_default_10_152237.pkl'], variable='roc_auc')
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl|ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset ASTAR}} & \multicolumn{3}{c}{\textbf{Dataset BSTAR}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} &\textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} \\
#         \midrule
#         CBLOF & Gaussian + Histogram & $0.8662\pm0.0034$ &AvgKNN & Gaussian + Histogram & 0.8211 \\
# AvgKNN & Gaussian + Histogram & 0.8645 &ECOD & Gaussian + Histogram & 0.8211 \\
# KNN & Gaussian + Histogram & 0.8645 &KNN & Gaussian + Histogram & 0.8211 \\
# MedKNN & Gaussian + Histogram & 0.8645 &MedKNN & Gaussian + Histogram & 0.8211 \\
# ECOD & Gaussian + Histogram & 0.8401 &HBOS & Gaussian + Histogram & 0.8200 \\
# HBOS & Gaussian + Histogram & 0.8254 &SUOD & Gaussian + Histogram & $0.8127\pm0.0042$ \\
# ...
