# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
odl.print_results('/raid/mpsych/ODL/B_default_10_152543.pkl')
# Out:
# KNN
#     roc_auc 0.425287356321839 +/- 5.551115123125783e-17
#     f1_score 0.0 +/- 0.0
#     acc_score 0.74 +/- 0.0
#     jaccard_score 0.0 +/- 0.0
#     precision_score 0.0 +/- 0.0
#     average_precision 0.12999999999999998 +/- 2.7755575615628914e-17
#     recall_score 0.0 +/- 0.0
#     hamming_loss 0.25999999999999995 +/- 5.551115123125783e-17
#     log_loss 8.980185810342704 +/- 0.0
#     tn 74.0 +/- 0.0
#     fp 13.0 +/- 0.0
#     fn 13.0 +/- 0.0
#     tp 0.0 +/- 0.0
# AE
#     roc_auc 0.5888594164456233 +/- 0.020258955326948856
#     f1_score 0.28461538461538466 +/- 0.03525058226889108
#     acc_score 0.8140000000000001 +/- 0.009165151389911638
#     jaccard_score 0.16640316205533595 +/- 0.023546831634160444
#     precision_score 0.28461538461538466 +/- 0.03525058226889108
#     average_precision 0.17524852071005917 +/- 0.014398507065216283
#     recall_score 0.28461538461538466 +/- 0.03525058226889108
#     hamming_loss 0.186 +/- 0.009165151389911688
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/B_default_10_152543.pkl'])
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset B}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Jaccard Score} \\
#         \midrule
#         INNE & Min-Max + SIFT & $0.4471\pm0.0624$ \\
# SOS & Max + SIFT & $0.3569\pm0.0605$ \\
# SOD & Min-Max + SIFT & $0.3020\pm0.0505$ \\
# HBOS & Max + Histogram & 0.3000 \\
# SUOD & Gaussian + Histogram & $0.2043\pm0.0276$ \\
# VAE & Max + SIFT & 0.1818 \\
# LOF & Min-Max + SIFT & 0.1818 \\
# COF & Min-Max + SIFT & $0.1767\pm0.0154$ \\
# AE & Max + SIFT & $0.1664\pm0.0235$ \\
# IForest & Gaussian + Histogram & $0.1622\pm0.0411$ \\
# COPOD & Gaussian + Histogram & 0.1304 \\
# ECOD & Gaussian + Histogram & 0.1304 \\
# LMDD & Max + SIFT & $0.1144\pm0.0608$ \\
# PCA & Gaussian + Histogram & 0.0833 \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/B_default_10_152543.pkl'], variable="roc_auc")
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset B}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} \\
#         \midrule
#         INNE & Min-Max + SIFT & $0.7790\pm0.0342$ \\
# SOS & Max + SIFT & $0.7259\pm0.0385$ \\
# HBOS & Max + Histogram & 0.6905 \\
# SOD & Min-Max + SIFT & $0.6905\pm0.0342$ \\
# SUOD & Gaussian + Histogram & $0.6198\pm0.0217$ \\
# VAE & Max + SIFT & 0.6021 \\
# LOF & Min-Max + SIFT & 0.6021 \\
# COF & Min-Max + SIFT & $0.5977\pm0.0133$ \\
# AE & Max + SIFT & $0.5889\pm0.0203$ \\
# IForest & Gaussian + Histogram & $0.5844\pm0.0354$ \\
# COPOD & Gaussian + Histogram & 0.5579 \\
# ECOD & Gaussian + Histogram & 0.5579 \\
# LMDD & Max + SIFT & $0.5402\pm0.0566$ \\
# PCA & Gaussian + Histogram & 0.5137 \\
# SOGAAL & Gaussian + ORB & $0.5102\pm0.0193$ \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/B_default_10_152543.pkl'], variable="f1_score")
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset B}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{F1 Score} \\
#         \midrule
#         INNE & Min-Max + SIFT & $0.6154\pm0.0596$ \\
# SOS & Max + SIFT & $0.5231\pm0.0671$ \\
# HBOS & Max + Histogram & 0.4615 \\
# SOD & Min-Max + SIFT & $0.4615\pm0.0596$ \\
# SUOD & Gaussian + Histogram & $0.3385\pm0.0377$ \\
# VAE & Max + SIFT & 0.3077 \\
# LOF & Min-Max + SIFT & 0.3077 \\
# COF & Min-Max + SIFT & $0.3000\pm0.0231$ \\
# AE & Max + SIFT & $0.2846\pm0.0353$ \\
# IForest & Gaussian + Histogram & $0.2769\pm0.0615$ \\
# COPOD & Gaussian + Histogram & 0.2308 \\
# ECOD & Gaussian + Histogram & 0.2308 \\
# LMDD & Max + SIFT & $0.2000\pm0.0985$ \\
# PCA & Gaussian + Histogram & 0.1538 \\
# ...
