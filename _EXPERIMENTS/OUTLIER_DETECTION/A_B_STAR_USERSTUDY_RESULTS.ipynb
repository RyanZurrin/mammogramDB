# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %%
import sys
sys.path.insert(0,'../..')
import omama as O
import collections
from collections import Counter, OrderedDict as od

# %%
dhruv_A = [
    32, 62, 79, 136, 182, 196, 199, 233, 244, 208, 209, 228, 236, 245, 336, 365, 385, 386, 388, 484, 605, 627, 713, 743, 754, 762, 764, 767, 776, 792, 793, 718, 789, 741, 807, 829, 846, 847, 853, 882, 898, 879, 936, 953, 972, 976
]
dhruv_B = [
    37, 55, 62, 92, 113, 137, 138, 147, 152, 190, 249, 272, 279, 305, 342, 393, 408, 412, 416, 452, 462, 497, 537, 552, 578, 589, 590, 521, 611, 661, 672, 663, 706, 720, 828, 810, 860, 892, 904, 922, 959, 963, 960, 990
]

# %%
jenna_A = [
    32, 62, 79, 136, 182, 196, 199,208, 209, 228, 233, 236, 244, 245,304, 311, 336, 365, 385, 386, 388, 484, 534,544,560,575,585,596,605,700, 713, 718, 741, 743, 754, 762, 764, 767, 776, 789, 792, 793,807, 829, 846, 847, 853, 879, 882, 898,936, 953, 972, 975
]
jenna_B = [
    37, 55, 62, 92, 113, 137, 138, 142, 147, 190, 249, 272, 279, 305, 342, 393, 408, 412, 416, 452, 462, 497, 521, 537, 547, 552, 578, 589, 590, 611, 661, 663, 672, 706, 720, 748, 810, 828, 860, 892, 904, 922, 59, 960, 963, 990
]

# %%
pablo_A = [
    32, 62, 79, 136, 182, 199, 196 , 208, 209, 228, 236, 233, 244, 245,  304, 311, 336, 365, 385, 386, 388, 484, 534, 544, 560, 575, 585, 596, 605, 713, 743, 754, 764, 762, 776, 789, 792, 793, 807, 853, 898, 847, 846, 829, 882, 879, 975, 953, 972, 936
]
pablo_B = [
    37, 55, 62, 92, 113, 137, 138, 147, 142, 190, 249, 272, 279, 305, 342, 393, 408, 416, 412, 452, 462, 497, 521, 537, 547, 552, 578, 589, 590, 611, 661, 663, 672, 706, 720, 748, 810, 828, 860, 892, 904, 922, 959, 963, 960, 990
]

# %%
lori_A = [
    32, 62, 79, 136, 182, 199, 208,209, 228, 233,244,236, 284, 304, 336, 321, 365, 385, 386,388,403, 447,494,534, 554,560,575,585,579,596,605, 637, 713,743, 754, 764, 762,774, 786,799,792,793,807,829,846,847,853, 882, 898, 936, 953, 972,975
]
lori_B = [
    37, 55, 62, 92, 123,137,147,138,282,259,289, 305,342,393,365,408,412,416,452,497, 537, 562, 578,590,599, 611,607,671,682,706,720,758,810,828,860, 892, 878, 904, 932,960, 963,959,990
]

# %%
ryan_A = [
    32, 62, 79, 136, 182, 196, 197, 199, 208, 209, 228, 233, 236, 244, 245, 261, 274, 276, 279, 304, 311, 336, 365, 385, 386, 388, 403, 447, 448, 456, 484, 534, 541, 544, 559, 560, 575, 579, 585, 596, 605, 627, 700, 713, 718, 741, 743, 754, 762, 764, 767, 776, 789, 792, 793, 807, 829, 846, 847, 849, 853, 879, 882, 898, 936, 953, 957, 971, 976, 975
]
ryan_B = [
    5, 12, 14, 20, 61, 67, 71, 104, 123, 142, 144, 158, 186, 190, 194, 205, 207, 242, 308, 318, 330, 334, 363, 382, 388, 407, 416, 438, 460, 463, 468, 502, 519, 610, 611, 616, 629, 651, 671, 677, 688, 718, 719, 756, 861, 918, 926, 959, 961, 975
]

# %%
jaink_A = [
    32, 62, 79, 112, 136, 182, 196, 199, 208, 209, 228, 233, 236, 244, 245, 261, 274, 276, 279, 304, 311, 336, 385, 386, 388, 447, 484, 534, 544, 560, 575, 579, 585, 596, 605, 627, 628, 713, 741, 743, 754, 762, 764, 767, 77, 789, 792, 793, 807, 829, 846, 847, 849, 853, 879, 882, 898, 936, 953, 971, 972, 975
]
jaink_B = [
    37, 55, 62, 92, 113, 137, 138, 142, 147, 190, 221, 249, 271, 279, 305, 342, 365, 393, 408, 412, 416, 452, 462, 497, 521, 537, 547, 552, 574, 578, 579, 589, 590, 607, 611, 661, 672, 706, 720, 748, 810, 828, 860, 878, 892, 904, 922, 959, 960, 963, 990
]

# %%
josh_A = [
    32, 62, 79, 136, 182, 196, 197, 199, 208, 209, 215, 238, 233, 236, 244, 245, 261, 274, 276, 279, 304, 311, 336, 365, 385, 386, 388, 448, 456, 484, 534, 544, 560, 575, 585, 596, 605, 627, 628, 700, 713, 718, 741, 743, 754, 762, 764, 767, 776, 789, 792, 793, 807, 829, 846, 847, 849, 853, 879, 882, 898, 936, 953, 971, 972, 975, 995
]
josh_B = [
    37, 55, 62, 92, 113, 137, 138, 147, 190, 221, 249, 272, 279, 305, 337, 342, 365, 393, 408, 412, 416, 452, 462, 497, 521, 537, 547, 552, 578, 589, 590, 607, 611, 661, 663, 672, 706, 720, 748, 810, 828, 860, 878, 892, 904, 922, 928, 959, 960, 963, 990
]

# %%
neha_A = [
    32, 62, 79, 122, 136, 182, 196, 197, 199, 208, 209, 228, 233, 236, 244, 245, 261, 274, 276, 279, 304, 311, 336, 365, 385, 386, 388, 399, 403, 447, 448, 456, 484, 500, 534, 541, 544, 560, 575, 579, 585, 596, 605, 700, 713, 718, 741, 743, 754, 762, 764, 767, 776, 789, 792, 793, 807, 829, 846, 847, 849, 853, 879, 882, 898, 936, 953, 957, 971, 972, 975, 995
]
neha_B = [
    37, 55, 62, 92, 113, 137, 138, 142, 147, 182, 190, 221, 249, 272, 279, 305, 342, 365, 393, 408, 412, 416, 452, 462, 497, 521, 537, 547, 552, 574, 578, 579, 589, 590, 606, 607, 611, 661, 663, 672, 706, 720, 748, 810, 828, 860, 878, 892, 904, 922, 928, 959, 960, 963, 990
]

# %%
# all_A = jenna_A + pablo_A + lori_A + ryan_A + dhruv_A + jaink_A + josh_A + neha_A
all_B = ryan_B # jenna_B + pablo_B + lori_B + ryan_B + dhruv_B + jaink_B + josh_B + neha_B

# %%
results_A = Counter(all_A)
results_A = od(sorted(results_A.items(), key=lambda kv: kv[1], reverse=True))

# %%
results_B = Counter(all_B)
results_B = od(sorted(results_B.items(), key=lambda kv: kv[1], reverse=True))

# %%
# ground_truth_A = sorted([k for k, v in results_A.items() if v >= 4])
ground_truth_B = sorted([k for k, v in results_B.items() if v >= 1])

# %%
len(ground_truth_B)
# Out:
# 50

# %%
print(ground_truth_A)
# Out:
# [32, 62, 79, 136, 182, 196, 199, 208, 209, 228, 233, 236, 244, 245, 261, 274, 276, 279, 304, 311, 336, 365, 385, 386, 388, 447, 484, 534, 544, 560, 575, 579, 585, 596, 605, 627, 700, 713, 718, 741, 743, 754, 762, 764, 767, 776, 789, 792, 793, 807, 829, 846, 847, 849, 853, 879, 882, 898, 936, 953, 971, 972, 975]

# %%
print(ground_truth_B)
# Out:
# [5, 12, 14, 20, 61, 67, 71, 104, 123, 142, 144, 158, 186, 190, 194, 205, 207, 242, 308, 318, 330, 334, 363, 382, 388, 407, 416, 438, 460, 463, 468, 502, 519, 610, 611, 616, 629, 651, 671, 677, 688, 718, 719, 756, 861, 918, 926, 959, 961, 975]

# %%
O.DataHelper.view('/raid/data01/deephealth/dh_dcm_ast/2.25.101512619415929936467237556871105847065/DXm.2.25.228757218061276551299441733976634454315')
# Out:
# type of data:  <class 'omama.data.Data'>

# %%
print(ground_truth_B)
# Out:
# [5, 12, 14, 20, 61, 67, 71, 104, 123, 142, 144, 158, 186, 190, 194, 205, 207, 242, 308, 318, 330, 334, 363, 382, 388, 407, 416, 438, 460, 463, 468, 502, 519, 610, 611, 616, 629, 651, 671, 677, 688, 718, 719, 756, 861, 918, 926, 959, 961, 975]

# %%
len(ground_truth_B)
# Out:
# 50

# %%
# paths_to_A = [line.rstrip('\r ').strip() for line in open('dataset_A_star.txt')]
paths_to_B = [line.rstrip('\r ').strip() for line in open('/raid/mpsych/whitelists/dataset_BSTAR.txt')]

# %%
O.DataHelper.view('/raid/data01/deephealth/dh_dcm_ast/2.25.47234677131819935337566193762653122146/DXm.2.25.188844879435122461817921056342465392405')
# Out:
# type of data:  <class 'omama.data.Data'>

# %%
paths_to_A
# Out:
# ['/raid/data01/deephealth/dh_dcm_ast/2.25.100728502639980456404134224979379881902/DXm.2.25.123955345078335270205044302468477147009',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.101221374746197577176382913385621654212/DXm.2.25.16514941654269633499078721268272687766',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.101637915282829098907884439396213083367/DXm.2.25.21017363671739539142885279636124564184',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.102197453853481117487375501103173727024/DXm.2.25.201254684196981491282236927767074456827',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.102296769056348883971431317704698714619/DXm.2.25.189193283102637769944043859500332182519',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.102397675810862130549653264214778050262/DXm.2.25.138653443247140683359504270104800416600',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.103163712792105308754798510443948269653/DXm.2.25.104205284316178910816977841359871952587',
# ...

# %%
paths_to_B
# Out:
# ['/raid/data01/deephealth/dh_dcm_ast/2.25.101061596273797118379578161597667520568/DXm.2.25.196019876218144338833912653988519089450',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.101305069476490315601276636535835442733/DXm.2.25.187959266909957004435527232080131655286',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.101342675621179815626949670445106436415/DXm.2.25.156799870628027491452997435739216973699',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.101438132421818920818932745259868778815/DXm.2.25.110353053144484196646236383886655653667',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.101510617389074050971204475716091746407/DXm.2.25.135165624907069169803736429415703757935',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.101512619415929936467237556871105847065/DXm.2.25.228757218061276551299441733976634454315',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.102038761507494102693728350705541482458/DXm.2.25.13032401631218353207605391966361356572',
# ...

# %%
# make a list of paths that use the indices in the ground truth
# ground_truth_paths_A = [paths_to_A[i].strip() for i in ground_truth_A]
ground_truth_paths_B = [paths_to_B[i].strip() for i in ground_truth_B]

# %%
ground_truth_paths_A
# Out:
# ['/raid/data01/deephealth/dh_dcm_ast/2.25.110916464715203445182871784373625753572/DXm.2.25.228445320364753264823102823285079382179',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.119798427111894677927754102577899160355/DXm.2.25.165488032964544137782651365231286274150',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.126018333337378409468931048338934939030/DXm.2.25.129929912523920970296082058152032439106',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.142729546202503225261926606814031176980/DXm.2.25.126860939382857152439201655809598783582',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.157507959102549660281011808886502999736/DXm.2.25.244795273039211108576999822155015948253',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.161855103564570643659925516560580227539/DXm.2.25.154726545842327128144023913069967858945',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.162128203391579133812960361152931489753/DXm.2.25.10689690428745907262275410383612522277',
# ...

# %%
ground_truth_sopuids = [path.split('/')[-1].strip() for path in ground_truth_paths_B]
ground_truth_sopuids = [sopuid.replace('DXm.', '') for sopuid in ground_truth_sopuids]

# %%
ground_truth_sopuids
# Out:
# ['2.25.228757218061276551299441733976634454315',
#  '2.25.186938390377702864424878266453617783452',
#  '2.25.104741570434286601024640599915765944050',
#  '2.25.34919021644207829746627699381007948801',
#  '2.25.102787927621950466899113393315058524090',
#  '2.25.148447723650642804858464400233497035468',
#  '2.25.326402327641003469188024101690905287801',
#  '2.25.213598039054484838606361554814505219338',
#  '2.25.300214680560415838318196660239364457653',
#  '2.25.103393271711914737569718144937024957616',
#  '2.25.82457179240616860907416801273366630158',
#  '2.25.286233379964022040364600669007368458455',
#  '2.25.186279306672112498829202095047008015246',
#  '2.25.132906022759651664039359337859728594549',
#  '2.25.133941834773783012094429514899141239009',
#  '2.25.20460653615197392336539842727043093043',
#  '2.25.217786273113602006536133619830901190813',
#  '2.25.117244012587548520294204126254868799907',
#  '2.25.301083143462307098769534157242949653169',
# ...

# %%
len(ground_truth_sopuids)
# Out:
# 50

# %%
ground_truth_paths_B
# Out:
# ['/raid/data01/deephealth/dh_dcm_ast/2.25.101512619415929936467237556871105847065/DXm.2.25.228757218061276551299441733976634454315',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.104166165186800264406196505274083899727/DXm.2.25.186938390377702864424878266453617783452',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.104866930069204690824809400814433435579/DXm.2.25.104741570434286601024640599915765944050',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.106160934222591908391447255343262938112/DXm.2.25.34919021644207829746627699381007948801',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.115978734206527604839336674046185356313/DXm.2.25.102787927621950466899113393315058524090',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.118192213927632171970513379879627988501/DXm.2.25.148447723650642804858464400233497035468',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.119219676450808198413861554859457566149/DXm.2.25.326402327641003469188024101690905287801',
# ...

# %%
O.DataHelper.view_grid(ground_truth_paths_A, ncols=10)

# %%
O.DataHelper.view_grid(ground_truth_paths_B, ncols=10)

# %%
print('length of A: ', len(results_A))
for k, v in results_A.items():
    print(k, v)
# Out:
# length of A:  85
# 136 8
# 182 8
# 199 8
# 208 8
# 209 8
# 233 8
# 236 8
# 244 8
# 336 8
# 385 8
# 386 8
# 388 8
# 605 8
# 713 8
# 743 8
# 754 8
# 762 8
# 764 8
# 792 8
# 793 8
# 807 8
# 829 8
# 846 8
# 847 8
# 853 8
# 882 8
# 898 8
# 936 8
# 953 8
# 196 7
# 228 7
# 245 7
# 304 7
# 365 7
# 484 7
# 534 7
# 560 7
# 575 7
# 585 7
# 596 7
# 789 7
# 879 7
# 972 7
# 975 7
# 311 6
# 544 6
# 741 6
# 767 6
# 776 6
# 718 5
# 700 4
# 447 4
# 579 4
# 261 4
# 274 4
# 276 4
# 279 4
# 627 4
# 849 4
# 971 4
# 403 3
# 197 3
# 448 3
# 456 3
# 541 2
# 957 2
# 976 2
# 628 2
# 995 2
# 284 1
# 321 1
# 494 1
# 554 1
# 637 1
# 774 1
# 786 1
# 799 1
# 559 1
# 112 1
# 77 1
# 215 1
# 238 1
# 122 1
# 399 1
# 500 1

# %%
print('length of B: ', len(results_B))
for k, v in results_B.items():
    print(k, v)
# Out:
# length of B:  69
# 37 8
# 55 8
# 62 8
# 92 8
# 137 8
# 138 8
# 147 8
# 305 8
# 342 8
# 393 8
# 408 8
# 412 8
# 416 8
# 452 8
# 497 8
# 537 8
# 578 8
# 590 8
# 611 8
# 706 8
# 720 8
# 810 8
# 828 8
# 860 8
# 892 8
# 904 8
# 960 8
# 963 8
# 990 8
# 113 7
# 190 7
# 249 7
# 462 7
# 521 7
# 552 7
# 589 7
# 661 7
# 672 7
# 922 7
# 959 7
# 272 6
# 279 6
# 547 6
# 663 6
# 748 6
# 142 5
# 365 5
# 607 5
# 878 5
# 221 4
# 574 3
# 579 3
# 928 3
# 182 2
# 59 1
# 123 1
# 282 1
# 259 1
# 289 1
# 562 1
# 599 1
# 671 1
# 682 1
# 758 1
# 932 1
# 152 1
# 271 1
# 337 1
# 606 1
