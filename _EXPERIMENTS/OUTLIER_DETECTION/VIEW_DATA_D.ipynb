# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')

# %%
import omama as O # importing the Omama package

# %%
import pickle

# %%
with open('/raid/mpsych/datasetD.pkl','rb') as f:
    imgs = pickle.load(f)

# %%
O.DataHelper.view_grid(imgs, ncols=10, show_indices=True)
# Out:
# /home/ryan.zurrin001/Projects/omama/_EXPERIMENTS/OUTLIER_DETECTION/../../omama/data_helper.py:139: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(pixels)

# %%
good_images = r'/raid/mpsych/cache_files/good_image_sopuids.txt'
good_images = O.DataHelper.file_to_list(good_images)

good_indices = [0]*100
for i,img in enumerate(imgs):
    if img.SOPInstanceUID in good_images:
          good_indices[i] = 1
        
with open('/raid/mpsych/datasetD_labels.pkl', 'wb') as f:
    pickle.dump(good_indices, f)

# %%
np.where(np.array(good_indices) > 0)
# Out:
# (array([ 2,  3,  4,  6,  7, 15, 25, 27, 32, 38, 39, 41, 45, 51, 55, 57, 61,
#         62, 63, 71, 76, 82, 92, 97]),)
