# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imgs = O.DataHelper.file_to_list('/raid/mpsych/cache_files/RERUN_MEGARUN/20230318_145534_1_ECOD%_51464c90a30bfbb04df4561621253be3.txt')

# %%
len(imgs)
# Out:
# 42092

# %%
O.DataHelper.view_grid(imgs[:100], ncols=10)
# Out:
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>

# %%
O.DataHelper.view_grid(imgs[41992:42091], ncols=10)
