# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
NO_RUNS = 1
DATASET = 'B'

# %%
runs = {}

for algo in odl.ALGORITHMS:
    
    print('Running', algo)

    runs[algo] = []
    
    for run in range(NO_RUNS):
    
        results = odl.run(DATASET, algo)
        
        print(algo, results['evaluation']['jaccard_score'])
        
        runs[algo].append(results)

    print('='*80)
# Out:
# Running AE
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running AE...
# In AE algorithm
# 2023-01-15 18:01:02.168910: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-15 18:01:03.635528: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-01-15 18:01:03.718180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-01-15 18:01:03.718227: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-15 18:01:03.721519: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-01-15 18:01:03.721557: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-01-15 18:01:03.722466: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-01-15 18:01:03.722793: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-01-15 18:01:03.723378: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-01-15 18:01:03.724148: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-01-15 18:01:03.724405: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-01-15 18:01:03.729736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                1560
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                300
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 12)                156
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                1600
# =================================================================
# Total params: 12,248
# Trainable params: 12,248
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2023-01-15 18:01:03.730396: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-15 18:01:03.733442: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-01-15 18:01:03.738495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-15 18:01:03.738527: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-15 18:01:04.205925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-15 18:01:04.205983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-15 18:01:04.205990: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-15 18:01:04.215105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# 2023-01-15 18:01:04.809257: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-01-15 18:01:04.827001: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245755000 Hz
# Epoch 1/100
# 2023-01-15 18:01:05.420576: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 3/3 [==============================] - 1s 79ms/step - loss: 7.8933 - val_loss: 6.2368
# Epoch 2/100
# 3/3 [==============================] - 0s 12ms/step - loss: 6.5183 - val_loss: 5.5156
# Epoch 3/100
# 1/3 [=========>....................] - ETA: 0s - loss: 6.5949
# 2023-01-15 18:01:06.104067: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-01-15 18:01:06.104409: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 3/3 [==============================] - 0s 13ms/step - loss: 5.5812 - val_loss: 5.0030
# Epoch 4/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.8775 - val_loss: 4.6532
# Epoch 5/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.5356 - val_loss: 4.3943
# Epoch 6/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.2447 - val_loss: 4.2120
# Epoch 7/100
# 3/3 [==============================] - 0s 11ms/step - loss: 4.0604 - val_loss: 4.0823
# Epoch 8/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.9063 - val_loss: 3.9902
# Epoch 9/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.7724 - val_loss: 3.9207
# Epoch 10/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.6773 - val_loss: 3.8657
# Epoch 11/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.6208 - val_loss: 3.8170
# Epoch 12/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.5565 - val_loss: 3.7769
# Epoch 13/100
# 3/3 [==============================] - 0s 12ms/step - loss: 3.4961 - val_loss: 3.7375
# Epoch 14/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.4651 - val_loss: 3.6978
# Epoch 15/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.4086 - val_loss: 3.6606
# Epoch 16/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.3697 - val_loss: 3.6264
# Epoch 17/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.3360 - val_loss: 3.5946
# Epoch 18/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.3008 - val_loss: 3.5648
# Epoch 19/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.2613 - val_loss: 3.5351
# Epoch 20/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.2305 - val_loss: 3.5045
# Epoch 21/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.1876 - val_loss: 3.4750
# Epoch 22/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.1590 - val_loss: 3.4448
# Epoch 23/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.1147 - val_loss: 3.4151
# Epoch 24/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.0747 - val_loss: 3.3835
# Epoch 25/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.0361 - val_loss: 3.3483
# Epoch 26/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.0021 - val_loss: 3.3084
# Epoch 27/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.9631 - val_loss: 3.2689
# Epoch 28/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.9150 - val_loss: 3.2285
# Epoch 29/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.8846 - val_loss: 3.1879
# Epoch 30/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.8263 - val_loss: 3.1454
# Epoch 31/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7728 - val_loss: 3.1039
# Epoch 32/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7242 - val_loss: 3.0580
# Epoch 33/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6736 - val_loss: 3.0072
# Epoch 34/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.6270 - val_loss: 2.9554
# Epoch 35/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.5813 - val_loss: 2.9058
# Epoch 36/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.5253 - val_loss: 2.8561
# Epoch 37/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.4508 - val_loss: 2.8077
# Epoch 38/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.3984 - val_loss: 2.7571
# Epoch 39/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.3489 - val_loss: 2.7066
# Epoch 40/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.3106 - val_loss: 2.6558
# Epoch 41/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.2581 - val_loss: 2.6066
# Epoch 42/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.2137 - val_loss: 2.5591
# Epoch 43/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.1896 - val_loss: 2.5142
# Epoch 44/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.1377 - val_loss: 2.4763
# Epoch 45/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.0962 - val_loss: 2.4409
# Epoch 46/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.0583 - val_loss: 2.4101
# Epoch 47/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.0705 - val_loss: 2.3791
# Epoch 48/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.0118 - val_loss: 2.3485
# Epoch 49/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9891 - val_loss: 2.3234
# Epoch 50/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9453 - val_loss: 2.2990
# Epoch 51/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.9438 - val_loss: 2.2812
# Epoch 52/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8959 - val_loss: 2.2663
# Epoch 53/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8856 - val_loss: 2.2534
# Epoch 54/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8741 - val_loss: 2.2393
# Epoch 55/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8544 - val_loss: 2.2252
# Epoch 56/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8285 - val_loss: 2.2120
# Epoch 57/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8115 - val_loss: 2.1960
# Epoch 58/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7992 - val_loss: 2.1792
# Epoch 59/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7904 - val_loss: 2.1632
# Epoch 60/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7773 - val_loss: 2.1481
# Epoch 61/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7597 - val_loss: 2.1353
# Epoch 62/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7359 - val_loss: 2.1284
# Epoch 63/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7262 - val_loss: 2.1229
# Epoch 64/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7153 - val_loss: 2.1175
# Epoch 65/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7125 - val_loss: 2.1080
# Epoch 66/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7111 - val_loss: 2.0980
# Epoch 67/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6759 - val_loss: 2.0868
# Epoch 68/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6598 - val_loss: 2.0757
# Epoch 69/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6522 - val_loss: 2.0628
# Epoch 70/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6496 - val_loss: 2.0501
# Epoch 71/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6429 - val_loss: 2.0399
# Epoch 72/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6227 - val_loss: 2.0304
# Epoch 73/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6352 - val_loss: 2.0213
# Epoch 74/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6280 - val_loss: 2.0161
# Epoch 75/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5937 - val_loss: 2.0087
# Epoch 76/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5764 - val_loss: 2.0027
# Epoch 77/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5873 - val_loss: 1.9966
# Epoch 78/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5725 - val_loss: 1.9921
# Epoch 79/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5743 - val_loss: 1.9880
# Epoch 80/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5587 - val_loss: 1.9828
# Epoch 81/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5587 - val_loss: 1.9748
# Epoch 82/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5644 - val_loss: 1.9661
# Epoch 83/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5434 - val_loss: 1.9606
# Epoch 84/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5396 - val_loss: 1.9534
# Epoch 85/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5362 - val_loss: 1.9460
# Epoch 86/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5339 - val_loss: 1.9409
# Epoch 87/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5203 - val_loss: 1.9385
# Epoch 88/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.5135 - val_loss: 1.9352
# Epoch 89/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.5038 - val_loss: 1.9298
# Epoch 90/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4909 - val_loss: 1.9250
# Epoch 91/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4867 - val_loss: 1.9178
# Epoch 92/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4851 - val_loss: 1.9121
# Epoch 93/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4882 - val_loss: 1.9055
# Epoch 94/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4792 - val_loss: 1.9012
# Epoch 95/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4742 - val_loss: 1.8953
# Epoch 96/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4476 - val_loss: 1.8915
# Epoch 97/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4554 - val_loss: 1.8863
# Epoch 98/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4563 - val_loss: 1.8807
# Epoch 99/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4343 - val_loss: 1.8738
# Epoch 100/100
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4406 - val_loss: 1.8695
# len of imgs and t_scores are equal for AE
# Trained!
# AE 0.18181818181818182
# ================================================================================
# Running AvgKNN
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running AvgKNN...
# In AvgKNN algorithm
# len of imgs and t_scores are equal for AvgKNN
# Trained!
# AvgKNN 0.0
# ================================================================================
# Running VAE
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running VAE...
# In VAE algorithm
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64)]         0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           4160        input_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          8320        dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           8256        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           2080        dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            66          dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2)            66          dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 2)            0           dense_11[0][0]
#                                                                  dense_12[0][0]
# ==================================================================================================
# Total params: 22,948
# Trainable params: 22,948
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                96
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# =================================================================
# Total params: 18,790
# Trainable params: 18,790
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64)]         0
# __________________________________________________________________________________________________
# model (Functional)              [(None, 2), (None, 2 22948       input_1[0][0]
# __________________________________________________________________________________________________
# model_1 (Functional)            (None, 64)           18790       model[0][2]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           4160        input_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          8320        dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           8256        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           2080        dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2)            66          dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            66          dropout_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 2)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# tf.math.square (TFOpLambda)     (None, 2)            0           dense_11[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 2)            0           tf.__operators__.add[0][0]
#                                                                  tf.math.square[0][0]
# __________________________________________________________________________________________________
# tf.math.exp (TFOpLambda)        (None, 2)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 2)            0           tf.math.subtract[0][0]
#                                                                  tf.math.exp[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None,)              0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 64)           0           model_1[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, 64)           0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None,)              0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference (TFO (None, 64)           0           tf.convert_to_tensor[0][0]
#                                                                  tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None,)              0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None,)              0           tf.math.squared_difference[0][0]
# __________________________________________________________________________________________________
# tf.math.abs (TFOpLambda)        (None,)              0           tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None,)              0           tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None,)              0           tf.math.abs[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None,)              0           tf.math.multiply[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb ()                   0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.math.reduce_mean_1[0][0]
# ==================================================================================================
# Total params: 41,738
# Trainable params: 41,738
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 1s 165ms/step - loss: 93.2456 - val_loss: 25.4702
# Epoch 2/100
# 3/3 [==============================] - 0s 13ms/step - loss: 95.2403 - val_loss: 24.9896
# Epoch 3/100
# 3/3 [==============================] - 0s 12ms/step - loss: 89.4484 - val_loss: 24.6271
# Epoch 4/100
# 3/3 [==============================] - 0s 12ms/step - loss: 91.8321 - val_loss: 24.1709
# Epoch 5/100
# 3/3 [==============================] - 0s 13ms/step - loss: 84.2622 - val_loss: 23.7503
# Epoch 6/100
# 3/3 [==============================] - 0s 12ms/step - loss: 86.4988 - val_loss: 23.9014
# Epoch 7/100
# 3/3 [==============================] - 0s 12ms/step - loss: 83.8395 - val_loss: 23.3783
# 3/3 [==============================] - 0s 13ms/step - loss: 59.4337 - val_loss: 14.5739
# Epoch 93/100
# 3/3 [==============================] - 0s 13ms/step - loss: 59.0921 - val_loss: 16.2096
# Epoch 94/100
# 3/3 [==============================] - 0s 13ms/step - loss: 63.0474 - val_loss: 15.0621
# Epoch 95/100
# 3/3 [==============================] - 0s 14ms/step - loss: 59.3575 - val_loss: 17.2492
# Epoch 96/100
# 3/3 [==============================] - 0s 14ms/step - loss: 58.6678 - val_loss: 15.1491
# Epoch 97/100
# 3/3 [==============================] - 0s 12ms/step - loss: 62.3915 - val_loss: 16.6455
# Epoch 98/100
# 3/3 [==============================] - 0s 12ms/step - loss: 60.5982 - val_loss: 15.2637
# Epoch 99/100
# 3/3 [==============================] - 0s 13ms/step - loss: 57.5413 - val_loss: 14.6601
# Epoch 100/100
# 3/3 [==============================] - 0s 13ms/step - loss: 61.5427 - val_loss: 15.2253
# len of imgs and t_scores are equal for VAE
# Trained!
# VAE 0.18181818181818182
# ================================================================================
# Running SOGAAL
# Loaded images.
# Loaded config, norm, and feats.
# KeyPointIntensities      ...took     0.006838 seconds
# ORB keypoints            ...took    47.345287 seconds
# Calculated features!
# Running SOGAAL...
# In SOGAAL algorithm
# Epoch 1 of 60
#
# Testing for epoch 1 index 1:
# /home/daniel.haehn/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 2 of 60
#
# Testing for epoch 2 index 1:
# Epoch 3 of 60
#
# Testing for epoch 3 index 1:
# Epoch 4 of 60
#
# Testing for epoch 4 index 1:
# Epoch 5 of 60
#
# Testing for epoch 5 index 1:
# Epoch 6 of 60
#
# Testing for epoch 6 index 1:
# Epoch 7 of 60
#
# Testing for epoch 7 index 1:
# 2023-01-15 18:03:55.362002: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.366057: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.397856: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.401802: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.433638: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.437578: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.473618: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.477548: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.509541: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.513471: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.564451: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.568559: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.618616: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.622551: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.660190: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.664138: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.714382: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.718324: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.753320: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.757376: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 8 of 60
#
# Testing for epoch 8 index 1:
# Epoch 9 of 60
#
# Testing for epoch 9 index 1:
# Epoch 10 of 60
#
# Testing for epoch 10 index 1:
# Epoch 11 of 60
#
# Testing for epoch 11 index 1:
# Epoch 12 of 60
#
# Testing for epoch 12 index 1:
# 2023-01-15 18:03:55.795333: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.799308: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.849668: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.853600: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.903498: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.907429: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.939115: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.943055: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.975055: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:55.978986: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 13 of 60
#
# Testing for epoch 13 index 1:
# Epoch 14 of 60
#
# Testing for epoch 14 index 1:
# Epoch 15 of 60
#
# Testing for epoch 15 index 1:
# Epoch 16 of 60
#
# Testing for epoch 16 index 1:
# Epoch 17 of 60
#
# Testing for epoch 17 index 1:
# 2023-01-15 18:03:56.032225: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.036220: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.068644: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.072608: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.107904: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.112154: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.144386: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.148372: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.180509: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.184444: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 18 of 60
#
# Testing for epoch 18 index 1:
# Epoch 19 of 60
#
# Testing for epoch 19 index 1:
# Epoch 20 of 60
#
# Testing for epoch 20 index 1:
# Epoch 21 of 60
#
# Testing for epoch 21 index 1:
# Epoch 22 of 60
#
# Testing for epoch 22 index 1:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6222
# Epoch 23 of 60
#
# Testing for epoch 23 index 1:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6824
# 2023-01-15 18:03:56.236115: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.356041: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 24 of 60
#
# Testing for epoch 24 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7481
# Epoch 25 of 60
#
# Testing for epoch 25 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8125
# Epoch 26 of 60
#
# Testing for epoch 26 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4182
# 2023-01-15 18:03:56.454528: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.540215: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.608236: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 27 of 60
#
# Testing for epoch 27 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2526
# Epoch 28 of 60
#
# Testing for epoch 28 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1599
# Epoch 29 of 60
#
# Testing for epoch 29 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1005
# 2023-01-15 18:03:56.676371: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.749387: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.834936: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# Epoch 30 of 60
#
# Testing for epoch 30 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0582
# Epoch 31 of 60
#
# Testing for epoch 31 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0443
# Epoch 32 of 60
#
# Testing for epoch 32 index 1:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0353
# 2023-01-15 18:03:56.904957: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# 2023-01-15 18:03:56.977100: W tensorflow/core/kernels/data/model_dataset_op.cc:205] Optimization loop failed: Cancelled: Operation was cancelled
# ...
# Epoch 37/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.9955 - val_loss: 6.6404
# Epoch 38/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.9439 - val_loss: 6.6784
# Epoch 39/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.8706 - val_loss: 6.6650
# Epoch 40/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.8370 - val_loss: 6.6591
# Epoch 41/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7651 - val_loss: 6.6594
# Epoch 42/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7245 - val_loss: 6.6600
# Epoch 43/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6842 - val_loss: 6.7008
# Epoch 44/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6399 - val_loss: 6.7670
# Epoch 45/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.6076 - val_loss: 6.8363
# Epoch 46/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.5648 - val_loss: 6.8550
# Epoch 47/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.5268 - val_loss: 6.9030
# Epoch 48/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.4897 - val_loss: 6.9363
# Epoch 49/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.4482 - val_loss: 6.9748
# Epoch 50/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.4136 - val_loss: 7.0088
# Epoch 51/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.3935 - val_loss: 7.0876
# Epoch 52/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.3603 - val_loss: 7.1043
# Epoch 53/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.3277 - val_loss: 7.2016
# Epoch 54/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.2949 - val_loss: 7.2832
# Epoch 55/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.2703 - val_loss: 7.3499
# Epoch 56/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.2404 - val_loss: 7.4354
# Epoch 57/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.2210 - val_loss: 7.5851
# Epoch 58/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.1991 - val_loss: 7.7291
# Epoch 59/100
# 3/3 [==============================] - 0s 10ms/step - loss: 2.1706 - val_loss: 7.7972
# Epoch 60/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.1487 - val_loss: 7.8826
# Epoch 61/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.1215 - val_loss: 7.9612
# Epoch 62/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.1031 - val_loss: 8.0724
# Epoch 63/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.0725 - val_loss: 8.1874
# Epoch 64/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.0574 - val_loss: 8.3402
# Epoch 65/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2.0287 - val_loss: 8.4120
# Epoch 66/100
# 3/3 [==============================] - 0s 9ms/step - loss: 2
# iter: 0
# query sample 68 / 100
# iter: 0
# query sample 69 / 100
# iter: 0
# query sample 70 / 100
# iter: 0
# query sample 71 / 100
# iter: 0
# query sample 72 / 100
# iter: 0
# query sample 73 / 100
# iter: 0
# query sample 74 / 100
# iter: 0
# query sample 75 / 100
# iter: 0
# query sample 76 / 100
# iter: 0
# query sample 77 / 100
# iter: 0
# query sample 78 / 100
# iter: 0
# query sample 79 / 100
# iter: 0
# query sample 80 / 100
# iter: 0
# query sample 81 / 100
# iter: 0
# query sample 82 / 100
# iter: 0
# query sample 83 / 100
# iter: 0
# query sample 84 / 100
# iter: 0
# query sample 85 / 100
# iter: 0
# query sample 86 / 100
# iter: 0
# query sample 87 / 100
# iter: 0
# query sample 88 / 100
# iter: 0
# query sample 89 / 100
# iter: 0
# query sample 90 / 100
# iter: 0
# query sample 91 / 100
# iter: 0
# query sample 92 / 100
# iter: 0
# query sample 93 / 100
# iter: 0
# query sample 94 / 100
# iter: 0
# query sample 95 / 100
# iter: 0
# query sample 96 / 100
# iter: 0
# query sample 97 / 100
# iter: 0
# query sample 98 / 100
# iter: 0
# query sample 99 / 100
# iter: 0
# query sample 100 / 100
# iter: 0
# len of imgs and t_scores are equal for AnoGAN
# Trained!
# AnoGAN 0.04
# ================================================================================
# Running HBOS
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running HBOS...
# In HBOS algorithm
# len of imgs and t_scores are equal for HBOS
# Trained!
# HBOS 0.3
# ================================================================================
# Running LOF
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running LOF...
# In LOF algorithm
# len of imgs and t_scores are equal for LOF
# Trained!
# LOF 0.3684210526315789
# ================================================================================
# Running OCSVM
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running OCSVM...
# In OCSVM algorithm
# [LibSVM]*
# optimization finished, #iter = 50
# obj = 12.500000, rho = 0.500000
# nSV = 100, nBSV = 0
# len of imgs and t_scores are equal for OCSVM
# Trained!
# OCSVM 0.0
# ================================================================================
# Running IForest
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running IForest...
# In IForest algorithm
# len of imgs and t_scores are equal for IForest
# Trained!
# IForest 0.0
# ================================================================================
# Running CBLOF
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running CBLOF...
# In CBLOF algorithm
# len of imgs and t_scores are equal for CBLOF
# Trained!
# CBLOF 0.04
# ================================================================================
# Running COPOD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running COPOD...
# In COPOD algorithm
# len of imgs and t_scores are equal for COPOD
# Trained!
# COPOD 0.0
# ================================================================================
# Running SOS
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running SOS...
# In SOS algorithm
# contamination:  0.13
# len of imgs and t_scores are equal for SOS
# Trained!
# SOS 0.3684210526315789
# ================================================================================
# Running KDE
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running KDE...
# In KDE algorithm
# len of imgs and t_scores are equal for KDE
# Trained!
# KDE 0.0
# ================================================================================
# Running Sampling
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running Sampling...
# In Sampling algorithm
# contamination:  0.13
# random_state: None
# len of imgs and t_scores are equal for Sampling
# Trained!
# Sampling 0.04
# ================================================================================
# Running PCA
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running PCA...
# In PCA algorithm
# len of imgs and t_scores are equal for PCA
# Trained!
# PCA 0.0
# ================================================================================
# Running LMDD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running LMDD...
# In LMDD algorithm
# len of imgs and t_scores are equal for LMDD
# Trained!
# LMDD 0.04
# ================================================================================
# Running COF
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running COF...
# In COF algorithm
# len of imgs and t_scores are equal for COF
# Trained!
# COF 0.625
# ================================================================================
# Running ECOD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running ECOD...
# In ECOD algorithm
# len of imgs and t_scores are equal for ECOD
# Trained!
# ECOD 0.0
# ================================================================================
# Running KNN
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running KNN...
# In KNN algorithm
# KNN(algorithm='auto', contamination=0.13, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#   radius=1.0)
# len of imgs and t_scores are equal for KNN
# Trained!
# KNN 0.04
# ================================================================================
# Running MedKNN
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running MedKNN...
# In MedKNN algorithm
# len of imgs and t_scores are equal for MedKNN
# Trained!
# MedKNN 0.04
# ================================================================================
# Running SOD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running SOD...
# In SOD algorithm
# len of imgs and t_scores are equal for SOD
# Trained!
# SOD 0.3
# ================================================================================
# Running INNE
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running INNE...
# In INNE algorithm
# len of imgs and t_scores are equal for INNE
# Trained!
# INNE 0.3684210526315789
# ================================================================================
# Running FB
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running FB...
# In FB algorithm
# len of imgs and t_scores are equal for FB
# Trained!
# FB 0.0
# ================================================================================
# Running LODA
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running LODA...
# In LODA algorithm
# len of imgs and t_scores are equal for LODA
# Trained!
# LODA 0.041666666666666664
# ================================================================================
# Running SUOD
# Loaded images.
# Loaded config, norm, and feats.
# Calculated features!
# Running SUOD...
# In SUOD algorithm
# Worker 1 sum of ranks: 8.0
#
# Split among workers BPS: [0, 5, 5] [5, 0]
# Parallel Training...
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Balanced Scheduling Total Train Time: 0.23403596878051758
# Split among workers default: [5] []
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# len of imgs and t_scores are equal for SUOD
# Trained!
# SUOD 0.0
# ================================================================================

# %%
run = 0

for algo in odl.ALGORITHMS:
    
    jaccard = runs[algo][run]['evaluation']['jaccard_score']
    f1 = runs[algo][run]['evaluation']['f1']
    tp = runs[algo][run]['evaluation']['tp']
    
    print(algo, jaccard, f1, tp)
# Out:
# AE 0.18181818181818182 0.3076923076923077 4
# AvgKNN 0.0 0.0 0
# VAE 0.18181818181818182 0.3076923076923077 4
# SOGAAL 0.0 0.0 0
# DeepSVDD 0.04 0.07692307692307693 1
# AnoGAN 0.04 0.07692307692307693 1
# HBOS 0.3 0.46153846153846156 6
# LOF 0.3684210526315789 0.5384615384615384 7
# OCSVM 0.0 0.0 0
# IForest 0.0 0.0 0
# CBLOF 0.04 0.07692307692307693 1
# COPOD 0.0 0.0 0
# SOS 0.3684210526315789 0.5384615384615384 7
# KDE 0.0 0.0 0
# Sampling 0.04 0.07692307692307693 1
# PCA 0.0 0.0 0
# LMDD 0.04 0.07692307692307693 1
# COF 0.625 0.7692307692307693 10
# ECOD 0.0 0.0 0
# KNN 0.04 0.07692307692307693 1
# MedKNN 0.04 0.07692307692307693 1
# SOD 0.3 0.46153846153846156 6
# INNE 0.3684210526315789 0.5384615384615384 7
# FB 0.0 0.0 0
# LODA 0.041666666666666664 0.08 1
# SUOD 0.0 0.0 0
