# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')

# %%
import omama as O

# %%
removed_images = O.Data(O.OmamaLoader(config_num=34), load_cache=True, timing=True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# load_studies             ...took     0.006859 seconds
# load_images              ...took     0.002701 seconds
# csv_to_map               ...took     0.241809 seconds
# load_pickle              ...took     0.007115 seconds
# generate_counts          ...took     0.005277 seconds
# generate_stats           ...took     0.005847 seconds
# total _init              ...took     0.282253 seconds
# total __init__           ...took     0.282350 seconds

# %%
print(removed_images)
# Out:
# Data(namespace(dh_dh2=namespace(total=6, 3D=0, 2D=6),
#           dh_dh0new=namespace(total=54, 3D=0, 2D=54),
#           dh_dcm_ast=namespace(total=4740, 3D=0, 2D=4740),
#           total_all_dicoms=4800,
#           total_2d_all=4800,
#           total_3d_all=0,
#           total_2d_cancer=245,
#           total_2d_preindex=38,
#           total_2d_noncancer=4517,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=245,
#           total_preindex=38,
#           total_noncancer=4517,
#           total_no_label=0))

# %%
removed_images.filter_data(labels=['IndexCancer'])

# %%
print(removed_images)
# Out:
# Data(namespace(dh_dh2=namespace(total=6, 3D=0, 2D=6),
#           dh_dh0new=namespace(total=53, 3D=0, 2D=53),
#           dh_dcm_ast=namespace(total=186, 3D=0, 2D=186),
#           total_all_dicoms=245,
#           total_2d_all=245,
#           total_3d_all=0,
#           total_2d_cancer=245,
#           total_2d_preindex=38,
#           total_2d_noncancer=4517,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=245,
#           total_preindex=38,
#           total_noncancer=4517,
#           total_no_label=-4555))

# %%
O.DataHelper.view_grid(removed_images[:200], ncols=10)

# %%
current_2d = O.Data(O.OmamaLoader(config_num=28), load_cache=True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>

# %%
print(current_2d)
# Out:
# Data(namespace(dh_dh2=namespace(total=17, 3D=0, 2D=17),
#           dh_dh0new=namespace(total=288, 3D=0, 2D=288),
#           dh_dcm_ast=namespace(total=168063, 3D=0, 2D=168063),
#           total_all_dicoms=168368,
#           total_2d_all=168368,
#           total_3d_all=0,
#           total_2d_cancer=6048,
#           total_2d_preindex=1586,
#           total_2d_noncancer=160734,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=6048,
#           total_preindex=1586,
#           total_noncancer=160734,
#           total_no_label=0))

# %%
old_2d = O.Data(O.OmamaLoader(config_num=19), load_cache=True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>

# %%
print(old_2d)
# Out:
# Data(namespace(dh_dh2=namespace(total=16, 3D=0, 2D=16),
#           dh_dh0new=namespace(total=285, 3D=0, 2D=285),
#           dh_dcm_ast=namespace(total=162699, 3D=0, 2D=162699),
#           total_all_dicoms=163000,
#           total_2d_all=163000,
#           total_3d_all=0,
#           total_2d_cancer=5448,
#           total_2d_preindex=1514,
#           total_2d_noncancer=156038,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=5448,
#           total_preindex=1514,
#           total_noncancer=156038,
#           total_no_label=0))

# %%
cur_2d_paths = O.DataHelper.file_to_list('/raid/mpsych/whitelists/2d_no_ml_bad_removed.txt')

# %%
to_remove = O.DataHelper.file_to_list('/raid/mpsych/whitelists/removed_images_after_vae.txt')

# %%
len(cur_2d_paths)
# Out:
# 168368

# %%
len(to_remove)
# Out:
# 4800

# %%
new_2d_paths = list(set(cur_2d_paths) - set(to_remove))

# %%
len(new_2d_paths)
# Out:
# 163568

# %%
O.DataHelper.list_to_caselist(new_2d_paths, '/raid/mpsych/whitelists/final_2d_dataset.txt')
# Out:
# '/raid/mpsych/whitelists/final_2d_dataset.txt'

# %%
final_2d_dataset = O.Data(O.OmamaLoader(config_num=35), load_cache=True, timing=True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# load_studies             ...took     0.247676 seconds
# load_images              ...took     0.103463 seconds
# csv_to_map               ...took     0.216903 seconds
# 1000                     ...took     1.411839 seconds
# 2000                     ...took     2.761205 seconds
# 3000                     ...took     4.165256 seconds
# 4000                     ...took     5.600552 seconds
# 5000                     ...took     6.933303 seconds
# 6000                     ...took     8.307485 seconds
# 7000                     ...took     9.732467 seconds
# 8000                     ...took    11.084153 seconds
# 9000                     ...took    12.465221 seconds
# 10000                    ...took    13.841127 seconds
# 11000                    ...took    15.179234 seconds
# 12000                    ...took    16.555209 seconds
# ...

# %%
print(final_2d_dataset)
# Out:
# Data(namespace(dh_dh2=namespace(total=11, 3D=0, 2D=11),
#           dh_dh0new=namespace(total=234, 3D=0, 2D=234),
#           dh_dcm_ast=namespace(total=163323, 3D=0, 2D=163323),
#           total_all_dicoms=163568,
#           total_2d_all=163568,
#           total_3d_all=0,
#           total_2d_cancer=5803,
#           total_2d_preindex=1548,
#           total_2d_noncancer=156217,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=5803,
#           total_preindex=1548,
#           total_noncancer=156217,
#           total_no_label=0))
