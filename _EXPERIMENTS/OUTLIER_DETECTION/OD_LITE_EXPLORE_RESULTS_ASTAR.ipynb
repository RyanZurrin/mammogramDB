# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
odl.print_results('/raid/mpsych/ODL/ASTAR_default_10_152545.pkl')
# Out:
# KNN
#     roc_auc 0.48332232216970733 +/- 5.551115123125783e-17
#     f1_score 0.031746031746031744 +/- 0.0
#     acc_score 0.8779999999999999 +/- 1.1102230246251565e-16
#     jaccard_score 0.016129032258064512 +/- 3.469446951953614e-18
#     precision_score 0.031746031746031744 +/- 0.0
#     average_precision 0.06200781053162006 +/- 0.0
#     recall_score 0.031746031746031744 +/- 0.0
#     hamming_loss 0.12199999999999997 +/- 2.7755575615628914e-17
#     log_loss 4.213779495622346 +/- 0.0
#     tn 876.0 +/- 0.0
#     fp 61.0 +/- 0.0
#     fn 61.0 +/- 0.0
#     tp 2.0 +/- 0.0
# AE
#     roc_auc 0.5341430773661296 +/- 0.0
#     f1_score 0.12698412698412698 +/- 0.0
#     acc_score 0.89 +/- 0.0
#     jaccard_score 0.06779661016949154 +/- 1.3877787807814457e-17
#     precision_score 0.12698412698412698 +/- 0.0
#     average_precision 0.07112496850592089 +/- 0.0
#     recall_score 0.12698412698412698 +/- 0.0
#     hamming_loss 0.11000000000000001 +/- 1.3877787807814457e-17
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/ASTAR_default_10_152545.pkl'], variable='roc_auc')
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset ASTAR}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} \\
#         \midrule
#         LOF & Min-Max + SIFT & $0.7340\pm0.0170$ \\
# FB & Max + SIFT & $0.7019\pm0.0207$ \\
# INNE & Max + SIFT & $0.6841\pm0.0355$ \\
# SOD & Min-Max + SIFT & $0.6112\pm0.0154$ \\
# SOS & Max + SIFT & $0.5884\pm0.0215$ \\
# ECOD & Gaussian + Histogram & 0.5680 \\
# IForest & Gaussian + Histogram & $0.5409\pm0.0200$ \\
# AE & Max + Histogram & 0.5341 \\
# COPOD & Gaussian + Histogram & 0.5341 \\
# SUOD & Gaussian + Histogram & $0.5274\pm0.0051$ \\
# VAE & Min-Max + Histogram & 0.5257 \\
# PCA & Gaussian + Histogram & 0.5257 \\
# COF & Gaussian + Histogram & 0.5257 \\
# DeepSVDD & Gaussian + Histogram & $0.5248\pm0.0285$ \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/ASTAR_default_10_152545.pkl'], variable='jaccard_score')
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset ASTAR}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Jaccard Score} \\
#         \midrule
#         LOF & Min-Max + SIFT & $0.3354\pm0.0288$ \\
# FB & Max + SIFT & $0.2839\pm0.0316$ \\
# INNE & Max + SIFT & $0.2584\pm0.0525$ \\
# SOD & Min-Max + SIFT & $0.1573\pm0.0190$ \\
# SOS & Max + SIFT & $0.1296\pm0.0253$ \\
# ECOD & Gaussian + Histogram & 0.1053 \\
# IForest & Gaussian + Histogram & $0.0755\pm0.0219$ \\
# AE & Max + Histogram & 0.0678 \\
# COPOD & Gaussian + Histogram & 0.0678 \\
# SUOD & Gaussian + Histogram & $0.0606\pm0.0054$ \\
# VAE & Min-Max + Histogram & 0.0588 \\
# PCA & Gaussian + Histogram & 0.0588 \\
# COF & Gaussian + Histogram & 0.0588 \\
# DeepSVDD & Gaussian + Histogram & $0.0588\pm0.0299$ \\
# ...
