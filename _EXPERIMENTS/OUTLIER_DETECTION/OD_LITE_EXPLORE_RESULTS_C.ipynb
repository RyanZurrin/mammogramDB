# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
odl.print_results('/raid/mpsych/ODL/C_default_10_152544.pkl')
# Out:
# KNN
#     roc_auc 0.34210526315789475 +/- 0.0
#     f1_score 0.0 +/- 0.0
#     acc_score 0.5199999999999999 +/- 1.1102230246251565e-16
#     jaccard_score 0.0 +/- 0.0
#     precision_score 0.0 +/- 0.0
#     average_precision 0.24000000000000005 +/- 5.551115123125783e-17
#     recall_score 0.0 +/- 0.0
#     hamming_loss 0.4800000000000001 +/- 1.1102230246251565e-16
#     log_loss 16.578804572940378 +/- 3.552713678800501e-15
#     tn 52.0 +/- 0.0
#     fp 24.0 +/- 0.0
#     fn 24.0 +/- 0.0
#     tp 0.0 +/- 0.0
# AE
#     roc_auc 0.662828947368421 +/- 0.01256188512871667
#     f1_score 0.4875 +/- 0.01909406539564934
#     acc_score 0.7539999999999999 +/- 0.009165151389911688
#     jaccard_score 0.3225225225225225 +/- 0.016513786288129138
#     precision_score 0.4875 +/- 0.01909406539564934
#     average_precision 0.36102083333333335 +/- 0.013715903642541445
#     recall_score 0.4875 +/- 0.01909406539564934
#     hamming_loss 0.246 +/- 0.009165151389911688
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/C_default_10_152544.pkl'])
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset C}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Jaccard Score} \\
#         \midrule
#         INNE & Min-Max + SIFT & $0.6128\pm0.0576$ \\
# SOS & Min-Max + SIFT & $0.5549\pm0.0483$ \\
# HBOS & Gaussian + Histogram & 0.4545 \\
# COF & Max + SIFT & 0.4545 \\
# SOD & Min-Max + SIFT & $0.4468\pm0.0384$ \\
# LOF & Min-Max + SIFT & $0.4332\pm0.0214$ \\
# VAE & Min-Max + SIFT & $0.4248\pm0.0269$ \\
# AE & Max + SIFT & $0.3225\pm0.0165$ \\
# SUOD & Gaussian + Histogram & $0.2154\pm0.0154$ \\
# COPOD & Gaussian + Histogram & 0.2000 \\
# DeepSVDD & Gaussian + Histogram & $0.1380\pm0.0587$ \\
# IForest & Gaussian + Histogram & $0.1354\pm0.0278$ \\
# PCA & Gaussian + Histogram & 0.1163 \\
# LMDD & Min-Max + SIFT & $0.0983\pm0.0952$ \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/C_default_10_152544.pkl'], variable="roc_auc")
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset C}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} \\
#         \midrule
#         INNE & Min-Max + SIFT & $0.8410\pm0.0295$ \\
# SOS & Min-Max + SIFT & $0.8109\pm0.0259$ \\
# HBOS & Gaussian + Histogram & 0.7533 \\
# COF & Max + SIFT & 0.7533 \\
# SOD & Min-Max + SIFT & $0.7478\pm0.0239$ \\
# LOF & Min-Max + SIFT & $0.7396\pm0.0137$ \\
# VAE & Min-Max + SIFT & $0.7341\pm0.0176$ \\
# AE & Max + SIFT & $0.6628\pm0.0126$ \\
# SUOD & Gaussian + Histogram & $0.5751\pm0.0137$ \\
# COPOD & Gaussian + Histogram & 0.5614 \\
# OCSVM & Gaussian + Histogram & 0.5000 \\
# KDE & Gaussian + Histogram & 0.5000 \\
# DeepSVDD & Gaussian + Histogram & $0.4984\pm0.0638$ \\
# IForest & Gaussian + Histogram & $0.4984\pm0.0275$ \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/C_default_10_152544.pkl'], variable="f1_score")
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset C}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{F1 Score} \\
#         \midrule
#         INNE & Min-Max + SIFT & $0.7583\pm0.0449$ \\
# SOS & Min-Max + SIFT & $0.7125\pm0.0393$ \\
# HBOS & Gaussian + Histogram & 0.6250 \\
# COF & Max + SIFT & 0.6250 \\
# SOD & Min-Max + SIFT & $0.6167\pm0.0363$ \\
# LOF & Min-Max + SIFT & $0.6042\pm0.0208$ \\
# VAE & Min-Max + SIFT & $0.5958\pm0.0267$ \\
# AE & Max + SIFT & $0.4875\pm0.0191$ \\
# SUOD & Gaussian + Histogram & $0.3542\pm0.0208$ \\
# COPOD & Gaussian + Histogram & 0.3333 \\
# DeepSVDD & Gaussian + Histogram & $0.2375\pm0.0969$ \\
# IForest & Gaussian + Histogram & $0.2375\pm0.0419$ \\
# PCA & Gaussian + Histogram & 0.2083 \\
# AnoGAN & Max + ORB & 0.1667 \\
# ...
