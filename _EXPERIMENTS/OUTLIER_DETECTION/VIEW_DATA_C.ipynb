# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')

# %%
import omama as O # importing the Omama package

# %%
import pickle

# %%
with open('/raid/mpsych/datasetC.pkl','rb') as f:
    imgs = pickle.load(f)

# %%
O.DataHelper.view_grid(imgs, ncols=10, show_indices=True)
# Out:
# /home/daniel.haehn/Projects/omama/_EXPERIMENTS/OUTLIER_DETECTION/../../omama/data_helper.py:139: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(pixels)

# %%
bad_images = '/raid/mpsych/cache_files/bad_image_sopuids.txt'
bad_images = O.DataHelper.file_to_list(bad_images)

bad_indices = [0]*100
for i,img in enumerate(imgs):
    if img.SOPInstanceUID in bad_images:
        bad_indices[i] = 1
        
with open('/raid/mpsych/datasetC_labels.pkl', 'wb') as f:
    pickle.dump(bad_indices, f)

# %%
np.where(np.array(bad_indices) > 0)
# Out:
# (array([ 1,  5,  9, 10, 14, 18, 21, 22, 24, 25, 36, 38, 44, 46, 57, 58, 69,
#         71, 73, 77, 86, 87, 91, 98]),)
