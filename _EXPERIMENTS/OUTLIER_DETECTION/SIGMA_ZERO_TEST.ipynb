# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
odl = O.OutlierDetectorLite()

# %%
imgs = odl.load_data('ASTAR')

# %%
sigma_zero_imgs = O.Features.get_features(data=imgs, feature_type='hist', norm_type='gaussian', sigma=0)

# %%
no_sigma_imgs = O.Features.get_features(data=imgs, feature_type='hist')

# %%
sigma_zero_imgs[1]
# Out:
# array([   5924,     778,    2012,   32456,  193881,  514155,  966190,
#        1271023, 1121784,   84473,    4899,    3471,    2685,    2163,
#           2533,    1601,    1909,    1929,    1343,    1297,    1823,
#           1286,    1083,     967,    1693,    1018,     971,    1039,
#           1002,    1344,     898,     924,     827,     921,    1231,
#            816,     894,     705,     823,     778,    1125,     737,
#            686,     715,     638,     734,     819,     806,     658,
#            602,     631,     646,     640,     676,     660,     600,
#            571,     567,     532,     533,     515,     587,     568,
#            476,     491,     518,     478,     478,     436,     527,
#            486,     484,     480,     485,     472,     490,     482,
#            465,     511,     472,     461,     431,     446,     439,
#            456,     454,     431,     444,     455,     450,     453,
# ...

# %%
no_sigma_imgs[1]
# Out:
# array([ 17651,  12186,  12074,  11794,  11958,  11654,  11779,  11644,
#         11745,  11712,  11720,  11895,  11333,  11873,  11411,  11342,
#         11856,  11508,  11262,  11344,  11340,  11070,  11482,  11075,
#         11149,  11280,  11204,  11113,  11065,  11165,  11059,  10992,
#         10876,  11031,  11139,  10768,  11178,  10890,  10887,  11097,
#         11122,  10799,  11009,  10935,  10962,  11021,  10928,  10841,
#         11506,  11022,  11284,  11570,  11320,  11966,  11974,  12113,
#         12662,  12895,  13376,  13607,  13641,  14146,  15283,  15277,
#         16104,  16540,  17138,  18507,  18980,  19181,  20057,  21474,
#         22446,  23624,  24961,  26385,  27814,  29477,  30773,  31744,
#         33092,  33153,  36183,  37941,  38340,  39805,  39244,  42126,
#         43341,  42967,  46899,  48614,  48929,  52866,  52406,  56026,
#         55865,  61676,  60698,  67082,  66522,  72145,  70240,  74798,
# ...

# %%
odl

# %%
img0, filtered = O.Normalize.gaussian(imgs[0].pixels, sigma=0)

# %%
imshow(filtered)

# %%
imshow(imgs[0].pixels)

# %%
img0[:10]
# Out:
# array([[227.43006047, 228.07861323, 228.90165165, ...,   0.        ,
#           0.        ,   0.        ],
#        [225.05342436, 225.71456054, 226.73424187, ...,   0.        ,
#           0.        ,   0.        ],
#        [222.66923542, 223.16583971, 224.4258072 , ...,   0.        ,
#           0.        ,   0.        ],
#        ...,
#        [221.52392595, 220.61740078, 219.26364686, ...,   0.        ,
#           0.        ,   0.        ],
#        [220.64527503, 219.90511801, 219.11154367, ...,   0.        ,
#           0.        ,   0.        ],
#        [220.91657781, 220.270365  , 219.62442024, ...,   0.        ,
#           0.        ,   0.        ]])

# %%
imgs[0].pixels[:10]
# Out:
# array([[2626, 2631, 2653, ...,    0,    0,    0],
#        [2554, 2561, 2590, ...,    0,    0,    0],
#        [2549, 2563, 2573, ...,    0,    0,    0],
#        ...,
#        [2578, 2551, 2536, ...,    0,    0,    0],
#        [2500, 2484, 2465, ...,    0,    0,    0],
#        [2531, 2519, 2551, ...,    0,    0,    0]], dtype=uint16)
