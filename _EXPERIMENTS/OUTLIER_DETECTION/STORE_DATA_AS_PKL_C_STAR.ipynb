# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')

# %%
import omama as O # importing the Omama package

# %%
import pickle

# %%
data = O.Data(O.OmamaLoader(config_num=33), load_cache=True)
# Out:
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>

# %%
len(data)
# Out:
# 1000

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=1, 3D=0, 2D=1),
#           dh_dh0new=namespace(total=3, 3D=0, 2D=3),
#           dh_dcm_ast=namespace(total=996, 3D=0, 2D=996),
#           total_all_dicoms=1000,
#           total_2d_all=1000,
#           total_3d_all=0,
#           total_2d_cancer=31,
#           total_2d_preindex=9,
#           total_2d_noncancer=960,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=31,
#           total_preindex=9,
#           total_noncancer=960,
#           total_no_label=0))

# %%
len(data._image_paths)
# Out:
# 1000

# %%
len(data._labels)
# Out:
# 1000

# %%
imgs = O.DataHelper.get2D(N=1000, config_num=33)
# Out:
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>

# %%
len(imgs)
# Out:
# 1000

# %%
with open('/raid/mpsych/datasetCSTAR.pkl','wb') as f:
    pickle.dump(imgs, f)

# %%
print('all stored')
# Out:
# all stored

# %%
gt_indexes = [24,26,73,190,209,212,259,364,471,642,655,744,788,815,970]

# %%
bad_images = []
for i, img in enumerate(imgs):
    if i in gt_indexes:
        bad_images.append(img)
        print(img.filePath)
# Out:
# /raid/data01/deephealth/dh_dcm_ast/2.25.105933940071447001562465246792821379671/DXm.2.25.135158804469512531919278173719431609247
# /raid/data01/deephealth/dh_dcm_ast/2.25.106241761817791097352132353252474394775/DXm.2.25.116895292595054156155504709277077534135
# /raid/data01/deephealth/dh_dcm_ast/2.25.120631473686549324269319128585301064720/DXm.2.25.138413625934238823745957874276437351029
# /raid/data01/deephealth/dh_dcm_ast/2.25.160918006085332610759905164772928757478/DXm.2.25.152533380466342572593469087587560595128
# /raid/data01/deephealth/dh_dcm_ast/2.25.166216371618878105868835041759239819084/DXm.2.25.131866041747378067944083955680115895568
# /raid/data01/deephealth/dh_dcm_ast/2.25.16752377296855403970016339936530271184/DXm.2.25.148061532950001173046731819161617248281
# /raid/data01/deephealth/dh_dcm_ast/2.25.184674735831204462721701382954529315286/DXm.2.25.102895495137602710725247337878569395537
# ...

# %%
O.DataHelper.view_grid(bad_images)
