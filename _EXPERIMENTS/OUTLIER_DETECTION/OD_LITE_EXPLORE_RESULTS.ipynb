# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
odl.print_results('/raid/mpsych/ODL/A_custom_10_152446.pkl')
# Out:
# KNN
#     roc_auc 0.45652173913043476 +/- 5.551115123125783e-17
#     f1_score 0.0 +/- 0.0
#     acc_score 0.8400000000000001 +/- 1.1102230246251565e-16
#     jaccard_score 0.0 +/- 0.0
#     precision_score 0.0 +/- 0.0
#     average_precision 0.07999999999999999 +/- 1.3877787807814457e-17
#     recall_score 0.0 +/- 0.0
#     hamming_loss 0.15999999999999998 +/- 2.7755575615628914e-17
#     log_loss 5.526268190980127 +/- 0.0
#     tn 84.0 +/- 0.0
#     fp 8.0 +/- 0.0
#     fn 8.0 +/- 0.0
#     tp 0.0 +/- 0.0
# AE
#     roc_auc 0.5815217391304348 +/- 0.0
#     f1_score 0.22222222222222224 +/- 0.0
#     acc_score 0.86 +/- 0.0
#     jaccard_score 0.125 +/- 0.0
#     precision_score 0.2 +/- 0.0
#     average_precision 0.11000000000000001 +/- 1.3877787807814457e-17
#     recall_score 0.25 +/- 0.0
#     hamming_loss 0.14000000000000004 +/- 2.7755575615628914e-17
#     log_loss 4.835492663081911 +/- 8.881784197001252e-16
#     tn 84.0 +/- 0.0
#     fp 8.0 +/- 0.0
#     fn 6.0 +/- 0.0
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/A_default_5_144387.pkl', '/raid/mpsych/ODL/B_default_5_144388.pkl', '/raid/mpsych//ODL/C_default_5_144389.pkl'], variable="roc_auc")
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl|ccl|ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset A}} & \multicolumn{3}{c}{\textbf{Dataset B}} & \multicolumn{3}{c}{\textbf{Dataset C}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} &\textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} &\textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} \\
#         \midrule
#         DeepSVDD & Gaussian + Histogram & $0.8234\pm0.0333$ &DeepSVDD & Gaussian + Histogram & $0.8243\pm0.0023$ &AvgKNN & Gaussian + Histogram & 0.8904 \\
# AvgKNN & Gaussian + Histogram & 0.7962 &AvgKNN & Gaussian + Histogram & 0.8232 &CBLOF & Gaussian + Histogram & 0.8904 \\
# HBOS & Gaussian + Histogram & 0.7962 &CBLOF & Gaussian + Histogram & 0.8232 &MedKNN & Gaussian + Histogram & 0.8904 \\
# ...
