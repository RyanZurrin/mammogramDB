# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
odl

# %%
res = odl.get_best_results_for_each_algorithm(cache_root='/raid/mpsych/ODL/FIXED_FEAT_NORM/', variable="tp")
# Out:
# {'AE': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#         'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 34.0},
#         'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#         'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 26.0},
#         'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 8.0}},
#  'AnoGAN': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 2.0},
#             'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 13.0},
#             'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#             'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 5.0},
#             'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 5.0}},
#  'AvgKNN': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#             'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 33.0},
#             'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#             'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 29.0},
#             'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 7.0}},
#  'CBLOF': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 2.8},
#            'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 31.4},
#            'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.6},
#            'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 21.8},
#            'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0}},
#  'COF': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.0},
#          'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 33.0},
#          'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#          'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 17.0},
#          'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 9.0}},
#  'COPOD': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#            'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 35.0},
#            'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#            'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 26.0},
#            'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 8.0}},
#  'DeepSVDD': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.6},
#               'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.2},
#               'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 1.6},
#               'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 2.4},
#               'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 1.8}},
#  'ECOD': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.0},
#           'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 42.0},
#           'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#           'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 25.0},
#           'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 7.0}},
#  'FB': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#         'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 25.2},
#         'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#         'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 16.0},
#         'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 5.2}},
#  'HBOS': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.0},
#           'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 33.0},
#           'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#           'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 25.0},
#           'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 5.0}},
#  'IForest': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.2},
#              'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 35.6},
#              'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.2},
#              'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 27.6},
#              'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 7.8}},
#  'INNE': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 2.2},
#           'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 26.2},
#           'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.4},
#           'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 24.0},
#           'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.6}},
#  'KDE': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#          'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#          'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#          'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#          'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0}},
#  'KNN': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#          'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 33.0},
#          'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#          'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 29.0},
#          'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 7.0}},
#  'LMDD': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#           'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 8.0},
#           'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#           'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 5.0},
#           'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0}},
#  'LODA': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 2.8},
#           'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 32.2},
#           'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 5.2},
#           'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 25.4},
#           'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 7.2}},
#  'LOF': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#          'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 27.0},
#          'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.0},
#          'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 16.0},
#          'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0}},
#  'MedKNN': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#             'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 33.0},
#             'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#             'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 29.0},
#             'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 7.0}},
#  'OCSVM': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#            'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#            'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#            'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#            'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0}},
#  'PCA': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#          'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 33.0},
#          'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#          'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 25.0},
#          'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 8.0}},
#  'SOD': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#          'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 35.0},
#          'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 5.0},
#          'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 26.0},
#          'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.0}},
#  'SOGAAL': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#             'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#             'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#             'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0},
#             'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 0.0}},
#  'SOS': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 2.0},
#          'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 21.0},
#          'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 4.0},
#          'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 24.0},
#          'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0}},
#  'SUOD': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#           'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 34.2},
#           'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#           'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 24.2},
#           'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.6}},
#  'Sampling': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.2},
#               'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 33.4},
#               'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 5.6},
#               'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 27.6},
#               'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 7.4}},
#  'VAE': {'A': {'feat': 'ORB', 'norm': 'zscore', 'tp': 3.0},
#          'ASTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 33.2},
#          'B': {'feat': 'ORB', 'norm': 'zscore', 'tp': 6.0},
#          'BSTAR': {'feat': 'ORB', 'norm': 'zscore', 'tp': 25.4},
#          'C': {'feat': 'ORB', 'norm': 'zscore', 'tp': 8.0}}}

# %%
result_dict = {}
strvar = "tp_acc:"
for k, v in res.items():
    for j, i in v.items():
        if j == 'A':
            print(f"{j:<7} {k:<9} {i['norm']:<9} {i['feat']:<10}  tp: {str(int(i['tp'])):<1}/8  {strvar:>10}  {i['tp']/8:>5.2f}")
            result_dict[f"{j} {k} {i['norm']} {i['feat']}  tp:{str(int(i['tp']))}/8"] = i['tp']/8
        elif j == 'B':
            print(f"{j:<7} {k:<9} {i['norm']:<9} {i['feat']:<10}  tp: {str(int(i['tp'])):<1}/13  {strvar:>10} {i['tp']/13:>5.2f}")
            result_dict[f"{j} {k} {i['norm']} {i['feat']}  tp:{str(int(i['tp']))}/13"] = i['tp']/13
        elif j == 'C':
            print(f"{j:<7} {k:<9} {i['norm']:<9} {i['feat']:<10}  tp: {str(int(i['tp'])):<1}/24  {strvar:>10} {i['tp']/24:>5.2f}")
            result_dict[f"{j} {k} {i['norm']} {i['feat']}  tp:{str(int(i['tp']))}/24"] = i['tp']/24
        elif j == 'BSTAR':
            print(f"{j:<7} {k:<9} {i['norm']:<9} {i['feat']:<10}  tp: {str(int(i['tp'])):<1}/50  {strvar:>10} {i['tp']/50:>5.2f}")
            result_dict[f"{j} {k} {i['norm']} {i['feat']}  tp:{str(int(i['tp']))}/50"] = i['tp']/50
        elif j == 'ASTAR':
            print(f"{j:<7} {k:<9} {i['norm']:<9} {i['feat']:<10}  tp: {str(int(i['tp'])):<1}/63  {strvar:>10} {i['tp']/63:>5.2f}")
            result_dict[f"{j} {k} {i['norm']} {i['feat']}  tp:{str(int(i['tp']))}/63"] = i['tp']/63
# Out:
# ASTAR   ECOD      zscore    ORB         tp: 42/63     tp_acc:  0.67
# C       ECOD      zscore    ORB         tp: 7/24     tp_acc:  0.29
# B       ECOD      zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       ECOD      zscore    ORB         tp: 4/8     tp_acc:   0.50
# BSTAR   ECOD      zscore    ORB         tp: 25/50     tp_acc:  0.50
# ASTAR   IForest   zscore    ORB         tp: 35/63     tp_acc:  0.57
# C       IForest   zscore    ORB         tp: 7/24     tp_acc:  0.33
# B       IForest   zscore    ORB         tp: 6/13     tp_acc:  0.48
# A       IForest   zscore    ORB         tp: 3/8     tp_acc:   0.40
# BSTAR   IForest   zscore    ORB         tp: 27/50     tp_acc:  0.55
# ASTAR   COPOD     zscore    ORB         tp: 35/63     tp_acc:  0.56
# C       COPOD     zscore    ORB         tp: 8/24     tp_acc:  0.33
# B       COPOD     zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       COPOD     zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   COPOD     zscore    ORB         tp: 26/50     tp_acc:  0.52
# ASTAR   SOD       zscore    ORB         tp: 35/63     tp_acc:  0.56
# C       SOD       zscore    ORB         tp: 4/24     tp_acc:  0.17
# B       SOD       zscore    ORB         tp: 5/13     tp_acc:  0.38
# A       SOD       zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   SOD       zscore    ORB         tp: 26/50     tp_acc:  0.52
# ASTAR   SUOD      zscore    ORB         tp: 34/63     tp_acc:  0.54
# C       SUOD      zscore    ORB         tp: 6/24     tp_acc:  0.27
# B       SUOD      zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       SUOD      zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   SUOD      zscore    ORB         tp: 24/50     tp_acc:  0.48
# ASTAR   AE        zscore    ORB         tp: 34/63     tp_acc:  0.54
# C       AE        zscore    ORB         tp: 8/24     tp_acc:  0.33
# B       AE        zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       AE        zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   AE        zscore    ORB         tp: 26/50     tp_acc:  0.52
# ASTAR   Sampling  zscore    ORB         tp: 33/63     tp_acc:  0.53
# C       Sampling  zscore    ORB         tp: 7/24     tp_acc:  0.31
# B       Sampling  zscore    ORB         tp: 5/13     tp_acc:  0.43
# A       Sampling  zscore    ORB         tp: 3/8     tp_acc:   0.40
# BSTAR   Sampling  zscore    ORB         tp: 27/50     tp_acc:  0.55
# ASTAR   VAE       zscore    ORB         tp: 33/63     tp_acc:  0.53
# C       VAE       zscore    ORB         tp: 8/24     tp_acc:  0.33
# B       VAE       zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       VAE       zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   VAE       zscore    ORB         tp: 25/50     tp_acc:  0.51
# ASTAR   HBOS      zscore    ORB         tp: 33/63     tp_acc:  0.52
# C       HBOS      zscore    ORB         tp: 5/24     tp_acc:  0.21
# B       HBOS      zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       HBOS      zscore    ORB         tp: 4/8     tp_acc:   0.50
# BSTAR   HBOS      zscore    ORB         tp: 25/50     tp_acc:  0.50
# ASTAR   KNN       zscore    ORB         tp: 33/63     tp_acc:  0.52
# C       KNN       zscore    ORB         tp: 7/24     tp_acc:  0.29
# B       KNN       zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       KNN       zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   KNN       zscore    ORB         tp: 29/50     tp_acc:  0.58
# ASTAR   AvgKNN    zscore    ORB         tp: 33/63     tp_acc:  0.52
# C       AvgKNN    zscore    ORB         tp: 7/24     tp_acc:  0.29
# B       AvgKNN    zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       AvgKNN    zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   AvgKNN    zscore    ORB         tp: 29/50     tp_acc:  0.58
# ASTAR   MedKNN    zscore    ORB         tp: 33/63     tp_acc:  0.52
# C       MedKNN    zscore    ORB         tp: 7/24     tp_acc:  0.29
# B       MedKNN    zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       MedKNN    zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   MedKNN    zscore    ORB         tp: 29/50     tp_acc:  0.58
# ASTAR   PCA       zscore    ORB         tp: 33/63     tp_acc:  0.52
# C       PCA       zscore    ORB         tp: 8/24     tp_acc:  0.33
# B       PCA       zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       PCA       zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   PCA       zscore    ORB         tp: 25/50     tp_acc:  0.50
# ASTAR   COF       zscore    ORB         tp: 33/63     tp_acc:  0.52
# C       COF       zscore    ORB         tp: 9/24     tp_acc:  0.38
# B       COF       zscore    ORB         tp: 6/13     tp_acc:  0.46
# A       COF       zscore    ORB         tp: 4/8     tp_acc:   0.50
# BSTAR   COF       zscore    ORB         tp: 17/50     tp_acc:  0.34
# ASTAR   LODA      zscore    ORB         tp: 32/63     tp_acc:  0.51
# C       LODA      zscore    ORB         tp: 7/24     tp_acc:  0.30
# B       LODA      zscore    ORB         tp: 5/13     tp_acc:  0.40
# A       LODA      zscore    ORB         tp: 2/8     tp_acc:   0.35
# BSTAR   LODA      zscore    ORB         tp: 25/50     tp_acc:  0.51
# ASTAR   CBLOF     zscore    ORB         tp: 31/63     tp_acc:  0.50
# C       CBLOF     zscore    ORB         tp: 6/24     tp_acc:  0.25
# B       CBLOF     zscore    ORB         tp: 4/13     tp_acc:  0.35
# A       CBLOF     zscore    ORB         tp: 2/8     tp_acc:   0.35
# BSTAR   CBLOF     zscore    ORB         tp: 21/50     tp_acc:  0.44
# ASTAR   LOF       zscore    ORB         tp: 27/63     tp_acc:  0.43
# C       LOF       zscore    ORB         tp: 6/24     tp_acc:  0.25
# B       LOF       zscore    ORB         tp: 4/13     tp_acc:  0.31
# A       LOF       zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   LOF       zscore    ORB         tp: 16/50     tp_acc:  0.32
# ASTAR   INNE      zscore    ORB         tp: 26/63     tp_acc:  0.42
# C       INNE      zscore    ORB         tp: 4/24     tp_acc:  0.19
# B       INNE      zscore    ORB         tp: 4/13     tp_acc:  0.34
# A       INNE      zscore    ORB         tp: 2/8     tp_acc:   0.28
# BSTAR   INNE      zscore    ORB         tp: 24/50     tp_acc:  0.48
# ASTAR   FB        zscore    ORB         tp: 25/63     tp_acc:  0.40
# C       FB        zscore    ORB         tp: 5/24     tp_acc:  0.22
# B       FB        zscore    ORB         tp: 3/13     tp_acc:  0.23
# A       FB        zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   FB        zscore    ORB         tp: 16/50     tp_acc:  0.32
# ASTAR   SOS       zscore    ORB         tp: 21/63     tp_acc:  0.33
# C       SOS       zscore    ORB         tp: 3/24     tp_acc:  0.12
# B       SOS       zscore    ORB         tp: 4/13     tp_acc:  0.31
# A       SOS       zscore    ORB         tp: 2/8     tp_acc:   0.25
# BSTAR   SOS       zscore    ORB         tp: 24/50     tp_acc:  0.48
# ASTAR   AnoGAN    zscore    ORB         tp: 13/63     tp_acc:  0.21
# C       AnoGAN    zscore    ORB         tp: 5/24     tp_acc:  0.21
# B       AnoGAN    zscore    ORB         tp: 3/13     tp_acc:  0.23
# A       AnoGAN    zscore    ORB         tp: 2/8     tp_acc:   0.25
# BSTAR   AnoGAN    zscore    ORB         tp: 5/50     tp_acc:  0.10
# ASTAR   LMDD      zscore    ORB         tp: 8/63     tp_acc:  0.13
# C       LMDD      zscore    ORB         tp: 6/24     tp_acc:  0.25
# B       LMDD      zscore    ORB         tp: 3/13     tp_acc:  0.23
# A       LMDD      zscore    ORB         tp: 3/8     tp_acc:   0.38
# BSTAR   LMDD      zscore    ORB         tp: 5/50     tp_acc:  0.10
# ASTAR   DeepSVDD  zscore    ORB         tp: 3/63     tp_acc:  0.05
# C       DeepSVDD  zscore    ORB         tp: 1/24     tp_acc:  0.07
# B       DeepSVDD  zscore    ORB         tp: 1/13     tp_acc:  0.12
# A       DeepSVDD  zscore    ORB         tp: 0/8     tp_acc:   0.07
# BSTAR   DeepSVDD  zscore    ORB         tp: 2/50     tp_acc:  0.05
# ASTAR   SOGAAL    zscore    ORB         tp: 0/63     tp_acc:  0.00
# C       SOGAAL    zscore    ORB         tp: 0/24     tp_acc:  0.00
# B       SOGAAL    zscore    ORB         tp: 0/13     tp_acc:  0.00
# A       SOGAAL    zscore    ORB         tp: 0/8     tp_acc:   0.00
# BSTAR   SOGAAL    zscore    ORB         tp: 0/50     tp_acc:  0.00
# ASTAR   OCSVM     zscore    ORB         tp: 0/63     tp_acc:  0.00
# C       OCSVM     zscore    ORB         tp: 0/24     tp_acc:  0.00
# B       OCSVM     zscore    ORB         tp: 0/13     tp_acc:  0.00
# A       OCSVM     zscore    ORB         tp: 0/8     tp_acc:   0.00
# BSTAR   OCSVM     zscore    ORB         tp: 0/50     tp_acc:  0.00
# ASTAR   KDE       zscore    ORB         tp: 0/63     tp_acc:  0.00
# C       KDE       zscore    ORB         tp: 0/24     tp_acc:  0.00
# B       KDE       zscore    ORB         tp: 0/13     tp_acc:  0.00
# A       KDE       zscore    ORB         tp: 0/8     tp_acc:   0.00
# BSTAR   KDE       zscore    ORB         tp: 0/50     tp_acc:  0.00

# %%
result_dict
# Out:
# {'ASTAR ECOD zscore ORB  tp:42/63': 0.6666666666666666,
#  'C ECOD zscore ORB  tp:7/24': 0.2916666666666667,
#  'B ECOD zscore ORB  tp:6/13': 0.46153846153846156,
#  'A ECOD zscore ORB  tp:4/8': 0.5,
#  'BSTAR ECOD zscore ORB  tp:25/50': 0.5,
#  'ASTAR IForest zscore ORB  tp:35/63': 0.5650793650793651,
#  'C IForest zscore ORB  tp:7/24': 0.325,
#  'B IForest zscore ORB  tp:6/13': 0.47692307692307695,
#  'A IForest zscore ORB  tp:3/8': 0.4,
#  'BSTAR IForest zscore ORB  tp:27/50': 0.552,
#  'ASTAR COPOD zscore ORB  tp:35/63': 0.5555555555555556,
#  'C COPOD zscore ORB  tp:8/24': 0.3333333333333333,
#  'B COPOD zscore ORB  tp:6/13': 0.46153846153846156,
#  'A COPOD zscore ORB  tp:3/8': 0.375,
#  'BSTAR COPOD zscore ORB  tp:26/50': 0.52,
#  'ASTAR SOD zscore ORB  tp:35/63': 0.5555555555555556,
#  'C SOD zscore ORB  tp:4/24': 0.16666666666666666,
#  'B SOD zscore ORB  tp:5/13': 0.38461538461538464,
#  'A SOD zscore ORB  tp:3/8': 0.375,
#  'BSTAR SOD zscore ORB  tp:26/50': 0.52,
#  'ASTAR SUOD zscore ORB  tp:34/63': 0.5428571428571429,
#  'C SUOD zscore ORB  tp:6/24': 0.27499999999999997,
#  'B SUOD zscore ORB  tp:6/13': 0.46153846153846156,
#  'A SUOD zscore ORB  tp:3/8': 0.375,
#  'BSTAR SUOD zscore ORB  tp:24/50': 0.484,
#  'ASTAR AE zscore ORB  tp:34/63': 0.5396825396825397,
#  'C AE zscore ORB  tp:8/24': 0.3333333333333333,
#  'B AE zscore ORB  tp:6/13': 0.46153846153846156,
#  'A AE zscore ORB  tp:3/8': 0.375,
#  'BSTAR AE zscore ORB  tp:26/50': 0.52,
#  'ASTAR Sampling zscore ORB  tp:33/63': 0.5301587301587302,
#  'C Sampling zscore ORB  tp:7/24': 0.30833333333333335,
#  'B Sampling zscore ORB  tp:5/13': 0.43076923076923074,
#  'A Sampling zscore ORB  tp:3/8': 0.4,
#  'BSTAR Sampling zscore ORB  tp:27/50': 0.552,
#  'ASTAR VAE zscore ORB  tp:33/63': 0.526984126984127,
#  'C VAE zscore ORB  tp:8/24': 0.3333333333333333,
#  'B VAE zscore ORB  tp:6/13': 0.46153846153846156,
#  'A VAE zscore ORB  tp:3/8': 0.375,
#  'BSTAR VAE zscore ORB  tp:25/50': 0.508,
#  'ASTAR HBOS zscore ORB  tp:33/63': 0.5238095238095238,
#  'C HBOS zscore ORB  tp:5/24': 0.20833333333333334,
#  'B HBOS zscore ORB  tp:6/13': 0.46153846153846156,
#  'A HBOS zscore ORB  tp:4/8': 0.5,
#  'BSTAR HBOS zscore ORB  tp:25/50': 0.5,
#  'ASTAR KNN zscore ORB  tp:33/63': 0.5238095238095238,
#  'C KNN zscore ORB  tp:7/24': 0.2916666666666667,
#  'B KNN zscore ORB  tp:6/13': 0.46153846153846156,
#  'A KNN zscore ORB  tp:3/8': 0.375,
#  'BSTAR KNN zscore ORB  tp:29/50': 0.58,
#  'ASTAR AvgKNN zscore ORB  tp:33/63': 0.5238095238095238,
#  'C AvgKNN zscore ORB  tp:7/24': 0.2916666666666667,
#  'B AvgKNN zscore ORB  tp:6/13': 0.46153846153846156,
#  'A AvgKNN zscore ORB  tp:3/8': 0.375,
#  'BSTAR AvgKNN zscore ORB  tp:29/50': 0.58,
#  'ASTAR MedKNN zscore ORB  tp:33/63': 0.5238095238095238,
#  'C MedKNN zscore ORB  tp:7/24': 0.2916666666666667,
#  'B MedKNN zscore ORB  tp:6/13': 0.46153846153846156,
#  'A MedKNN zscore ORB  tp:3/8': 0.375,
#  'BSTAR MedKNN zscore ORB  tp:29/50': 0.58,
#  'ASTAR PCA zscore ORB  tp:33/63': 0.5238095238095238,
#  'C PCA zscore ORB  tp:8/24': 0.3333333333333333,
#  'B PCA zscore ORB  tp:6/13': 0.46153846153846156,
#  'A PCA zscore ORB  tp:3/8': 0.375,
#  'BSTAR PCA zscore ORB  tp:25/50': 0.5,
#  'ASTAR COF zscore ORB  tp:33/63': 0.5238095238095238,
#  'C COF zscore ORB  tp:9/24': 0.375,
#  'B COF zscore ORB  tp:6/13': 0.46153846153846156,
#  'A COF zscore ORB  tp:4/8': 0.5,
#  'BSTAR COF zscore ORB  tp:17/50': 0.34,
#  'ASTAR LODA zscore ORB  tp:32/63': 0.5111111111111112,
#  'C LODA zscore ORB  tp:7/24': 0.3,
#  'B LODA zscore ORB  tp:5/13': 0.4,
#  'A LODA zscore ORB  tp:2/8': 0.35,
#  'BSTAR LODA zscore ORB  tp:25/50': 0.508,
#  'ASTAR CBLOF zscore ORB  tp:31/63': 0.49841269841269836,
#  'C CBLOF zscore ORB  tp:6/24': 0.25,
#  'B CBLOF zscore ORB  tp:4/13': 0.3538461538461538,
#  'A CBLOF zscore ORB  tp:2/8': 0.35,
#  'BSTAR CBLOF zscore ORB  tp:21/50': 0.436,
#  'ASTAR LOF zscore ORB  tp:27/63': 0.42857142857142855,
#  'C LOF zscore ORB  tp:6/24': 0.25,
#  'B LOF zscore ORB  tp:4/13': 0.3076923076923077,
#  'A LOF zscore ORB  tp:3/8': 0.375,
#  'BSTAR LOF zscore ORB  tp:16/50': 0.32,
#  'ASTAR INNE zscore ORB  tp:26/63': 0.41587301587301584,
#  'C INNE zscore ORB  tp:4/24': 0.19166666666666665,
#  'B INNE zscore ORB  tp:4/13': 0.3384615384615385,
#  'A INNE zscore ORB  tp:2/8': 0.275,
#  'BSTAR INNE zscore ORB  tp:24/50': 0.48,
#  'ASTAR FB zscore ORB  tp:25/63': 0.39999999999999997,
#  'C FB zscore ORB  tp:5/24': 0.21666666666666667,
#  'B FB zscore ORB  tp:3/13': 0.23076923076923078,
#  'A FB zscore ORB  tp:3/8': 0.375,
#  'BSTAR FB zscore ORB  tp:16/50': 0.32,
#  'ASTAR SOS zscore ORB  tp:21/63': 0.3333333333333333,
#  'C SOS zscore ORB  tp:3/24': 0.125,
#  'B SOS zscore ORB  tp:4/13': 0.3076923076923077,
#  'A SOS zscore ORB  tp:2/8': 0.25,
#  'BSTAR SOS zscore ORB  tp:24/50': 0.48,
#  'ASTAR AnoGAN zscore ORB  tp:13/63': 0.20634920634920634,
#  'C AnoGAN zscore ORB  tp:5/24': 0.20833333333333334,
#  'B AnoGAN zscore ORB  tp:3/13': 0.23076923076923078,
#  'A AnoGAN zscore ORB  tp:2/8': 0.25,
#  'BSTAR AnoGAN zscore ORB  tp:5/50': 0.1,
#  'ASTAR LMDD zscore ORB  tp:8/63': 0.12698412698412698,
#  'C LMDD zscore ORB  tp:6/24': 0.25,
#  'B LMDD zscore ORB  tp:3/13': 0.23076923076923078,
#  'A LMDD zscore ORB  tp:3/8': 0.375,
#  'BSTAR LMDD zscore ORB  tp:5/50': 0.1,
#  'ASTAR DeepSVDD zscore ORB  tp:3/63': 0.050793650793650794,
#  'C DeepSVDD zscore ORB  tp:1/24': 0.075,
#  'B DeepSVDD zscore ORB  tp:1/13': 0.12307692307692308,
#  'A DeepSVDD zscore ORB  tp:0/8': 0.075,
#  'BSTAR DeepSVDD zscore ORB  tp:2/50': 0.048,
#  'ASTAR SOGAAL zscore ORB  tp:0/63': 0.0,
#  'C SOGAAL zscore ORB  tp:0/24': 0.0,
#  'B SOGAAL zscore ORB  tp:0/13': 0.0,
#  'A SOGAAL zscore ORB  tp:0/8': 0.0,
#  'BSTAR SOGAAL zscore ORB  tp:0/50': 0.0,
#  'ASTAR OCSVM zscore ORB  tp:0/63': 0.0,
#  'C OCSVM zscore ORB  tp:0/24': 0.0,
#  'B OCSVM zscore ORB  tp:0/13': 0.0,
#  'A OCSVM zscore ORB  tp:0/8': 0.0,
#  'BSTAR OCSVM zscore ORB  tp:0/50': 0.0,
#  'ASTAR KDE zscore ORB  tp:0/63': 0.0,
#  'C KDE zscore ORB  tp:0/24': 0.0,
#  'B KDE zscore ORB  tp:0/13': 0.0,
#  'A KDE zscore ORB  tp:0/8': 0.0,
#  'BSTAR KDE zscore ORB  tp:0/50': 0.0}

# %%
sorted_res = O.outlier_detector_lite.sort_dict_by_value(result_dict)
# Out:
# Dataset Alg   Norm  Feat  TP/TotalBad        tp acc:
# ASTAR ECOD zscore ORB  tp:42/63                0.67
# BSTAR KNN zscore ORB  tp:29/50                 0.58
# BSTAR AvgKNN zscore ORB  tp:29/50              0.58
# BSTAR MedKNN zscore ORB  tp:29/50              0.58
# ASTAR IForest zscore ORB  tp:35/63             0.57
# ASTAR COPOD zscore ORB  tp:35/63               0.56
# ASTAR SOD zscore ORB  tp:35/63                 0.56
# BSTAR IForest zscore ORB  tp:27/50             0.55
# BSTAR Sampling zscore ORB  tp:27/50            0.55
# ASTAR SUOD zscore ORB  tp:34/63                0.54
# ASTAR AE zscore ORB  tp:34/63                  0.54
# ASTAR Sampling zscore ORB  tp:33/63            0.53
# ASTAR VAE zscore ORB  tp:33/63                 0.53
# ASTAR HBOS zscore ORB  tp:33/63                0.52
# ASTAR KNN zscore ORB  tp:33/63                 0.52
# ASTAR AvgKNN zscore ORB  tp:33/63              0.52
# ASTAR MedKNN zscore ORB  tp:33/63              0.52
# ASTAR PCA zscore ORB  tp:33/63                 0.52
# ASTAR COF zscore ORB  tp:33/63                 0.52
# BSTAR COPOD zscore ORB  tp:26/50               0.52
# BSTAR SOD zscore ORB  tp:26/50                 0.52
# BSTAR AE zscore ORB  tp:26/50                  0.52
# ASTAR LODA zscore ORB  tp:32/63                0.51
# BSTAR VAE zscore ORB  tp:25/50                 0.51
# BSTAR LODA zscore ORB  tp:25/50                0.51
# A ECOD zscore ORB  tp:4/8                      0.50
# BSTAR ECOD zscore ORB  tp:25/50                0.50
# A HBOS zscore ORB  tp:4/8                      0.50
# BSTAR HBOS zscore ORB  tp:25/50                0.50
# BSTAR PCA zscore ORB  tp:25/50                 0.50
# A COF zscore ORB  tp:4/8                       0.50
# ASTAR CBLOF zscore ORB  tp:31/63               0.50
# BSTAR SUOD zscore ORB  tp:24/50                0.48
# BSTAR INNE zscore ORB  tp:24/50                0.48
# BSTAR SOS zscore ORB  tp:24/50                 0.48
# B IForest zscore ORB  tp:6/13                  0.48
# B ECOD zscore ORB  tp:6/13                     0.46
# B COPOD zscore ORB  tp:6/13                    0.46
# B SUOD zscore ORB  tp:6/13                     0.46
# B AE zscore ORB  tp:6/13                       0.46
# B VAE zscore ORB  tp:6/13                      0.46
# B HBOS zscore ORB  tp:6/13                     0.46
# B KNN zscore ORB  tp:6/13                      0.46
# B AvgKNN zscore ORB  tp:6/13                   0.46
# B MedKNN zscore ORB  tp:6/13                   0.46
# B PCA zscore ORB  tp:6/13                      0.46
# B COF zscore ORB  tp:6/13                      0.46
# BSTAR CBLOF zscore ORB  tp:21/50               0.44
# B Sampling zscore ORB  tp:5/13                 0.43
# ASTAR LOF zscore ORB  tp:27/63                 0.43
# ASTAR INNE zscore ORB  tp:26/63                0.42
# A IForest zscore ORB  tp:3/8                   0.40
# A Sampling zscore ORB  tp:3/8                  0.40
# B LODA zscore ORB  tp:5/13                     0.40
# ASTAR FB zscore ORB  tp:25/63                  0.40
# B SOD zscore ORB  tp:5/13                      0.38
# A COPOD zscore ORB  tp:3/8                     0.38
# A SOD zscore ORB  tp:3/8                       0.38
# A SUOD zscore ORB  tp:3/8                      0.38
# A AE zscore ORB  tp:3/8                        0.38
# A VAE zscore ORB  tp:3/8                       0.38
# A KNN zscore ORB  tp:3/8                       0.38
# A AvgKNN zscore ORB  tp:3/8                    0.38
# A MedKNN zscore ORB  tp:3/8                    0.38
# A PCA zscore ORB  tp:3/8                       0.38
# C COF zscore ORB  tp:9/24                      0.38
# A LOF zscore ORB  tp:3/8                       0.38
# A FB zscore ORB  tp:3/8                        0.38
# A LMDD zscore ORB  tp:3/8                      0.38
# B CBLOF zscore ORB  tp:4/13                    0.35
# A LODA zscore ORB  tp:2/8                      0.35
# A CBLOF zscore ORB  tp:2/8                     0.35
# BSTAR COF zscore ORB  tp:17/50                 0.34
# B INNE zscore ORB  tp:4/13                     0.34
# C COPOD zscore ORB  tp:8/24                    0.33
# C AE zscore ORB  tp:8/24                       0.33
# C VAE zscore ORB  tp:8/24                      0.33
# C PCA zscore ORB  tp:8/24                      0.33
# ASTAR SOS zscore ORB  tp:21/63                 0.33
# C IForest zscore ORB  tp:7/24                  0.33
# BSTAR LOF zscore ORB  tp:16/50                 0.32
# BSTAR FB zscore ORB  tp:16/50                  0.32
# C Sampling zscore ORB  tp:7/24                 0.31
# B LOF zscore ORB  tp:4/13                      0.31
# B SOS zscore ORB  tp:4/13                      0.31
# C LODA zscore ORB  tp:7/24                     0.30
# C ECOD zscore ORB  tp:7/24                     0.29
# C KNN zscore ORB  tp:7/24                      0.29
# C AvgKNN zscore ORB  tp:7/24                   0.29
# C MedKNN zscore ORB  tp:7/24                   0.29
# A INNE zscore ORB  tp:2/8                      0.28
# C SUOD zscore ORB  tp:6/24                     0.27
# C CBLOF zscore ORB  tp:6/24                    0.25
# C LOF zscore ORB  tp:6/24                      0.25
# A SOS zscore ORB  tp:2/8                       0.25
# A AnoGAN zscore ORB  tp:2/8                    0.25
# C LMDD zscore ORB  tp:6/24                     0.25
# B FB zscore ORB  tp:3/13                       0.23
# B AnoGAN zscore ORB  tp:3/13                   0.23
# B LMDD zscore ORB  tp:3/13                     0.23
# C FB zscore ORB  tp:5/24                       0.22
# C HBOS zscore ORB  tp:5/24                     0.21
# C AnoGAN zscore ORB  tp:5/24                   0.21
# ASTAR AnoGAN zscore ORB  tp:13/63              0.21
# C INNE zscore ORB  tp:4/24                     0.19
# C SOD zscore ORB  tp:4/24                      0.17
# ASTAR LMDD zscore ORB  tp:8/63                 0.13
# C SOS zscore ORB  tp:3/24                      0.12
# B DeepSVDD zscore ORB  tp:1/13                 0.12
# BSTAR AnoGAN zscore ORB  tp:5/50               0.10
# BSTAR LMDD zscore ORB  tp:5/50                 0.10
# C DeepSVDD zscore ORB  tp:1/24                 0.07
# A DeepSVDD zscore ORB  tp:0/8                  0.07
# ASTAR DeepSVDD zscore ORB  tp:3/63             0.05
# BSTAR DeepSVDD zscore ORB  tp:2/50             0.05
# ASTAR SOGAAL zscore ORB  tp:0/63               0.00
# C SOGAAL zscore ORB  tp:0/24                   0.00
# B SOGAAL zscore ORB  tp:0/13                   0.00
# A SOGAAL zscore ORB  tp:0/8                    0.00
# BSTAR SOGAAL zscore ORB  tp:0/50               0.00
# ASTAR OCSVM zscore ORB  tp:0/63                0.00
# C OCSVM zscore ORB  tp:0/24                    0.00
# B OCSVM zscore ORB  tp:0/13                    0.00
# A OCSVM zscore ORB  tp:0/8                     0.00
# BSTAR OCSVM zscore ORB  tp:0/50                0.00
# ASTAR KDE zscore ORB  tp:0/63                  0.00
# C KDE zscore ORB  tp:0/24                      0.00
# B KDE zscore ORB  tp:0/13                      0.00
# A KDE zscore ORB  tp:0/8                       0.00
# BSTAR KDE zscore ORB  tp:0/50                  0.00

# %%
odl.results_to_latex(['/raid/mpsych/ODL/FIXED_FEAT_NORM/ASTAR_custom_orb_zscore_5_3.pkl'], variable='roc_auc')
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset ASTAR}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} \\
#         \midrule
#         ECOD & zscore + ORB & 0.8024 \\
# IForest & zscore + ORB & $0.7482\pm0.0102$ \\
# COPOD & zscore + ORB & 0.7431 \\
# SOD & zscore + ORB & 0.7431 \\
# SUOD & zscore + ORB & $0.7363\pm0.0146$ \\
# AE & zscore + ORB & 0.7346 \\
# Sampling & zscore + ORB & $0.7295\pm0.0148$ \\
# VAE & zscore + ORB & $0.7278\pm0.0034$ \\
# HBOS & zscore + ORB & 0.7262 \\
# KNN & zscore + ORB & 0.7262 \\
# AvgKNN & zscore + ORB & 0.7262 \\
# MedKNN & zscore + ORB & 0.7262 \\
# PCA & zscore + ORB & 0.7262 \\
# COF & zscore + ORB & 0.7262 \\
# LODA & zscore + ORB & $0.7194\pm0.0146$ \\
# CBLOF & zscore + ORB & $0.7126\pm0.0346$ \\
# LOF & zscore + ORB & 0.6753 \\
# INNE & zscore + ORB & $0.6686\pm0.0164$ \\
# FB & zscore + ORB & $0.6601\pm0.0063$ \\
# SOS & zscore + ORB & 0.6245 \\
# AnoGAN & zscore + ORB & 0.5567 \\
# LMDD & zscore + ORB & 0.5144 \\
# SOGAAL & zscore + ORB & 0.5000 \\
# OCSVM & zscore + ORB & 0.5000 \\
# KDE & zscore + ORB & 0.5000 \\
# DeepSVDD & zscore + ORB & $0.4737\pm0.0083$ \\
#
#         \bottomrule
#         \end{tabular}
#         }
#         \end{table}
# '\n        \\begin{table}[!h]\n        \\centering\n        \\label{tab:results}\n        \\caption{ }\n        \\resizebox{\\textwidth}{!}{\n        \\begin{tabular}{ccl}\n        \\toprule\n        \\multicolumn{3}{c}{\\textbf{Dataset ASTAR}} \\\\\n        \\textbf{Algorithm} & \\textbf{Norm. + Feature}  & \\textbf{Roc Auc} \\\\\n        \\midrule\n        ECOD & zscore + ORB & 0.8024 \\\\\nIForest & zscore + ORB & $0.7482\\pm0.0102$ \\\\\nCOPOD & zscore + ORB & 0.7431 \\\\\nSOD & zscore + ORB & 0.7431 \\\\\nSUOD & zscore + ORB & $0.7363\\pm0.0146$ \\\\\nAE & zscore + ORB & 0.7346 \\\\\nSampling & zscore + ORB & $0.7295\\pm0.0148$ \\\\\nVAE & zscore + ORB & $0.7278\\pm0.0034$ \\\\\nHBOS & zscore + ORB & 0.7262 \\\\\nKNN & zscore + ORB & 0.7262 \\\\\nAvgKNN & zscore + ORB & 0.7262 \\\\\nMedKNN & zscore + ORB & 0.7262 \\\\\nPCA & zscore + ORB & 0.7262 \\\\\nCOF & zscore + ORB & 0.7262 \\\\\nLODA & zscore + ORB & $0.7194\\pm0.0146$ \\\\\nCBLOF & zscore + ORB & $0.7126\\pm0.0346$ \\\\\nLOF & zscore + ORB & 0.6753 \\\\\nINNE & zscore + ORB & $0.6686\\pm0.0164$ \\\\\nFB & zscore + ORB & $0.6601\\pm0.0063$ \\\\\nSOS & zscore + ORB & 0.6245 \\\\\nAnoGAN & zscore + ORB & 0.5567 \\\\\nLMDD & zscore + ORB & 0.5144 \\\\\nSOGAAL & zscore + ORB & 0.5000 \\\\\nOCSVM & zscore + ORB & 0.5000 \\\\\nKDE & zscore + ORB & 0.5000 \\\\\nDeepSVDD & zscore + ORB & $0.4737\\pm0.0083$ \\\\\n\n        \\bottomrule\n        \\end{tabular}\n        }\n        \\end{table}\n        '

# %%
res1 = odl.get_best_results_per_dataset(cache_root='/raid/mpsych/ODL/RERUN/', variable="acc_score")
# Out:
# {'A': {'acc_score': 0.92, 'algorithm': 'SOGAAL', 'feat': 'ORB', 'norm': 'Max'},
#  'ASTAR': {'acc_score': 0.937,
#            'algorithm': 'OCSVM',
#            'feat': 'Histogram',
#            'norm': 'zscore'},
#  'B': {'acc_score': 0.89,
#        'algorithm': 'INNE',
#        'feat': 'SIFT',
#        'norm': 'Min-Max'},
#  'BSTAR': {'acc_score': 0.95,
#            'algorithm': 'SOGAAL',
#            'feat': 'ORB',
#            'norm': 'zscore'},
#  'C': {'acc_score': 0.76,
#        'algorithm': 'SOGAAL',
#        'feat': 'Histogram',
#        'norm': 'zscore'}}

# %%
res1 = odl.get_best_results_per_dataset(cache_root='/raid/mpsych/ODL/RERUN/', variable="tp")
# Out:
# {'A': {'algorithm': 'HBOS', 'feat': 'ORB', 'norm': 'Max', 'tp': 4.0},
#  'ASTAR': {'algorithm': 'HBOS',
#            'feat': 'Histogram',
#            'norm': 'zscore',
#            'tp': 9.0},
#  'B': {'algorithm': 'INNE', 'feat': 'SIFT', 'norm': 'Min-Max', 'tp': 6.0},
#  'BSTAR': {'algorithm': 'KNN', 'feat': 'ORB', 'norm': 'zscore', 'tp': 29.0},
#  'C': {'algorithm': 'LODA', 'feat': 'Histogram', 'norm': 'zscore', 'tp': 2.0}}
