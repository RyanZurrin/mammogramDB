# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.insert(0,'../..')
import omama as O

# %%
odl = O.OutlierDetectorLite()

# %%
odl.print_results('/raid/mpsych/ODL/A_custom_1_152923.pkl')
# Out:
# KNN
#     roc_auc 0.44565217391304346 +/- 0.0
#     f1_score 0.0 +/- 0.0
#     acc_score 0.82 +/- 0.0
#     jaccard_score 0.0 +/- 0.0
#     precision_score 0.0 +/- 0.0
#     average_precision 0.08 +/- 0.0
#     recall_score 0.0 +/- 0.0
#     hamming_loss 0.18 +/- 0.0
#     log_loss 6.217059710826943 +/- 0.0
#     tn 82.0 +/- 0.0
#     fp 10.0 +/- 0.0
#     fn 8.0 +/- 0.0
#     tp 0.0 +/- 0.0
# AE
#     roc_auc 0.6494565217391304 +/- 0.0
#     f1_score 0.33333333333333326 +/- 0.0
#     acc_score 0.88 +/- 0.0
#     jaccard_score 0.2 +/- 0.0
#     precision_score 0.3 +/- 0.0
#     average_precision 0.16249999999999998 +/- 0.0
#     recall_score 0.375 +/- 0.0
#     hamming_loss 0.12 +/- 0.0
#     log_loss 4.144709139209396 +/- 0.0
#     tn 85.0 +/- 0.0
#     fp 7.0 +/- 0.0
#     fn 5.0 +/- 0.0
#     tp 3.0 +/- 0.0
# AvgKNN
#     roc_auc 0.44565217391304346 +/- 0.0
#     f1_score 0.0 +/- 0.0
#     acc_score 0.82 +/- 0.0
#     jaccard_score 0.0 +/- 0.0
#     precision_score 0.0 +/- 0.0
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/A_custom_hist_zscore_1_155525.pkl'])
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset A}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Jaccard Score} \\
#         \midrule
#         AnoGAN & zscore + Histogram & 0.0588 \\
# LOF & zscore + Histogram & 0.0588 \\
# CBLOF & zscore + Histogram & 0.0588 \\
# KNN & zscore + Histogram & 0.0588 \\
# MedKNN & zscore + Histogram & 0.0588 \\
# Sampling & zscore + Histogram & 0.0588 \\
# COF & zscore + Histogram & 0.0588 \\
# FB & zscore + Histogram & 0.0588 \\
# LODA & zscore + Histogram & 0.0588 \\
# AE & zscore + Histogram & 0.0000 \\
# VAE & zscore + Histogram & 0.0000 \\
# SOGAAL & zscore + Histogram & 0.0000 \\
# DeepSVDD & zscore + Histogram & 0.0000 \\
# HBOS & zscore + Histogram & 0.0000 \\
# OCSVM & zscore + Histogram & 0.0000 \\
# ...

# %%
odl.display_best_results('/raid/mpsych/ODL/A_custom_hist_robust_1_155536.pkl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2545234/1839403153.py in <module>
# ----> 1 odl.display_best_results('/raid/mpsych/ODL/A_custom_hist_robust_1_155536.pkl')
#
# ~/Projects/omama/_EXPERIMENTS/OUTLIER_DETECTION/../../omama/outlier_detection/outlier_detector_lite.py in display_best_results(self, resultsfile)
#     129         best_tp_alg = ''
#     130         for alg in all_evals.keys():
# --> 131             tp = all_evals[alg][0]['evaluation']['tp']
#     132             print(alg, tp)
#     133             if best_tp < tp:
#
# KeyError: 'tp'

# %%
odl.results_to_latex(['/raid/mpsych/ODL/A_default_10_152542.pkl'], variable="roc_auc")
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset A}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{Roc Auc} \\
#         \midrule
#         INNE & Max + SIFT & $0.7554\pm0.0333$ \\
# SOS & Max + SIFT & $0.7418\pm0.0408$ \\
# SOD & Min-Max + SIFT & $0.6603\pm0.0526$ \\
# IForest & Gaussian + Histogram & $0.6060\pm0.0408$ \\
# LOF & Min-Max + SIFT & $0.5992\pm0.0476$ \\
# FB & Max + SIFT & $0.5924\pm0.0526$ \\
# AE & Max + Histogram & 0.5924 \\
# VAE & Min-Max + Histogram & 0.5924 \\
# HBOS & Gaussian + Histogram & 0.5924 \\
# COPOD & Gaussian + Histogram & 0.5924 \\
# PCA & Gaussian + Histogram & 0.5924 \\
# COF & Gaussian + Histogram & 0.5245 \\
# SUOD & Gaussian + Histogram & 0.5245 \\
# DeepSVDD & Gaussian + Histogram & $0.5109\pm0.0666$ \\
# ...

# %%
odl.results_to_latex(['/raid/mpsych/ODL/A_default_10_152542.pkl'], variable="f1_score")
# Out:
#         \begin{table}[!h]
#         \centering
#         \label{tab:results}
#         \caption{ }
#         \resizebox{\textwidth}{!}{
#         \begin{tabular}{ccl}
#         \toprule
#         \multicolumn{3}{c}{\textbf{Dataset A}} \\
#         \textbf{Algorithm} & \textbf{Norm. + Feature}  & \textbf{F1 Score} \\
#         \midrule
#         INNE & Max + SIFT & $0.5500\pm0.0612$ \\
# SOS & Max + SIFT & $0.5250\pm0.0750$ \\
# SOD & Min-Max + SIFT & $0.3750\pm0.0968$ \\
# IForest & Gaussian + Histogram & $0.2750\pm0.0750$ \\
# LOF & Min-Max + SIFT & $0.2625\pm0.0875$ \\
# AE & Max + Histogram & 0.2500 \\
# VAE & Min-Max + Histogram & 0.2500 \\
# HBOS & Gaussian + Histogram & 0.2500 \\
# COPOD & Gaussian + Histogram & 0.2500 \\
# PCA & Gaussian + Histogram & 0.2500 \\
# FB & Max + SIFT & $0.2500\pm0.0968$ \\
# COF & Gaussian + Histogram & 0.1250 \\
# SUOD & Gaussian + Histogram & 0.1250 \\
# DeepSVDD & Gaussian + Histogram & $0.1000\pm0.1225$ \\
# ...
