# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
plt.rcParams['font.size'] = 14

# plt.rcParams['font.size'] = 20
# gp2.Util.display_image_and_mask(images[100], masks[100])
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('../')
import gp2
import pickle

# %%
SCD1 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_1_3_test.pkl"
SCD2 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_2_3_more.pkl"
SCD3 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_3_3_test.pkl"

# %%
with open(SCD1, 'rb') as f:
    classifier_scores_1, discriminator_scores_1 = pickle.load(f)

with open(SCD2, 'rb') as f:
    classifier_scores_2, discriminator_scores_2 = pickle.load(f)

with open(SCD3, 'rb') as f:
    classifier_scores_3, discriminator_scores_3 = pickle.load(f)

# %%
gp2.Util.plot_combined(
    [classifier_scores_1, classifier_scores_2, classifier_scores_3],
    title="SkinCancer Data",
    initial_classifier_score=(0, .8869)
)

# %%
EBHI1 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_1_5_EBHI_filtered.pkl"
EBHI2 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_2_5_EBHI_filtered.pkl"
EBHI3 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_3_5_EBHI_filtered.pkl"

# %%
with open(EBHI1, 'rb') as f:
    classifier_scores_1, discriminator_scores_1 = pickle.load(f)

with open(EBHI2, 'rb') as f:
    classifier_scores_2, discriminator_scores_2 = pickle.load(f)

with open(EBHI3, 'rb') as f:
    classifier_scores_3, discriminator_scores_3 = pickle.load(f)

# %%
gp2.Util.plot_combined(
    [classifier_scores_1, classifier_scores_2, classifier_scores_3],
    title="EBHI Data",
    initial_classifier_score=(0, .8808)
)

# %%
EXAMPLE1 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_1_5_Example1.pkl"
EXAMPLE2 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_2_5_Example1.pkl"
EXAMPLE3 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_3_5_Example1.pkl"

# %%
with open(EXAMPLE1, 'rb') as f:
    classifier_scores_1, discriminator_scores_1 = pickle.load(f)

with open(EXAMPLE2, 'rb') as f:
    classifier_scores_2, discriminator_scores_2 = pickle.load(f)

with open(EXAMPLE3, 'rb') as f:
    classifier_scores_3, discriminator_scores_3 = pickle.load(f)

# %%
gp2.Util.plot_combined_d(
    [classifier_scores_1, classifier_scores_2, classifier_scores_3],
    [discriminator_scores_1, discriminator_scores_2, discriminator_scores_3],
    title="Toy Example Large Data",
    initial_classifier_score=(0, .8888)
)

# %%
gp2.Util.plot_combined(
    [classifier_scores_1, classifier_scores_2, classifier_scores_3],
    title="Toy Example Large Data",
#     initial_classifier_score=(0, .8888)
)

# %%
COVID1 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_1_10_covid.pkl"
COVID2 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_1_10_covid2.pkl"
COVID3 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_3_10_covid.pkl"

# %%
with open(COVID1, 'rb') as f:
    classifier_scores_1, discriminator_scores_1 = pickle.load(f)

with open(COVID2, 'rb') as f:
    classifier_scores_2, discriminator_scores_2 = pickle.load(f)

with open(COVID3, 'rb') as f:
    classifier_scores_3, discriminator_scores_3 = pickle.load(f)

# %%
gp2.Util.plot_combined(
    [classifier_scores_1, classifier_scores_2, classifier_scores_3],
    title="Covid Data",
#     initial_classifier_score=(0, .5738)
)

# %%
gp2.Util.plot_combined_d(
    [classifier_scores_1, classifier_scores_2, classifier_scores_3],
    [discriminator_scores_1, discriminator_scores_2, discriminator_scores_3],
    title="Covid Data",
    initial_classifier_score=(0, .5738)
)

# %%
FIRESEG1 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_1_3_fireseg.pkl"
FIRESEG2 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_2_3_fireseg.pkl"
FIRESEG3 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_3_3_fireseg.pkl"

# %%
with open(FIRESEG1, 'rb') as f:
    classifier_scores_1, discriminator_scores_1 = pickle.load(f)

with open(FIRESEG2, 'rb') as f:
    classifier_scores_2, discriminator_scores_2 = pickle.load(f)

with open(FIRESEG3, 'rb') as f:
    classifier_scores_3, discriminator_scores_3 = pickle.load(f)

# %%
gp2.Util.plot_combined(
    [classifier_scores_1, classifier_scores_2, classifier_scores_3],
    title="Fire Segmentation Data",
    initial_classifier_score=(0, .4303)
)

# %%
LUNGOPACITY1 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_1_5_LungOpacity.pkl"
LUNGOPACITY2 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_2_5_LungOpacity.pkl"
LUNGOPACITY3 = "/raid/mpsych/OMAMA/GP2/results/kuc_unet2d_0kuc_unet2d_model_3_5_LungOpacity.pkl"

# %%
with open(LUNGOPACITY1, 'rb') as f:
    classifier_scores_1, discriminator_scores_1 = pickle.load(f)

with open(LUNGOPACITY2, 'rb') as f:
    classifier_scores_2, discriminator_scores_2 = pickle.load(f)

with open(LUNGOPACITY3, 'rb') as f:
    classifier_scores_3, discriminator_scores_3 = pickle.load(f)

# %%
gp2.Util.plot_combined(
    [classifier_scores_1, classifier_scores_2, classifier_scores_3],
    title="Lung Opacity Data",
    initial_classifier_score=(0, .9628)
)
