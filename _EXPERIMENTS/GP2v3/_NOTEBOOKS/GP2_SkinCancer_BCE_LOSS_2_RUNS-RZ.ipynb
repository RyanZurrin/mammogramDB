# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
images = np.load('/hpcstor6/scratch01/r/ryan.zurrin001/SkinCancerMNIST/SkinCancer_images.npy')
masks = np.load('/hpcstor6/scratch01/r/ryan.zurrin001/SkinCancerMNIST/SkinCancer_masks.npy')

# %%
images.shape
# Out:
# (12311, 512, 512, 1)

# %%
imshow(images[100])

# %%
masks.shape
# Out:
# (12311, 512, 512, 1)

# %%
imshow(masks[100])

# %%
import sys
sys.path.append('../')
import gp2

# %%
from keras import losses

# %%
loss_fx = losses.BCE

# %%
C = gp2.KUC_UNet2D(loss=loss_fx)
# Out:
# *** GP2  KUC U-Net2D ***
# Working directory: /tmp/tmp0x5ge18wkuc_unet2d

# %%
weights = {
    'A': 0.5,
    'A_train': 0.1,
    'A_val': 0.3,
    'A_test': 0.6,
    'B': 0.3,
    'B_train': 0.7,
    'B_val': 0.1,
    'B_test': 0.2,
    'Z': 0.2
}
PERCENT_TO_REPLACE = 30

# %%
from runner import Runner
R = Runner(verbose=True, workingdir=C.workingdir)
# Out:
# *** GP2 ***
# Working directory: /tmp/tmp0x5ge18wkuc_unet2d
# Verbose mode active!

# %%
R.classifier = C ### use custom classifier

# %%
R.setup_data(images, masks, dataset_size=12311, weights=weights)
# Out:
# Weights OK!

# %%
RUNS = 2

# %%
for run in range(RUNS):
    print('***')
    print('RUN:', run)
    t0 = time.time()
    R.run_classifier(batch_size=16)
    R.run_discriminator()
    l = R.find_machine_labels()
    if l == 0:
        print('No more machine labels.')
        print('TOOK', time.time()-t0, 'seconds')
        break
    R.relabel(percent_to_replace=PERCENT_TO_REPLACE)
    print('TOOK', time.time()-t0, 'seconds')
# Out:
# ***
# RUN: 0
# Epoch 1/100
# 39/39 [==============================] - 37s 687ms/step - loss: 0.5379 - dice_coeff: 0.3096 - val_loss: 0.6324 - val_dice_coeff: 0.2736
# Epoch 2/100
# 39/39 [==============================] - 19s 485ms/step - loss: 0.4792 - dice_coeff: 0.3734 - val_loss: 0.4591 - val_dice_coeff: 0.4496
# Epoch 3/100
# 39/39 [==============================] - 19s 483ms/step - loss: 0.4389 - dice_coeff: 0.4760 - val_loss: 0.4272 - val_dice_coeff: 0.5725
# Epoch 4/100
# 39/39 [==============================] - 19s 483ms/step - loss: 0.4174 - dice_coeff: 0.5160 - val_loss: 0.4138 - val_dice_coeff: 0.5188
# Epoch 5/100
# 39/39 [==============================] - 19s 497ms/step - loss: 0.4184 - dice_coeff: 0.5174 - val_loss: 0.4056 - val_dice_coeff: 0.5295
# Epoch 6/100
# 39/39 [==============================] - 19s 488ms/step - loss: 0.4069 - dice_coeff: 0.5333 - val_loss: 0.4177 - val_dice_coeff: 0.5181
# Epoch 7/100
# 39/39 [==============================] - 19s 486ms/step - loss: 0.3941 - dice_coeff: 0.5428 - val_loss: 0.4020 - val_dice_coeff: 0.5619
# Epoch 8/100
# 39/39 [==============================] - 19s 484ms/step - loss: 0.3893 - dice_coeff: 0.5560 - val_loss: 0.4221 - val_dice_coeff: 0.5252
# Epoch 9/100
# 39/39 [==============================] - 19s 487ms/step - loss: 0.3927 - dice_coeff: 0.5399 - val_loss: 0.3843 - val_dice_coeff: 0.5723
# Epoch 10/100
# 39/39 [==============================] - 19s 498ms/step - loss: 0.3904 - dice_coeff: 0.5537 - val_loss: 0.4130 - val_dice_coeff: 0.5362
# Model saved to: /tmp/tmp0x5ge18wkuc_unet2d/kuc_unet2d_0kuc_unet2d_model
# History saved to: /tmp/tmp0x5ge18wkuc_unet2d/kuc_unet2d_history_0.pkl
# Testing the classifier...
# Model saved to /tmp/tmp0x5ge18wkuc_unet2d/cnnd_0.model
# History saved to /tmp/tmp0x5ge18wkuc_unet2d/cnnd_history_0.pickle
# Testing the discriminator...
# 24/24 [==============================] - 1s 43ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Found 390 machine labels.
# Replacing 130 from 390 !
# D_relabeled_ 130
# point ids 130
# Removed: 130 Filled: 130
# TOOK 521.7588670253754 seconds
# ***
# RUN: 1
# Epoch 1/100
# 47/47 [==============================] - 27s 571ms/step - loss: 0.3969 - dice_coeff: 0.5550 - val_loss: 0.3872 - val_dice_coeff: 0.5583
# Epoch 2/100
# 47/47 [==============================] - 21s 460ms/step - loss: 0.3889 - dice_coeff: 0.5687 - val_loss: 0.3976 - val_dice_coeff: 0.5758
# Epoch 3/100
# 47/47 [==============================] - 21s 453ms/step - loss: 0.4680 - dice_coeff: 0.5336 - val_loss: 0.3887 - val_dice_coeff: 0.5690
# Epoch 4/100
# 47/47 [==============================] - 21s 457ms/step - loss: 0.4221 - dice_coeff: 0.5338 - val_loss: 0.4270 - val_dice_coeff: 0.5038
# Model saved to: /tmp/tmp0x5ge18wkuc_unet2d/kuc_unet2d_1kuc_unet2d_model
# History saved to: /tmp/tmp0x5ge18wkuc_unet2d/kuc_unet2d_history_1.pkl
# Testing the classifier...
# Testing the discriminator...
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Found 367 machine labels.
# Replacing 122 from 367 !
# D_relabeled_ 122
# point ids 122
# Removed: 122 Filled: 122
# TOOK 232.835116147995 seconds

# %%
R.classifier_scores # after 2 runs of GP2
# Out:
# [[0.4532720148563385, 0.5186104774475098],
#  [0.46104758977890015, 0.488956481218338]]

# %%
R.discriminator_scores # after 2 runs of GP2
# Out:
# [[0.0, 1.0], [0.0, 1.0]]

# %%
R.plot() # after 2 runs of GP2

# %%
gp2.Util.visualize_predictions(C, images[1000:1500], masks[1000:1500], num_samples=100) # after 2 runs of GP2
