# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ol = O.OmamaLoader()
data = O.Data(ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.233529 seconds
# load_images              ...took     3.967319 seconds
# csv_to_map               ...took     0.224682 seconds
# load_pickle              ...took     2.120594 seconds
# generate_counts          ...took     1.087276 seconds
# generate_stats           ...took     1.296856 seconds
# total _init              ...took     8.943545 seconds
# total __init__           ...took     8.943620 seconds

# %%
img = data.get_image(dicom_name='2.25.104955924129273171233547445694575239277')

# %%
O.DataHelper.view(img, slice_num=10)

# %%
path = img.filePath

# %%
img.label
# Out:
# 'IndexCancer'

# %%
pred = O.DeepSight.run(path, force_run=True, timing=True)
# Out:
# Running DeepSight on 1 cases, please be patient...
# Time to update cache:  3.4140942096710205
# ...took 131.7560203075409

# %%
pred
# Out:
# {'2.25.104955924129273171233547445694575239277': {'coords': [1692.0,
#    1717.0,
#    1889.0,
#    2053.0],
#   'score': 0.13447412848472595,
#   'slice': 10,
#   'errors': None}}

# %%
O.DataHelper.view(img, slice_num=10, prediction=pred)
