# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
imgs = O.DataHelper.get2D(N=2, randomize=True, timing=True)
# Out:
# get2D                    ...took     0.371871 seconds

# %%
pred = O.DeepSight.run(imgs, timing=True)
# Out:
# Time to parse SOP UIDs:  6.198883056640625e-06
# Time to check cache:  0.6099939346313477
# Running DeepSight on 1 cases, please be patient...
# Time to update cache:  2.2791457176208496
# ...took 8.598405599594116

# %%
pred
# Out:
# {'2.25.14957244908401617009918630795434420399': {'coords': [589.0,
#    1227.0,
#    805.0,
#    1440.0],
#   'score': 0.553355872631073,
#   'errors': None},
#  '2.25.219187304872200819443135870295978314942': {'coords': None,
#   'score': -1,
#   'slice': -1,
#   'errors': ['FAC-30: wrong Patient Orientation values',
#    'GE-110: grid',
#    'GE-140: rows',
#    'GE-150: columns',
#    'GE-170: window width']}}

# %%
O.DataHelper.view(imgs[0], pred)

# %%
O.DataHelper.view(imgs[1], pred)
