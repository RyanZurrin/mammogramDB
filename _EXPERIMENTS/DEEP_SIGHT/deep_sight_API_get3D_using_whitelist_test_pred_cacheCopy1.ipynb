# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
img3d = O.DataHelper.get3D(N=80, cancer=True, randomize=True, config_num=3 , timing=True)
# Out:
# get3D                    ...took   1572.281160 seconds

# %%
pred = O.DeepSight.run(img3d, timing=True)
# Out:
# Time to parse SOP UIDs:  7.295608520507812e-05
# Time to check cache:  0.8765654563903809
# ...took 0.9148983955383301

# %%
pred
# Out:
# {'2.25.262084681787442807721882974791606245538': {'coords': [1578.0,
#    1623.0,
#    1822.0,
#    1844.0],
#   'score': 0.9960236549377441,
#   'slice': 22,
#   'errors': None},
#  '2.25.95957816809386192259138125777133405740': {'coords': [1337.0,
#    1546.0,
#    1623.0,
#    1781.0],
#   'score': 0.9937794208526611,
#   'slice': 45,
#   'errors': None},
#  '2.25.116739489059124772211557458193700104366': {'coords': [1493.0,
#    1059.0,
#    1718.0,
#    1319.0],
#   'score': 0.726158618927002,
#   'slice': 31,
#   'errors': None},
#  '2.25.181464087187805886362407097239859694313': {'coords': None,
#   'score': -1,
#   'slice': -1,
#   'errors': ['FAC-170: modified view']},
#  '2.25.169734382205218427774333608957602371617': {'coords': [1510.0,
#    921.0,
#    1723.0,
#    1167.0],
#   'score': 0.9836750030517578,
#   'slice': 42,
#   'errors': None},
#  '2.25.89706891825846926110133715757578413846': {'coords': [1821.0,
#    432.0,
#    1995.0,
#    736.0],
# ...
