# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O
from omama.deep_sight.deep_sight import build_predictions_cache as bpc

# %%
# bpc('/raid/mpsych/', '/raid/mpsych/cache_files/')
# Out:
# {'2.25.124381528605702917763164197238060295247': {'coords': [1.0,
#    1391.0,
#    196.0,
#    1728.0],
#   'score': 0.7790870666503906,
#   'errors': None},
#  '2.25.217321484352248699030844413496181043774': {'coords': [1.0,
#    2180.0,
#    214.0,
#    2507.0],
#   'score': 0.787968635559082,
#   'errors': None},
#  '2.25.142868473970278527427749501528070356414': {'coords': None,
#   'score': -1,
#   'errors': ['FAC-170: modified view',
#    'HOL-10: image type',
#    'HOL-20: estimated radiographic magnification factor',
#    'HOL-30: photometric interpretation',
#    'HOL-50: bits stored',
#    'HOL-60: high bit',
#    'HOL-110: grid',
#    'HOL-140: rows',
#    'HOL-150: columns',
#    'HOL-180: pixel intensity relationship',
#    'HOL-190: pixel intensity relationship sign',
#    'HOL-200: presentation lut shape']},
#  '2.25.199959862768948666665874411484208115230': {'coords': [1333.0,
#    1144.0,
#    1620.0,
#    1518.0],
#   'score': 0.5009718537330627,
# ...
