# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ol = O.OmamaLoader()
data = O.Data(ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.221736 seconds
# load_images              ...took     3.715727 seconds
# csv_to_map               ...took     0.249938 seconds
# load_pickle              ...took     1.941041 seconds
# generate_counts          ...took     1.028550 seconds
# generate_stats           ...took     1.251097 seconds
# total _init              ...took     8.421422 seconds
# total __init__           ...took     8.421492 seconds

# %%
img = data.get_image(dicom_name='2.25.136972480211972997481011277084585823420')

# %%
O.DataHelper.view(img)

# %%
path = img.filePath

# %%
img.shape
# Out:
# (67, 2457, 1996)

# %%
img.label
# Out:
# 'NonCancer'

# %%
pred = O.DeepSight.run(path, force_run=True, timing=True)
# Out:
# Running DeepSight on 1 cases, please be patient...
# Time to update cache:  3.0654456615448
# ...took 122.88106989860535

# %%
pred
# Out:
# {'2.25.136972480211972997481011277084585823420': {'coords': [1318.0,
#    870.0,
#    1612.0,
#    1103.0],
#   'score': 0.08721521496772766,
#   'slice': 33,
#   'errors': None}}

# %%
O.DataHelper.view(img, slice_num=33, prediction=pred)
