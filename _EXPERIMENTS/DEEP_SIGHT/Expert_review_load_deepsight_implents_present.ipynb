# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ol = O.OmamaLoader()
data = O.Data(ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.222289 seconds
# load_images              ...took     3.665716 seconds
# csv_to_map               ...took     0.275231 seconds
# load_pickle              ...took     1.930493 seconds
# generate_counts          ...took     1.036553 seconds
# generate_stats           ...took     1.240532 seconds
# total _init              ...took     8.382209 seconds
# total __init__           ...took     8.382281 seconds

# %%
img = data.get_image(dicom_name='2.25.249996820574850606012039951068655456961')

# %%
O.DataHelper.view(img)

# %%
path = img.filePath

# %%
img.shape
# Out:
# (44, 2457, 1890)

# %%
img.label
# Out:
# 'IndexCancer'

# %%
pred = O.DeepSight.run(path, force_run=True, timing=True)
# Out:
# Running DeepSight on 1 cases, please be patient...
# Time to update cache:  6.869022369384766
# ...took 110.55458855628967

# %%
pred
# Out:
# {'2.25.249996820574850606012039951068655456961': {'coords': [1653.0,
#    622.0,
#    1865.0,
#    875.0],
#   'score': 0.9590169191360474,
#   'slice': 23,
#   'errors': None}}

# %%
O.DataHelper.view(img, slice_num=23, prediction=pred)
