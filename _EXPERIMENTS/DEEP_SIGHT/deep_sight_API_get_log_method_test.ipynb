# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
log_all = O.DeepSight.get_logs(timing=True) # Will get all the logs present
# Out:
# Time to get all logs:  27.835227489471436

# %%
log_all
# Out:
# {'log_0': {'username': 'ryan.zurrin001',
#   'date_time': '2022-06-14 14:29:02.417327',
#   'total_time': '62.47542691230774',
#   'log_path': '/raid/mpsych/deepsight_out/f714ab10d5bc4e58b0acc1199be304d6/'},
#  'log_1': {'username': 'ryan.zurrin001',
#   'date_time': '2022-06-14 00:04:19.236253',
#   'total_time': '54.30492448806763',
#   'log_path': '/raid/mpsych/deepsight_out/5344d8c156fa422fa9913407247f41ba/'},
#  'log_2': {'username': 'p.bendiksen001',
#   'date_time': '2022-06-02 15:19:58.384789',
#   'total_time': '100.58449721336365',
#   'log_path': '/raid/mpsych/deepsight_out/6758420f732f44429b9eaf5cbdb790ee/'},
#  'log_3': {'username': 'ryan.zurrin001',
#   'date_time': '2022-06-22 14:03:14.092534',
#   'total_time': '0.5403130054473877',
#   'log_path': '/raid/mpsych/deepsight_out/71efdb2aabfc4986bf2d73cf809d4911/'},
#  'log_4': {'username': 'ryan.zurrin001',
#   'date_time': '2022-06-22 11:52:51.534325',
#   'total_time': '0.5538864135742188',
# ...

# %%
logs_name = O.DeepSight.get_logs(username='zurrin001', timing=True) # Will get logs by username
# Out:
# Time to get logs:  3.6111252307891846

# %%
len(logs_name)
# Out:
# 224

# %%
logs_date = O.DeepSight.get_logs(date='06-03', timing=True) # Will get logs by date
# Out:
# Time to get logs:  3.5391199588775635

# %%
len(logs_date)
# Out:
# 0

# %%
logs_name_date = O.DeepSight.get_logs(username='ryan', date='05-31', timing=True) # Will get logs by username
# Out:
# Time to get logs:  0.016773223876953125

# %%
logs_name_date
# Out:
# {'log_0': {'user_name': 'ryan.zurrin001',
#   'date_time': '2022-05-31 08:35:03.790876',
#   'total_time': '82.5755684375763',
#   'current_path': '/tmp/test/deepsightOut/00a7c6b709f34915b3e4ef7fa8b6f768/'},
#  'log_1': {'user_name': 'ryan.zurrin001',
#   'date_time': '2022-05-31 11:09:20.662209',
#   'total_time': '83.05247735977173',
#   'current_path': '/tmp/test/deepsightOut/9b6fe0aa8d324dafa9d9881acf9e8d84/'},
#  'log_2': {'user_name': 'ryan.zurrin001',
#   'date_time': '2022-05-31 08:42:26.663958',
#   'total_time': '150.10684967041016',
#   'current_path': '/tmp/test/deepsightOut/92cc625c82e5493fb0b9b8db94290190/'},
#  'log_3': {'user_name': 'ryan.zurrin001',
#   'date_time': '2022-05-31 11:34:21.779689',
#   'total_time': '84.76761603355408',
#   'current_path': '/tmp/test/deepsightOut/15e5538e261948fa99e225f3706bcdff/'},
#  'log_4': {'user_name': 'ryan.zurrin001',
#   'date_time': '2022-05-31 12:17:49.309584',
#   'total_time': '73.36370253562927',
# ...

# %%
logs_name_date2 = O.DeepSight.get_logs(username='bendiksen001', date='05-26', timing=True) # Will get logs by usernam
# Out:
# Time to get logs:  0.016577482223510742

# %%
logs_name_date2
# Out:
# {'log_0': {'user_name': 'p.bendiksen001',
#   'date_time': '2022-05-26 14:26:48.319509',
#   'total_time': '84.40804934501648',
#   'current_path': '/tmp/test/deepsightOut/6f8972f83a064460bae80bf3d8b8a68e/'},
#  'log_1': {'user_name': 'p.bendiksen001',
#   'date_time': '2022-05-26 14:30:35.204737',
#   'total_time': '84.69259929656982',
#   'current_path': '/tmp/test/deepsightOut/5c4c37e56f6f458fb5da0df5a7a435ed/'},
#  'log_2': {'user_name': 'p.bendiksen001',
#   'date_time': '2022-05-26 14:54:56.240985',
#   'total_time': '5.58110499382019',
#   'current_path': '/tmp/test/deepsightOut/4102812765bb4228a546727bd7cb0d63/'},
#  'log_3': {'user_name': 'p.bendiksen001',
#   'date_time': '2022-05-26 14:15:49.464446',
#   'total_time': '0.1439809799194336',
#   'current_path': '/tmp/test/deepsightOut/29212e4fbe3d405dbdabc951d2bf1c5d/'},
#  'log_4': {'user_name': 'p.bendiksen001',
#   'date_time': '2022-05-26 14:50:06.691888',
#   'total_time': '84.8545937538147',
# ...
