# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
omama_loader = O.OmamaLoader()
data = O.Data(data_loader=omama_loader, load_cache=True)

# %%
img = data.get_image(dicom_name='2.25.102010704025650649750933007907656319278', timing=True)
# Out:
# _get_dicom               ...took     0.254450 seconds
# get_image                ...took     0.857774 seconds

# %%
pred = {"2.25.102010704025650649750933007907656319278": {"coords": [609.0, 820.0, 935.0, 1122.0], "score": 0.7073085308074951}}

# %%
O.DataHelper.view(img, pred) # softer

# %%
# low quality images: 2.25.102211908111393541900833018975603374039

# %%
# high end inages: 2.25.102010704025650649750933007907656319278
