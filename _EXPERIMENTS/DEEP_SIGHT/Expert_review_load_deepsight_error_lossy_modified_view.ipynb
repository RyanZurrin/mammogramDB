# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ol = O.OmamaLoader()
data = O.Data(ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.239037 seconds
# load_images              ...took     4.008768 seconds
# csv_to_map               ...took     0.225706 seconds
# load_pickle              ...took     2.472683 seconds
# generate_counts          ...took     1.184702 seconds
# generate_stats           ...took     1.401506 seconds
# total _init              ...took     9.547290 seconds
# total __init__           ...took     9.547361 seconds

# %%
img = data.get_image(dicom_name='2.25.107519176330803835582597548500949363025')

# %%
O.DataHelper.view(img, slice_num=15)

# %%
O.DataHelper.view(img)

# %%
path = img.filePath

# %%
img.label
# Out:
# 'IndexCancer'

# %%
pred = O.DeepSight.run(path, force_run=True, timing=True)
# Out:
# Running DeepSight on 1 cases, please be patient...
# Time to update cache:  3.2942898273468018
# ...took 129.63103938102722

# %%
pred
# Out:
# {'2.25.107519176330803835582597548500949363025': {'coords': [1844.0,
#    599.0,
#    1995.0,
#    902.0],
#   'score': 0.9546550512313843,
#   'slice': 28,
#   'errors': None}}

# %%
O.DataHelper.view(img, slice_num=28, prediction=pred)
