# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
imgs = O.DataHelper.get2D(N=50, cancer=False, timing=True)
# Out:
# get2D                    ...took    31.127723 seconds

# %%
pred = O.DeepSight.run(imgs, timing=True)
# Out:
# Time to parse SOP UIDs:  0.00011515617370605469
# Time to check cache:  1.684443473815918
# ...took 1.7154991626739502

# %%
pred
# Out:
# {'2.25.119403010146292111130118207990186551199': {'coords': [26.0,
#    2714.0,
#    230.0,
#    2832.0],
#   'score': 0.04587244614958763,
#   'errors': None},
#  '2.25.214600937758118091934649285423608587441': {'coords': [1566.0,
#    1365.0,
#    1875.0,
#    1677.0],
#   'score': 0.03495284914970398,
#   'errors': None},
#  '2.25.327701373051007081828181561095836790377': {'coords': [590.0,
#    782.0,
#    923.0,
#    1084.0],
#   'score': 0.029667750000953674,
#   'errors': None},
#  '2.25.97161058065485149118059870586506470816': {'coords': [2004.0,
#    894.0,
#    2346.0,
#    1194.0],
#   'score': 0.04895300418138504,
#   'errors': None},
#  '2.25.127461109080365862090076836140412024743': {'coords': [1375.0,
#    717.0,
#    1619.0,
#    939.0],
#   'score': 0.5200059413909912,
#   'errors': None},
#  '2.25.183253575408022210904074277014430330058': {'coords': [1143.0,
#    1367.0,
#    1436.0,
#    1625.0],
#   'score': 0.03832092508673668,
#   'errors': None},
# ...

# %%
O.DataHelper.view(imgs[10], pred)

# %%
O.DataHelper.view(imgs[11], pred)

# %%
O.DataHelper.view(imgs[20], pred)

# %%
O.DataHelper.view(imgs[1], pred)

# %%
O.DataHelper.view(imgs[41], pred, normalize=True)

# %%
O.DataHelper.view(imgs[0], pred) # normal

# %%
O.DataHelper.view(imgs[0], pred)

# %%
O.DataHelper.view(imgs[1], pred) # normal

# %%
imgs[0].filePath
# Out:
# '/raid/data01/deephealth/dh_dcm_ast/2.25.140444855925922455252200839492407749678/DXm.2.25.335172376966778698150011324426234481179'
