# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ol = O.OmamaLoader()
data = O.Data(ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.610801 seconds
# load_images              ...took    24.599045 seconds
# csv_to_map               ...took     0.444850 seconds
# load_pickle              ...took     4.272059 seconds
# generate_counts          ...took     2.097261 seconds
# generate_stats           ...took     2.501784 seconds
# total _init              ...took    34.556473 seconds
# total __init__           ...took    34.571996 seconds

# %%
img = data.get_image(dicom_name='2.25.123204232252392180492801746224515939015')

# %%
O.DataHelper.view(img, slice_num=40)

# %%
img.shape
# Out:
# (77, 2457, 1996)

# %%
path = img.filePath

# %%
img.label
# Out:
# 'IndexCancer'

# %%
pred = O.DeepSight.run(path, timing=True)
# Out:
# Time to parse SOP UIDs:  5.245208740234375e-06
# Time to check cache:  1.949657678604126
# ...took 2.0985634326934814

# %%
pred
# Out:
# {'2.25.123204232252392180492801746224515939015': {'coords': [1776.0,
#    1344.0,
#    1990.0,
#    1657.0],
#   'score': 0.16971763968467712,
#   'slice': 44,
#   'errors': None}}

# %%
O.DataHelper.view(img, slice_num=44, prediction=pred)
