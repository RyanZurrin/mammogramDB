# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ol = O.OmamaLoader()
data = O.Data(ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.222190 seconds
# load_images              ...took     3.681515 seconds
# csv_to_map               ...took     0.273857 seconds
# load_pickle              ...took     1.923821 seconds
# generate_counts          ...took     1.039910 seconds
# generate_stats           ...took     1.256256 seconds
# total _init              ...took     8.409493 seconds
# total __init__           ...took     8.409564 seconds

# %%
img = data.get_image(dicom_name='2.25.55227903982733461106311903002569068704')

# %%
O.DataHelper.view(img)

# %%
path = img.filePath

# %%
img.shape
# Out:
# (67, 2457, 1890)

# %%
img.label
# Out:
# 'NonCancer'

# %%
pred = O.DeepSight.run(path, force_run=True, timing=True)
# Out:
# Running DeepSight on 1 cases, please be patient...
# Time to update cache:  3.2969179153442383
# ...took 118.79368042945862

# %%
pred
# Out:
# {'2.25.55227903982733461106311903002569068704': {'coords': [1483.0,
#    550.0,
#    1721.0,
#    848.0],
#   'score': 0.13690325617790222,
#   'slice': 36,
#   'errors': None}}

# %%
O.DataHelper.view(img, slice_num=36, prediction=pred)
