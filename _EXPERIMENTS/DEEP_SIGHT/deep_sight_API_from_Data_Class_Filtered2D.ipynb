# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
omama_loader = O.OmamaLoader(config_num=35)
data = O.Data(data_loader=omama_loader,load_cache=True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=11, 3D=0, 2D=11),
#           dh_dh0new=namespace(total=234, 3D=0, 2D=234),
#           dh_dcm_ast=namespace(total=163323, 3D=0, 2D=163323),
#           total_all_dicoms=163568,
#           total_2d_all=163568,
#           total_3d_all=0,
#           total_2d_cancer=5803,
#           total_2d_preindex=1548,
#           total_2d_noncancer=156217,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=5803,
#           total_preindex=1548,
#           total_noncancer=156217,
#           total_no_label=0))

# %%
data[33]
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 192
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.103897187055468918776130569982539173423
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.4
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_364'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', '']
# ...

# %%
pred = O.DeepSight.run(data)

# %%
id_val = 162000

# %%
identifier = data[id_val].SOPInstanceUID

# %%
len(pred)
# Out:
# 163568

# %%
path = '/raid/data01/deephealth/dh_dcm_ast/2.25.202558831967215680366152357647285946741/DXm.2.25.175866744091832141414914115591532377059'

# %%
O.DataHelper.view(path, prediction=pred)
# Out:
# type of data:  <class 'omama.data.Data'>
# bb: [291, 1004, 560, 1225]

# %%
O.DataHelper.view(id_val, histogram=True)

# %%
pred[identifier]

# %%
import os
npz_files = sorted([f for f in os.listdir('/raid/mpsych/OMAMA/DATA/data/2d/') if f.endswith('.npz')])

# %%
len(npz_files)
# Out:
# 163568

# %%
npz_files[961]
# Out:
# '2.25.100438643578095519523176043748946097574.npz'

# %%
data.get_image(dicom_name='2.25.175866744091832141414914115591532377059')
# Out:
# namespace(filePath='/raid/data01/deephealth/dh_dcm_ast/2.25.202558831967215680366152357647285946741/DXm.2.25.175866744091832141414914115591532377059',
#           SOPInstanceUID='2.25.175866744091832141414914115591532377059',
#           StudyInstanceUID='2.25.202558831967215680366152357647285946741',
#           PatientID='DHY5GC70SPA4',
#           InstanceNumber="1",
#           label='PreIndexCancer',
#           imageLaterality='L',
#           shape=(2294, 1914),
#           metadata=None,
#           pixels=array([[ 603,  610,  613, ...,  608,  608,  609],
#                         [ 599,  609,  614, ...,  605,  609,  610],
#                         [ 599,  610,  613, ...,  605,  606,  607],
#                         ...,
#                         [3025, 3052, 3072, ...,  608,  610,  609],
#                         [3035, 3042, 3072, ...,  609,  606,  605],
#                         [3044, 3055, 3057, ...,  603,  607,  609]], dtype=uint16))
