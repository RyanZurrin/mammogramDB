# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
# Will get all the logs present in order to see a list of potential file names to use in the get_predictions method 
log_all = O.DeepSight.get_logs(timing=True)
# Out:
# Time to get all logs:  3.547574520111084

# %%
log_all
# Out:
# {'log_0': {'username': 'ryan.zurrin001',
#   'date_time': '2022-06-14 14:29:02.417327',
#   'total_time': '62.47542691230774',
#   'log_path': '/raid/mpsych/deepsight_out/f714ab10d5bc4e58b0acc1199be304d6/'},
#  'log_1': {'username': 'ryan.zurrin001',
#   'date_time': '2022-06-14 00:04:19.236253',
#   'total_time': '54.30492448806763',
#   'log_path': '/raid/mpsych/deepsight_out/5344d8c156fa422fa9913407247f41ba/'},
#  'log_2': {'username': 'p.bendiksen001',
#   'date_time': '2022-06-02 15:19:58.384789',
#   'total_time': '100.58449721336365',
#   'log_path': '/raid/mpsych/deepsight_out/6758420f732f44429b9eaf5cbdb790ee/'},
#  'log_3': {'username': 'ryan.zurrin001',
#   'date_time': '2022-06-22 14:03:14.092534',
#   'total_time': '0.5403130054473877',
#   'log_path': '/raid/mpsych/deepsight_out/71efdb2aabfc4986bf2d73cf809d4911/'},
#  'log_4': {'username': 'ryan.zurrin001',
#   'date_time': '2022-06-22 11:52:51.534325',
#   'total_time': '0.5538864135742188',
# ...

# %%
# only passing the file name from the log_path will give you the predictions for that classifier run
pred = O.DeepSight.get_predictions('eb38c7038b6c4104beaf92d4d70287df')

# %%
pred
# Out:
# {'2.25.119403010146292111130118207990186551199': {'coords': [26.0,
#    2714.0,
#    230.0,
#    2832.0],
#   'score': 0.04587244614958763,
#   'errors': None}}

# %%
pred2 = O.DeepSight.get_predictions('cbeb52ff47714ac5b7de2a6a658cc2e6')

# %%
pred2
# Out:
# {'2.25.124381528605702917763164197238060295247': {'coords': [1.0,
#    1391.0,
#    196.0,
#    1728.0],
#   'score': 0.7790870666503906,
#   'errors': None},
#  '2.25.217321484352248699030844413496181043774': {'coords': [1.0,
#    2180.0,
#    214.0,
#    2507.0],
#   'score': 0.787968635559082,
#   'errors': None},
#  '2.25.38579031505102571256361347111343069904': {'coords': [23.0,
#    615.0,
#    214.0,
#    924.0],
#   'score': 0.7993554472923279,
#   'errors': None},
#  '2.25.41840648022000818954245230828971871497': {'coords': [916.0,
#    1685.0,
#    1250.0,
#    1866.0],
#   'score': 0.32470428943634033,
#   'errors': None},
#  '2.25.145073787325764149610466456418871231507': {'coords': [224.0,
#    683.0,
#    504.0,
#    927.0],
#   'score': 0.7760008573532104,
#   'errors': None},
#  '2.25.215618008885862934193222128967779925929': {'coords': [252.0,
#    775.0,
#    387.0,
#    875.0],
#   'score': 0.7982940673828125,
#   'errors': None},
# ...

# %%
len(pred2)
# Out:
# 500
