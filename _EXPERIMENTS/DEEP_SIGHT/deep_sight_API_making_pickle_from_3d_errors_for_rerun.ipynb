# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
error_file = open("../../omama/deep_sight/whitelists/errors_3d.txt")

# %%
error_paths = error_file.readlines()

# %%
error_paths
# Out:
# ['/raid/data01/deephealth/dh_dh0new/2.25.138052562257905534235263277460310139068/BT.2.25.104955924129273171233547445694575239277\n',
#  '/raid/data01/deephealth/dh_dh0new/2.25.317635727200043412177341888617278834793/BT.2.25.107519176330803835582597548500949363025\n',
#  '/raid/data01/deephealth/dh_dh0new/2.25.317635727200043412177341888617278834793/BT.2.25.114458759393930823942949754183553217402\n',
#  '/raid/data01/deephealth/dh_dh0new/2.25.262566359948244095469337943835260552622/BT.2.25.118952582675528413466305920731594886792\n',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.248759284138013060096863671623117297486/BT.2.25.123204232252392180492801746224515939015\n',
#  '/raid/data01/deephealth/dh_dh0new/2.25.27726273533169908162503161857515359113/BT.2.25.1262248269025193691294684459671984655\n',
#  '/raid/data01/deephealth/dh_dh2/2.25.312090746627037060920757258886246763519/BT.2.25.130571646392226568584187789158139575902\n',
# ...

# %%
stripped_line = [s.rstrip() for s in error_paths]

# %%
stripped_line
# Out:
# ['/raid/data01/deephealth/dh_dh0new/2.25.138052562257905534235263277460310139068/BT.2.25.104955924129273171233547445694575239277',
#  '/raid/data01/deephealth/dh_dh0new/2.25.317635727200043412177341888617278834793/BT.2.25.107519176330803835582597548500949363025',
#  '/raid/data01/deephealth/dh_dh0new/2.25.317635727200043412177341888617278834793/BT.2.25.114458759393930823942949754183553217402',
#  '/raid/data01/deephealth/dh_dh0new/2.25.262566359948244095469337943835260552622/BT.2.25.118952582675528413466305920731594886792',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.248759284138013060096863671623117297486/BT.2.25.123204232252392180492801746224515939015',
#  '/raid/data01/deephealth/dh_dh0new/2.25.27726273533169908162503161857515359113/BT.2.25.1262248269025193691294684459671984655',
#  '/raid/data01/deephealth/dh_dh2/2.25.312090746627037060920757258886246763519/BT.2.25.130571646392226568584187789158139575902',
# ...

# %%
len(stripped_line)
# Out:
# 9962

# %%
import pickle
with open('error_rerun.pkl', 'wb') as f:
    pickle.dump(stripped_line, f)

# %%
file = open("error_rerun.pkl",'rb')
object_file = pickle.load(file)

# %%
object_file
# Out:
# ['/raid/data01/deephealth/dh_dh0new/2.25.138052562257905534235263277460310139068/BT.2.25.104955924129273171233547445694575239277',
#  '/raid/data01/deephealth/dh_dh0new/2.25.317635727200043412177341888617278834793/BT.2.25.107519176330803835582597548500949363025',
#  '/raid/data01/deephealth/dh_dh0new/2.25.317635727200043412177341888617278834793/BT.2.25.114458759393930823942949754183553217402',
#  '/raid/data01/deephealth/dh_dh0new/2.25.262566359948244095469337943835260552622/BT.2.25.118952582675528413466305920731594886792',
#  '/raid/data01/deephealth/dh_dcm_ast/2.25.248759284138013060096863671623117297486/BT.2.25.123204232252392180492801746224515939015',
#  '/raid/data01/deephealth/dh_dh0new/2.25.27726273533169908162503161857515359113/BT.2.25.1262248269025193691294684459671984655',
#  '/raid/data01/deephealth/dh_dh2/2.25.312090746627037060920757258886246763519/BT.2.25.130571646392226568584187789158139575902',
# ...

# %%
len(object_file)
# Out:
# 9962
