# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
conf = O.ConfusionMatrix(config_num=3, threshold=0.9, timing=True)
conf.build() # .90 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.22592949867248535
# Time to initialize ConfusionMatrix: 1.7448146343231201

# %%
conf = O.ConfusionMatrix(config_num=3, threshold=0.8, timing=True)
conf.build() # .80 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.21727395057678223
# Time to initialize ConfusionMatrix: 1.0526690483093262

# %%
conf = O.ConfusionMatrix(config_num=3, threshold=0.7, timing=True)
conf.build() # .70 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.21628236770629883
# Time to initialize ConfusionMatrix: 0.8601102828979492

# %%
conf = O.ConfusionMatrix(config_num=3, threshold=0.6, timing=True)
conf.build() # .60 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.21664047241210938
# Time to initialize ConfusionMatrix: 1.048250675201416

# %%
conf = O.ConfusionMatrix(config_num=3, threshold=0.5, timing=True)
conf.build() # .60 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.2160801887512207
# Time to initialize ConfusionMatrix: 1.0234863758087158
