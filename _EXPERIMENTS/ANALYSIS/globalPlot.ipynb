# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import plotly.express as px
import pickle
import seaborn as sns
import omama.global_df as g
import os
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2419694/1023204696.py in <module>
# ----> 1 import plotly.express as px
#       2 import pickle
#       3 import seaborn as sns
#       4 import omama.global_df as g
#       5 import os
#
# ModuleNotFoundError: No module named 'plotly'

# %%
pd.options.plotting.backend = "plotly"

# %%
path = '/home/neha.goyal001/deepHealth/'

# %%
global_plot = g.Global_Plot(path)
# Out:
# Total dicoms available
# Counter({'2D': 895834, '3D': 72157})
# Counter({'NonCancer': 922925, 'No Label information': 27810, 'IndexCancer': 15341, 'PreIndexCancer': 1915})
# Counter({'L': 484410, 'R': 483458, 'B': 123})

# %%
indexPre_df = global_plot.index_pre()

# %%
global_df = global_plot.pltDF(executionTime=True)
# Out:
# /home/neha.goyal001/deepHealth/omama/global_df.py:117: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Shape'] = df1['Shape'].str.replace('(2457, 1890,.*)','2457, 1890, x)')
# /home/neha.goyal001/deepHealth/omama/global_df.py:118: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Shape'] = df1['Shape'].str.replace('(2457, 1996,.*)','2457, 1996, x)')
# /home/neha.goyal001/deepHealth/omama/global_df.py:122: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df1 = df1[~df1["Shape"].str.contains(pattern)]
# ...took  8.905030965805054 seconds
# For 2D dicoms in global
# Counter({'NonCancer': 855763, 'No Label information': 23191, 'IndexCancer': 14965, 'PreIndexCancer': 1915})
# Counter({'L': 448193, 'R': 447518, 'B': 123})
# Counter({'2D': 895834})
#
#
# For 3D dicoms in global
# ...

# %%
df_plot = indexPre_df.groupby(['label','folder', 'image', 'Imagelaterality']).size().reset_index().pivot(columns=['Imagelaterality'], index=['label','folder', 'image'], values=0)

df_plot.plot(kind='bar', stacked=True, cmap = 'Greens')
plt.title("image and label across different folders")
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
px.bar(data_frame = , x = 'image', facet_row='label', color = 'Imagelaterality', barmode = 'stack')
