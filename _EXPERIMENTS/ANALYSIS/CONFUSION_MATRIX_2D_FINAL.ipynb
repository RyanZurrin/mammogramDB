# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
data = O.Data(data_loader=O.OmamaLoader(config_num=35), load_cache=True, timing=True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# load_studies             ...took     0.287771 seconds
# load_images              ...took     0.104351 seconds
# csv_to_map               ...took     0.217263 seconds
# load_pickle              ...took     0.375711 seconds
# generate_counts          ...took     0.177797 seconds
# generate_stats           ...took     0.239272 seconds
# total _init              ...took     1.412130 seconds
# total __init__           ...took     1.412370 seconds

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=11, 3D=0, 2D=11),
#           dh_dh0new=namespace(total=234, 3D=0, 2D=234),
#           dh_dcm_ast=namespace(total=163323, 3D=0, 2D=163323),
#           total_all_dicoms=163568,
#           total_2d_all=163568,
#           total_3d_all=0,
#           total_2d_cancer=5803,
#           total_2d_preindex=1548,
#           total_2d_noncancer=156217,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=5803,
#           total_preindex=1548,
#           total_noncancer=156217,
#           total_no_label=0))

# %%
conf = O.ConfusionMatrix(config_num=35, threshold=0.9, timing=True)
conf.build()
# Out:
# Initializing ConfusionMatrix
# Loading config data from ini file
# Time to generate data: 0.6137654781341553
# Time to initialize ConfusionMatrix: 1.559070110321045
# Accuracy: 0.9598
# Precision: 0.7714
# Recall: 0.1510
# F1 Score: 0.2526
# Specificity: 0.9979

# %%
conf = O.ConfusionMatrix(config_num=35, threshold=0.8, timing=True)
conf.build() # .80 threshold
# Out:
# Initializing ConfusionMatrix
# Loading config data from ini file
# Time to generate data: 0.637047529220581
# Time to initialize ConfusionMatrix: 1.5828096866607666
# Accuracy: 0.9594
# Precision: 0.5987
# Recall: 0.2913
# F1 Score: 0.3919
# Specificity: 0.9908

# %%
conf = O.ConfusionMatrix(config_num=35, threshold=0.7, timing=True)
conf.build() # .70 threshold
# Out:
# Initializing ConfusionMatrix
# Loading config data from ini file
# Time to generate data: 0.579845666885376
# Time to initialize ConfusionMatrix: 1.5504059791564941
# Accuracy: 0.9507
# Precision: 0.4463
# Recall: 0.4042
# F1 Score: 0.4242
# Specificity: 0.9764

# %%
conf = O.ConfusionMatrix(config_num=35, threshold=0.6, timing=True)
conf.build() # .60 threshold
# Out:
# Initializing ConfusionMatrix
# Loading config data from ini file
# Time to generate data: 0.6209161281585693
# Time to initialize ConfusionMatrix: 1.3514509201049805
# Accuracy: 0.9308
# Precision: 0.3253
# Recall: 0.5035
# F1 Score: 0.3952
# Specificity: 0.9509

# %%
conf = O.ConfusionMatrix(config_num=35, threshold=0.5, timing=True)
conf.build() # .60 threshold
# Out:
# Initializing ConfusionMatrix
# Loading config data from ini file
# Time to generate data: 0.620276689529419
# Time to initialize ConfusionMatrix: 1.54268479347229
# Accuracy: 0.8968
# Precision: 0.2392
# Recall: 0.5946
# F1 Score: 0.3412
# Specificity: 0.9110
