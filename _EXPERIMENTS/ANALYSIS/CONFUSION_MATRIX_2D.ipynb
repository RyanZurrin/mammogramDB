# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
conf = O.ConfusionMatrix(config_num=2, threshold=0.9, timing=True)
conf.build() # .90 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.624842643737793
# Time to initialize ConfusionMatrix: 2.9392096996307373

# %%
conf = O.ConfusionMatrix(config_num=2, threshold=0.8, timing=True)
conf.build() # .80 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.622657060623169
# Time to initialize ConfusionMatrix: 1.4908273220062256

# %%
conf = O.ConfusionMatrix(config_num=2, threshold=0.7, timing=True)
conf.build() # .70 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.6150410175323486
# Time to initialize ConfusionMatrix: 1.2928194999694824

# %%
conf = O.ConfusionMatrix(config_num=2, threshold=0.6, timing=True)
conf.build() # .60 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.6158719062805176
# Time to initialize ConfusionMatrix: 1.4551706314086914

# %%
conf = O.ConfusionMatrix(config_num=2, threshold=0.5, timing=True)
conf.build() # .60 threshold
# Out:
# Initializing ConfusionMatrix
# Time to generate data: 0.6161444187164307
# Time to initialize ConfusionMatrix: 1.4376294612884521
