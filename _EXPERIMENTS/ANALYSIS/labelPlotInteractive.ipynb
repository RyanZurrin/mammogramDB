# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Out:
# ...
#   Using cached python_gdcm-3.0.10.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydicom as dicom

# %%
import pickle
import seaborn as sns

# %%
import omama.plot_df as p
import os
import pandas as pd

# %%
path = './pickle/'
folder = 'dh_dh2'

# %%
plot = p.Plot(path, folder)
# Out:
# For dicoms in folder dh_dh2
# Counter({'NonCancer': 20727, 'No Label information': 1380, 'IndexCancer': 37})
# Counter({'None': 9363, 'R': 6421, 'L': 6360})
# Counter({'2D': 12781, '3D': 9363})

# %% [markdown]
# plot = p.Plot(path, folder)

# %%
indexPre_dh2, notCancerPre_dh2, df_dh2 = plot.pltDF(executionTime=True)
# Out:
# ...took  0.7897815704345703 seconds
# For 2D dicoms in folder dh_dh2
# Counter({'NonCancer': 11976, 'No Label information': 768, 'IndexCancer': 37})
# Counter({'R': 6421, 'L': 6360})
# Counter({'2D': 12781})
#
#
# For 3D dicoms in folder dh_dh2
# Counter({'NonCancer': 8751, 'No Label information': 612})
# Counter({'None': 9363})
# Counter({'3D': 9363})

# %%
folder = 'dh_dh0new'
plot = p.Plot(path, folder)
# Out:
# For dicoms in folder dh_dh0new
# Counter({'NonCancer': 117752, 'No Label information': 8333, 'IndexCancer': 375})
# Counter({'None': 62736, 'L': 32049, 'R': 31675})
# Counter({'2D': 63724, '3D': 62736})

# %%
indexPre_dh0new, notCancerPre_dh0new, df_dh0new = plot.pltDF(executionTime=True)
# Out:
# ...took  1.2356624603271484 seconds
# For 2D dicoms in folder dh_dh0new
# Counter({'NonCancer': 59023, 'No Label information': 4326, 'IndexCancer': 375})
# Counter({'L': 32049, 'R': 31675})
# Counter({'2D': 63724})
#
#
# For 3D dicoms in folder dh_dh0new
# Counter({'NonCancer': 58729, 'No Label information': 4007})
# Counter({'None': 62736})
# Counter({'3D': 62736})
