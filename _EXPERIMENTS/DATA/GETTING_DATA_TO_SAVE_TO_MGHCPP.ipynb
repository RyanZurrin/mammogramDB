# %%
# %pylab inline
import sys
sys.path.insert(0,'../..')
import omama as O
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ol = O.OmamaLoader(config_num=7)
data = O.Data(ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.000538 seconds
# load_images              ...took     0.000117 seconds
# csv_to_map               ...took     0.228037 seconds
# load_pickle              ...took     0.000501 seconds
# generate_counts          ...took     0.000160 seconds
# generate_stats           ...took     0.000135 seconds
# total _init              ...took     0.240606 seconds
# total __init__           ...took     0.240674 seconds

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=0, 3D=0, 2D=0),
#           dh_dh0new=namespace(total=0, 3D=0, 2D=0),
#           dh_dcm_ast=namespace(total=100, 3D=0, 2D=100),
#           total_all_dicoms=100,
#           total_2d_all=100,
#           total_3d_all=0,
#           total_2d_cancer=6,
#           total_2d_preindex=1,
#           total_2d_noncancer=93,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=6,
#           total_preindex=1,
#           total_noncancer=93,
#           total_no_label=0))

# %%
O.DataHelper.store_all(data, '/home/ryan.zurrin001/Projects/dataset')
# Out:
# <class 'pydicom.dataset.FileDataset'>
# DXm_2_25_119403010146292111130118207990186551199.DCM
# /home/ryan.zurrin001/Projects/dataset/DXm_2_25_119403010146292111130118207990186551199.DCM
# <class 'pydicom.dataset.FileDataset'>
# DXm_2_25_127461109080365862090076836140412024743.DCM
# /home/ryan.zurrin001/Projects/dataset/DXm_2_25_127461109080365862090076836140412024743.DCM
# <class 'pydicom.dataset.FileDataset'>
# DXm_2_25_275395047981175631229220204776148301030.DCM
# /home/ryan.zurrin001/Projects/dataset/DXm_2_25_275395047981175631229220204776148301030.DCM
# <class 'pydicom.dataset.FileDataset'>
# DXm_2_25_109671841718419919187642480808451180070.DCM
# /home/ryan.zurrin001/Projects/dataset/DXm_2_25_109671841718419919187642480808451180070.DCM
# <class 'pydicom.dataset.FileDataset'>
# DXm_2_25_118275985486690043433875765475611783958.DCM
# /home/ryan.zurrin001/Projects/dataset/DXm_2_25_118275985486690043433875765475611783958.DCM
# <class 'pydicom.dataset.FileDataset'>
# ...
