# %%
import sys
import time
# %pylab inline
# %load_ext autoreload
# %autoreload 2
sys.path.append('../..')
import omama as O
import  pydicom
import cv2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ds = pydicom.dcmread('/raid/data01/deephealth/dh_dcm_ast/2.25.2456805794252069664778269809362896459/DXm.2.25.194720049696376001555667454493978604449')

# %%
pixel_array = ds.pixel_array

# %%
pixel_array.dtype
# Out:
# dtype('uint16')

# %%
imshow(pixel_array)

# %%
cv2.imwrite("testPNG.png", pixel_array)
# Out:
# True

# %%
image_path = "testPNG.png"
image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)  # Unchanged flag loads the image as is


plt.figure(figsize=(10, 10))  # Set the figure size
plt.imshow(image)  # Assuming grayscale. Remove cmap if RGB.
plt.axis('off')  # Hide axes
plt.show()

# %%
# Step 2: Normalize for visualization
normalized_image = (image - np.min(image)) / (np.max(image) - np.min(image))

# %%
plt.figure(figsize=(10, 10))  # Set the figure size
plt.imshow(normalized_image)
plt.axis('off')  # Hide axes
plt.show()

# %%
bit_depth = image.dtype

# %%
bit_depth
# Out:
# dtype('uint16')
