# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
# ol = O.OmamaLoader(config_num=29)
# data = O.Data(data_loader=ol, cache=True, timing=True)
# Out:
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# load_studies             ...took     0.113236 seconds
# load_images              ...took     0.037864 seconds
# csv_to_map               ...took     0.429631 seconds
# 1000                     ...took     2.660940 seconds
# 2000                     ...took     5.388091 seconds
# 3000                     ...took     8.028878 seconds
# 4000                     ...took    10.717390 seconds
# 5000                     ...took    13.381723 seconds
# 6000                     ...took    16.214377 seconds
# 7000                     ...took    18.791353 seconds
# 8000                     ...took    21.415076 seconds
# 9000                     ...took    24.061183 seconds
# 10000                    ...took    26.784574 seconds
# 11000                    ...took    29.397904 seconds
# 12000                    ...took    32.034175 seconds
# 13000                    ...took    34.632759 seconds
# ...

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=5, 3D=0, 2D=5),
#           dh_dh0new=namespace(total=78, 3D=0, 2D=78),
#           dh_dcm_ast=namespace(total=42009, 3D=0, 2D=42009),
#           total_all_dicoms=42092,
#           total_2d_all=42092,
#           total_3d_all=0,
#           total_2d_cancer=1498,
#           total_2d_preindex=390,
#           total_2d_noncancer=40204,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=1498,
#           total_preindex=390,
#           total_noncancer=40204,
#           total_no_label=0))

# %%
# ol2 = O.OmamaLoader(config_num=30)
# data2 = O.Data(data_loader=ol2, cache=True, timing=True, print_data=True)
# Out:
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# load_studies             ...took     0.055223 seconds
# load_images              ...took     0.021730 seconds
# csv_to_map               ...took     0.268591 seconds
# 1000                     ...took     1.608203 seconds
# 2000                     ...took     3.010333 seconds
# 3000                     ...took     4.403189 seconds
# 4000                     ...took     5.766285 seconds
# 5000                     ...took     7.171348 seconds
# 6000                     ...took     8.519311 seconds
# 7000                     ...took     9.948888 seconds
# 8000                     ...took    11.306703 seconds
# 9000                     ...took    12.659890 seconds
# 10000                    ...took    14.097570 seconds
# 11000                    ...took    15.463594 seconds
# 12000                    ...took    16.849050 seconds
# 13000                    ...took    18.227171 seconds
# ...

# %%
ol3 = O.OmamaLoader(config_num=31)
data2 = O.Data(data_loader=ol3, cache=True, timing=True, print_data=True)
# Out:
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# load_studies             ...took     0.055610 seconds
# load_images              ...took     0.022032 seconds
# csv_to_map               ...took     0.215371 seconds
# 1000                     ...took     1.379015 seconds
# 2000                     ...took     2.803879 seconds
# 3000                     ...took     4.160624 seconds
# 4000                     ...took     5.546711 seconds
# 5000                     ...took     6.957019 seconds
# 6000                     ...took     8.309357 seconds
# 7000                     ...took     9.698528 seconds
# 8000                     ...took    11.049434 seconds
# 9000                     ...took    12.431841 seconds
# 10000                    ...took    13.828439 seconds
# 11000                    ...took    15.197741 seconds
# 12000                    ...took    16.622051 seconds
# 13000                    ...took    17.982358 seconds
# ...

# %%
ol4 = O.OmamaLoader(config_num=32)
data2 = O.Data(data_loader=ol4, cache=True, timing=True, print_data=True)
# Out:
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# load_studies             ...took     0.108902 seconds
# load_images              ...took     0.037657 seconds
# csv_to_map               ...took     0.472163 seconds
# 1000                     ...took     2.668623 seconds
# 2000                     ...took     5.220136 seconds
# 3000                     ...took     7.814710 seconds
# 4000                     ...took    10.379804 seconds
# 5000                     ...took    12.884311 seconds
# 6000                     ...took    15.529620 seconds
# 7000                     ...took    18.344122 seconds
# 8000                     ...took    20.849002 seconds
# 9000                     ...took    23.481866 seconds
# 10000                    ...took    26.072116 seconds
# 11000                    ...took    28.657886 seconds
# 12000                    ...took    31.222448 seconds
# 13000                    ...took    33.734807 seconds
# ...
