# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import sys
import time
sys.path.append('../..')
import omama as O
from IPython.display import display, Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
npz_data = np.load("/raid/mpsych/OMAMA/DATA/data/2d/images/2.25.100000039159562031368112550794429920461.npz")

# %%
print(npz_data.files)
# Out:
# ['data']

# %%
imshow(npz_data["data"])

# %%
type(npz_data["data"])
# Out:
# numpy.ndarray

# %%
npz_data["data"].dtype
# Out:
# dtype('uint16')

# %%
npz_data_resized = np.load("/raid/mpsych/OMAMA/DATA/data/2d_resized_1024/images/2.25.249674341777620714729127235408910089468.npz")

# %%
import json

# %%
json_path = "/raid/mpsych/OMAMA/DATA/data/2d_resized_1024/labels/2.25.249674341777620714729127235408910089468.json"

# %%
with open(json_path, 'r') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'coords': [211, 489, 313, 581], 'score': 0.3555743098258972}

# %%
npz_data_resized["data"].shape
# Out:
# (1024, 1024)

# %%
imshow(npz_data_resized["data"])

# %%
reshaped_img = np.resize(npz_data_resized["data"], (1024, 1024, 1))

# %%
reshaped_img.shape
# Out:
# (1024, 1024, 1)

# %%
imshow(reshaped_img)

# %%
O.DataHelper.view(image=npz_data_resized["data"], roi_coords=[211, 489, 313, 581])
# Out:
# type of data:  <class 'omama.data.Data'>
# bb: [211, 489, 313, 581]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('/raid/mpsych/OMAMA/DATA/data/2d_resized_1024/masks/2.25.100000039159562031368112550794429920461.png')
plt.imshow(img, cmap="gray")
plt.show()
