# %%
import sys
import time
# %pylab inline
# %load_ext autoreload
# %autoreload 2
sys.path.append('../..')
import omama as O
import  pydicom
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
omama_loader = O.OmamaLoader(config_num=36)
data = O.Data(data_loader=omama_loader, cache=True, timing = True)
# Out:
# Loading config data from ini file
# DataLoader type is:  <class 'omama.loaders.omama_loader.OmamaLoader'>
# load_studies             ...took     0.007111 seconds
# load_images              ...took     0.002373 seconds
# csv_to_map               ...took     0.255260 seconds
# 1000                     ...took     1.043417 seconds
# 2000                     ...took     2.079945 seconds
# 3000                     ...took     3.115571 seconds
# 4000                     ...took     4.155400 seconds
# 5000                     ...took     5.229877 seconds
# load_labels              ...took     6.079284 seconds
# save_pickle              ...took     0.007703 seconds
# generate_counts          ...took     0.006418 seconds
# generate_stats           ...took     0.006814 seconds
# total _init              ...took     6.374965 seconds
# total __init__           ...took     6.375201 seconds

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=11, 3D=0, 2D=11),
#           dh_dh0new=namespace(total=233, 3D=0, 2D=233),
#           dh_dcm_ast=namespace(total=5559, 3D=0, 2D=5559),
#           total_all_dicoms=5803,
#           total_2d_all=5803,
#           total_3d_all=0,
#           total_2d_cancer=5803,
#           total_2d_preindex=0,
#           total_2d_noncancer=0,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=5803,
#           total_preindex=0,
#           total_noncancer=0,
#           total_no_label=0))

# %%
len(data)
# Out:
# 5803

# %%
for i in range(len(data)):
    print(data.get_image(image_id=i,pixels=False).filePath)
# Out:
# /raid/data01/deephealth/dh_dcm_ast/2.25.100019467787541382690455566629544103893/DXm.2.25.124381528605702917763164197238060295247
# /raid/data01/deephealth/dh_dcm_ast/2.25.100019467787541382690455566629544103893/DXm.2.25.217321484352248699030844413496181043774
# /raid/data01/deephealth/dh_dcm_ast/2.25.100106310335705418077395932274653810425/DXm.2.25.38579031505102571256361347111343069904
# /raid/data01/deephealth/dh_dcm_ast/2.25.100290090557015004282341117448173003433/DXm.2.25.272789657192509341267773957749187214958
# /raid/data01/deephealth/dh_dcm_ast/2.25.100313016052817537845839577466619376871/DXm.2.25.116172399286609165352607502306838890473
# /raid/data01/deephealth/dh_dcm_ast/2.25.100313016052817537845839577466619376871/DXm.2.25.66114916102969461060135840931640547836
# /raid/data01/deephealth/dh_dcm_ast/2.25.10045169369314296912882598083529803797/DXm.2.25.113571073442308054940697312741941147650
# ...

# %%
data.get_image(image_id=1,pixels=False).filePath
# Out:
# '/raid/data01/deephealth/dh_dcm_ast/2.25.100019467787541382690455566629544103893/DXm.2.25.217321484352248699030844413496181043774'
