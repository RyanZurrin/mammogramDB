# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
imgs3D = O.DataHelper.get3D(N=5)

# %%
O.DataHelper.view(imgs3D[0])

# %%
O.DataHelper.view(imgs3D[1])

# %%
O.DataHelper.view(imgs3D[2])

# %%
O.DataHelper.view(imgs3D[3])

# %%
O.DataHelper.view(imgs3D[4])
