# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
# cache_path = r"/hpcstor6/scratch01/r/ryan.zurrin001/pickle/whitelistTest"
# whitelist_path = r"whitelist.txt"
omama_loader = O.OmamaLoader()
data = O.Data(data_loader=omama_loader, timing = True, load_cache=True)
# Out:
# load_studies             ...took     0.482857 seconds
# load_images              ...took    19.977002 seconds
# csv_to_map               ...took     0.214852 seconds
# load_pickle              ...took     4.656759 seconds
# generate_counts          ...took     0.995672 seconds
# generate_stats           ...took     1.082015 seconds
# total _init              ...took    27.420675 seconds
# total __init__           ...took    27.420702 seconds

# %%
print(data)
# Out:
# namespace(dh_dh2=namespace(total=22144, 3D=9363, 2D=12781),
#           dh_dh0new=namespace(total=126460, 3D=62736, 2D=63724),
#           dh_dcm_ast=namespace(total=819387, 3D=58, 2D=819329),
#           total_all_dicoms=967991,
#           total_2d_all=895834,
#           total_3d_all=72157,
#           total_2d_cancer=14965,
#           total_2d_preindex=1915,
#           total_2d_noncancer=855763,
#           total_3d_cancer=376,
#           total_3d_preindex=0,
#           total_3d_noncancer=67162,
#           total_cancer=15341,
#           total_preindex=1915,
#           total_noncancer=922925,
#           total_no_label=27810)
# None

# %%
data.get_image(dicom_name='2.25.100727004928486510517145390240221522870',pixels=False).StudyInstanceUID
# Out:
# '2.25.11906022736393544971066674489625122146'

# %%
data.get_image(dicom_name='2.25.100727004928486510517145390240221522870',pixels=False).label
# Out:
# 'PreIndexCancer'

# %%
import os
t0 = time.time() 
sopuid_list_paths = open("2D_whitelist_final.txt").read().splitlines()
sop_uids = []
for path in sopuid_list_paths:
    sop_uids.append(os.path.basename(path).replace('DXm.', ""))
print("...took ", time.time() - t0)
# Out:
# ...took  0.15770220756530762

# %%
t0 = time.time()
for sop in sop_uids:
    print(data.get_label(sop))
print("...took ", time.time() - t0)
# Out:
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# IndexCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# PreIndexCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# IndexCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# NonCancer
# PreIndexCancer
# NonCancer
# NonCancer
# NonCancer
# ...
