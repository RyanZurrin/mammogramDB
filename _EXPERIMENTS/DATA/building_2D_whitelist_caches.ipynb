# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import time
sys.path.insert(0,'../..')
import omama as O

# %%
ol = O.OmamaLoader(config_num=2)
data = O.Data(data_loader=ol, load_cache=True, timing=True)
# Out:
# load_studies             ...took     0.304903 seconds
# load_images              ...took     0.110381 seconds
# csv_to_map               ...took     0.218094 seconds
# load_pickle              ...took     0.389697 seconds
# generate_counts          ...took     0.212735 seconds
# generate_stats           ...took     0.223878 seconds
# total _init              ...took     1.470156 seconds
# total __init__           ...took     1.470226 seconds

# %%
imgs = O.DataHelper.get2D(N=100, randomize=True)

# %%
O.DataHelper.view_grid(imgs, ncols=10)
# Out:
# /home/ryan.zurrin001/Projects/omama/_EXPERIMENTS/DATA/../../omama/data_helper.py:139: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(pixels)

# %%
# ol = O.OmamaLoader(config_num=3)
# data = O.Data(data_loader=ol, load_cache=True, timing=True)

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=17, 3D=0, 2D=17),
#           dh_dh0new=namespace(total=288, 3D=0, 2D=288),
#           dh_dcm_ast=namespace(total=176187, 3D=0, 2D=176187),
#           total_all_dicoms=176492,
#           total_2d_all=176492,
#           total_3d_all=0,
#           total_2d_cancer=7465,
#           total_2d_preindex=1657,
#           total_2d_noncancer=167370,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=7465,
#           total_preindex=1657,
#           total_noncancer=167370,
#           total_no_label=0))

# %%
# new numbers after adding the new images after 3D rerun
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=14, 3D=0, 2D=14),
#           dh_dh0new=namespace(total=289, 3D=0, 2D=289),
#           dh_dcm_ast=namespace(total=176189, 3D=0, 2D=176189),
#           total_all_dicoms=176492,
#           total_2d_all=176492,
#           total_3d_all=0,
#           total_2d_cancer=7428,
#           total_2d_preindex=1694,
#           total_2d_noncancer=167370,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=7428,
#           total_preindex=1694,
#           total_noncancer=167370,
#           total_no_label=0))

# %%
# print(data) This was the numbers before rerunning with some additional ignored errors
# Out:
# namespace(dh_dh2=namespace(total=5123, 3D=5123, 2D=0),
#           dh_dh0new=namespace(total=52405, 3D=52405, 2D=0),
#           dh_dcm_ast=namespace(total=44, 3D=44, 2D=0),
#           total_all_dicoms=57572,
#           total_2d_all=0,
#           total_3d_all=57572,
#           total_2d_cancer=0,
#           total_2d_preindex=0,
#           total_2d_noncancer=0,
#           total_3d_cancer=294,
#           total_3d_preindex=0,
#           total_3d_noncancer=57278,
#           total_cancer=294,
#           total_preindex=0,
#           total_noncancer=57278,
#           total_no_label=0)
# None

# %%
data.filter_data(labels=['IndexCancer'])

# %%
len(data)
# Out:
# 7465

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=27, 3D=27, 2D=0),
#           dh_dh0new=namespace(total=347, 3D=347, 2D=0),
#           dh_dcm_ast=namespace(total=2, 3D=2, 2D=0),
#           total_all_dicoms=376,
#           total_2d_all=0,
#           total_3d_all=376,
#           total_2d_cancer=0,
#           total_2d_preindex=0,
#           total_2d_noncancer=0,
#           total_3d_cancer=376,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=376,
#           total_preindex=0,
#           total_noncancer=0,
#           total_no_label=0))

# %%
data[0].SOPInstanceUID
# Out:
# '2.25.123204232252392180492801746224515939015'

# %%
data.get_label(data[0].SOPInstanceUID)
# Out:
# 'IndexCancer'

# %%
for i in range(len(data)):
    print(data.get_label(data[i].SOPInstanceUID))
# Out:
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# IndexCancer
# ...

# %%
test_val = '2.25.62620874485538808299313569484625743110'
data.get_label(test_val)
# Out:
# 'IndexCancer'

# %%
O.DataHelper.view(test_val)

# %%
ol = O.OmamaLoader(config_num=14)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.250362 seconds
# load_images              ...took     0.104331 seconds
# csv_to_map               ...took     0.295759 seconds
# 1000                     ...took     1.487000 seconds
# 2000                     ...took     2.787044 seconds
# 3000                     ...took     4.054925 seconds
# 4000                     ...took     5.363242 seconds
# 5000                     ...took     6.634749 seconds
# 6000                     ...took     7.940421 seconds
# 7000                     ...took     9.248514 seconds
# 8000                     ...took    10.514732 seconds
# 9000                     ...took    11.785080 seconds
# 10000                    ...took    13.089479 seconds
# 11000                    ...took    14.391345 seconds
# 12000                    ...took    15.661882 seconds
# 13000                    ...took    16.933622 seconds
# 14000                    ...took    18.273888 seconds
# ...

# %%
ol = O.OmamaLoader(config_num=19)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.263644 seconds
# load_images              ...took     0.114386 seconds
# csv_to_map               ...took     0.224391 seconds
# 1000                     ...took     1.290083 seconds
# 2000                     ...took     2.527845 seconds
# 3000                     ...took     3.828676 seconds
# 4000                     ...took     5.074864 seconds
# 5000                     ...took     6.349071 seconds
# 6000                     ...took     7.592370 seconds
# 7000                     ...took     8.936215 seconds
# 8000                     ...took    10.183370 seconds
# 9000                     ...took    11.464569 seconds
# 10000                    ...took    12.758121 seconds
# 11000                    ...took    14.025654 seconds
# 12000                    ...took    15.278383 seconds
# 13000                    ...took    16.565859 seconds
# 14000                    ...took    17.850637 seconds
# ...

# %%
print(data)

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=16, 3D=0, 2D=16),
#           dh_dh0new=namespace(total=285, 3D=0, 2D=285),
#           dh_dcm_ast=namespace(total=162699, 3D=0, 2D=162699),
#           total_all_dicoms=163000,
#           total_2d_all=163000,
#           total_3d_all=0,
#           total_2d_cancer=5448,
#           total_2d_preindex=1514,
#           total_2d_noncancer=156038,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=5448,
#           total_preindex=1514,
#           total_noncancer=156038,
#           total_no_label=0))

# %%
partition_list = data.partition_data(4)
# Out:
# Saving partitioned paths to files in: /home/ryan.zurrin001/Projects/omama/omama

# %%
ol = O.OmamaLoader(config_num=20)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.054491 seconds
# load_images              ...took     0.021400 seconds
# csv_to_map               ...took     0.222721 seconds
# 1000                     ...took     1.060643 seconds
# 2000                     ...took     2.150579 seconds
# 3000                     ...took     3.204317 seconds
# 4000                     ...took     4.251102 seconds
# 5000                     ...took     5.305927 seconds
# 6000                     ...took     6.391275 seconds
# 7000                     ...took     7.556157 seconds
# 8000                     ...took     8.775246 seconds
# 9000                     ...took     9.820632 seconds
# 10000                    ...took    10.868506 seconds
# 11000                    ...took    11.956462 seconds
# 12000                    ...took    13.006016 seconds
# 13000                    ...took    14.055646 seconds
# 14000                    ...took    15.104190 seconds
# ...

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=6, 3D=0, 2D=6),
#           dh_dh0new=namespace(total=83, 3D=0, 2D=83),
#           dh_dcm_ast=namespace(total=40661, 3D=0, 2D=40661),
#           total_all_dicoms=40750,
#           total_2d_all=40750,
#           total_3d_all=0,
#           total_2d_cancer=0,
#           total_2d_preindex=0,
#           total_2d_noncancer=0,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=0,
#           total_preindex=0,
#           total_noncancer=0,
#           total_no_label=40750))

# %%
ol = O.OmamaLoader(config_num=21)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.054634 seconds
# load_images              ...took     0.021435 seconds
# csv_to_map               ...took     0.265445 seconds
# 1000                     ...took     1.281033 seconds
# 2000                     ...took     2.536916 seconds
# 3000                     ...took     3.780654 seconds
# 4000                     ...took     5.075524 seconds
# 5000                     ...took     6.356372 seconds
# 6000                     ...took     7.611435 seconds
# 7000                     ...took     8.874359 seconds
# 8000                     ...took    10.142610 seconds
# 9000                     ...took    11.428844 seconds
# 10000                    ...took    12.676846 seconds
# 11000                    ...took    13.967863 seconds
# 12000                    ...took    15.212318 seconds
# 13000                    ...took    16.503770 seconds
# 14000                    ...took    17.799666 seconds
# ...

# %%
ol = O.OmamaLoader(config_num=22)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.055040 seconds
# load_images              ...took     0.021360 seconds
# csv_to_map               ...took     0.283412 seconds
# 1000                     ...took     1.201551 seconds
# 2000                     ...took     2.426515 seconds
# 3000                     ...took     3.633385 seconds
# 4000                     ...took     4.920701 seconds
# 5000                     ...took     6.137774 seconds
# 6000                     ...took     7.349046 seconds
# 7000                     ...took     8.544847 seconds
# 8000                     ...took     9.836269 seconds
# 9000                     ...took    11.040999 seconds
# 10000                    ...took    12.246373 seconds
# 11000                    ...took    13.437064 seconds
# 12000                    ...took    14.685019 seconds
# 13000                    ...took    15.935911 seconds
# 14000                    ...took    17.146098 seconds
# ...

# %%
ol = O.OmamaLoader(config_num=23)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.055076 seconds
# load_images              ...took     0.021528 seconds
# csv_to_map               ...took     0.235066 seconds
# 1000                     ...took     1.252901 seconds
# 2000                     ...took     2.490248 seconds
# 3000                     ...took     3.756935 seconds
# 4000                     ...took     4.998610 seconds
# 5000                     ...took     6.263551 seconds
# 6000                     ...took     7.477760 seconds
# 7000                     ...took     8.727194 seconds
# 8000                     ...took     9.946810 seconds
# 9000                     ...took    11.203252 seconds
# 10000                    ...took    12.417489 seconds
# 11000                    ...took    13.684640 seconds
# 12000                    ...took    14.899325 seconds
# 13000                    ...took    16.155566 seconds
# 14000                    ...took    17.602390 seconds
# ...

# %%
ol = O.OmamaLoader(config_num=24)
data = O.Data(ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.004727 seconds
# load_images              ...took     0.000867 seconds
# csv_to_map               ...took     0.225301 seconds
# 1000                     ...took     1.389637 seconds
# load_labels              ...took     2.541844 seconds
# save_pickle              ...took     0.003509 seconds
# generate_counts          ...took     0.002508 seconds
# generate_stats           ...took     0.002139 seconds
# total _init              ...took     2.791991 seconds
# total __init__           ...took     2.792064 seconds

# %%
len(data)
# Out:
# 1844

# %%
ol = O.OmamaLoader(config_num=26)
data = O.Data(data_loader=ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.001770 seconds
# load_images              ...took     0.000655 seconds
# csv_to_map               ...took     0.235503 seconds
# 1000                     ...took     1.639712 seconds
# load_labels              ...took     1.639941 seconds
# save_pickle              ...took     0.001786 seconds
# generate_counts          ...took     0.001160 seconds
# generate_stats           ...took     0.001185 seconds
# total _init              ...took     1.893391 seconds
# total __init__           ...took     1.893463 seconds

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=0, 3D=0, 2D=0),
#           dh_dh0new=namespace(total=1, 3D=0, 2D=1),
#           dh_dcm_ast=namespace(total=999, 3D=0, 2D=999),
#           total_all_dicoms=1000,
#           total_2d_all=1000,
#           total_3d_all=0,
#           total_2d_cancer=52,
#           total_2d_preindex=8,
#           total_2d_noncancer=940,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=52,
#           total_preindex=8,
#           total_noncancer=940,
#           total_no_label=0))

# %%
ol = O.OmamaLoader(config_num=27)
data = O.Data(data_loader=ol, cache=True, timing=True)
# Out:
# load_studies             ...took     0.002065 seconds
# load_images              ...took     0.000544 seconds
# first 50 entries in the map:
# StudyInstanceUID_CancerLaterality Label
# 2.25.118657020821082351510538697641908046675_None NonCancer
# 2.25.24974237302217889236471674842254400421_None NonCancer
# 2.25.330047135490263461987008844163541144387_None NonCancer
# 2.25.293923190844227131155437522879504958950_None NonCancer
# 2.25.234810466767402426258529783173561476083_None NonCancer
# 2.25.199174419399158119793859673748151392666_None NonCancer
# 2.25.50156341657856004482802219473263047361_None NonCancer
# 2.25.314473309409711898986989792473893310266_None NonCancer
# 2.25.176497333925178329104957319752095303064_None NonCancer
# 2.25.68511605537248125160939947336621070795_None NonCancer
# 2.25.183043200940850072913104394857070637513_None NonCancer
# 2.25.47436651935812663600989194132969361745_None NonCancer
# 2.25.220769173478180874643691863640004015670_None NonCancer
# ...

# %%
print(data)
# Out:
# Data(namespace(dh_dh2=namespace(total=0, 3D=0, 2D=0),
#           dh_dh0new=namespace(total=4, 3D=0, 2D=4),
#           dh_dcm_ast=namespace(total=996, 3D=0, 2D=996),
#           total_all_dicoms=1000,
#           total_2d_all=1000,
#           total_3d_all=0,
#           total_2d_cancer=0,
#           total_2d_preindex=0,
#           total_2d_noncancer=0,
#           total_3d_cancer=0,
#           total_3d_preindex=0,
#           total_3d_noncancer=0,
#           total_cancer=0,
#           total_preindex=0,
#           total_noncancer=0,
#           total_no_label=1000))

# %%
data[0]
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 192
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.196019876218144338833912653988519089450
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.4
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_364'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', '']
# ...
